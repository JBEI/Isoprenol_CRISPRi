# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from textwrap import wrap
from matplotlib.font_manager import FontProperties
import re
from scipy import stats
from matplotlib.lines import Line2D 

line_size=0.5
custom_params = {
    'axes.facecolor': 'white',
    'axes.edgecolor': 'black',
    'axes.grid': False,
    'axes.axisbelow': 'line',
    'axes.labelcolor': 'black',
    'figure.facecolor': 'white',
    "axes.spines.right": True, 
    "axes.spines.bottom": True,
    'xtick.direction': 'inout',
    'ytick.direction': 'in',
    'xtick.bottom': True,
    'xtick.minor.visible': False,
    'xtick.major.bottom':  True,
    'xtick.minor.bottom':  True,
    'xtick.major.pad':     7,     # distance to major tick label in points#
    'xtick.minor.pad':     3.4,     # distance to the minor tick label in points#
    'xtick.major.size':    10,
    'ytick.major.size':    4,
    'xtick.major.width':   line_size,
    'ytick.major.width':   line_size,
    'axes.linewidth': line_size,
    'xtick.minor.size':    2,
    'pdf.fonttype': 42}

sns.set_theme(style="ticks", rc=custom_params, font="Arial",font_scale=0.7)

enmax_palette = ["#648FFF", "#FE6100", "#785EF0", "#DC267F", "#FFB000"]
sns.set_palette(palette=enmax_palette)

# %% [markdown]
# ### KO Strains only for 24C

# %%
#KO_Strains
fig="24C_Isoprenol"
df = pd.read_csv('Figure_Data\\241118_CT_24C_Isoprenol.csv')
df_sorted = df.sort_values(by='Strain', ascending=True)
data=df.copy()
filtered_data = data[~data['Strain'].str.startswith("PCK-")]

sns.set_palette(palette=enmax_palette)

w=len(filtered_data)/36
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
with sns.color_palette():
    ax=sns.stripplot(
        filtered_data, x="Strain", 
        y="Titer", 
        hue="Time", 
        dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2)

    ax=sns.barplot(
        filtered_data, x="Strain", y="Titer", hue="Time",
        errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
        linewidth =line_size, edgecolor="0", ax=ax,saturation=1)
    legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic') 

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 6.666666666666667
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3281112096.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD422B8D0> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3281112096.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD4228790> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3281112096.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021C9FF70910> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3281112096.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD4193AD0> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

# %% [markdown]
# ### PCK Strains only for 24C

# %%
#KO_Strains
fig="24C_Isoprenol_PCK"
df = pd.read_csv('Figure_Data\\241118_CT_24C_Isoprenol.csv')
df_sorted = df.sort_values(by='Strain', ascending=True)
data=df.copy()
filtered_data = data[data['Strain'].str.startswith("PCK-")]


sns.set_palette(palette=enmax_palette)

w=len(filtered_data)/24
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
with sns.color_palette():
    ax=sns.stripplot(
        filtered_data, x="Strain", 
        y="Titer", 
        hue="Time", 
        dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2)

    ax=sns.barplot(
        filtered_data, x="Strain", y="Titer", hue="Time",
        errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
        linewidth =line_size, edgecolor="0", ax=ax,saturation=1)
    legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic') 

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 5.5
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\2872875155.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD3A75E90> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\2872875155.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021C9FFFEE10> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\2872875155.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD3DDAF50> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\2872875155.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD3DDAB90> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

# %% [markdown]
# ### Ko Strains at 30C

# %%
#KO_Strains
fig="30C_Isoprenol"
df = pd.read_csv('Figure_Data\\241118_CT_30C_Isoprenol.csv')
df_sorted = df.sort_values(by='Strain', ascending=True)
data=df.copy()
filtered_data = data[~data['Strain'].str.startswith("PCK-")]


sns.set_palette(palette=enmax_palette)

w=len(filtered_data)/36
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
with sns.color_palette():
    ax=sns.stripplot(
        filtered_data, x="Strain", 
        y="Titer", 
        hue="Time", 
        dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2)

    ax=sns.barplot(
        filtered_data, x="Strain", y="Titer", hue="Time",
        errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
        linewidth =line_size, edgecolor="0", ax=ax,saturation=1)
    legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic') 

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 6.666666666666667
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3568217010.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD4012650> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3568217010.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD7BEFB50> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3568217010.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD7874290> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_46508\3568217010.py:32: UserWarning: The label '_' of <matplotlib.collections.PathCollection object at 0x0000021CD880BB50> starts with '_'. It is thus excluded from the legend.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

# %%
#KO_Strains
fig="24C_Isoprenol_PCK"
df = pd.read_csv('Figure_Data\\241118_CT_30C_Isoprenol.csv')
df_sorted = df.sort_values(by='Strain', ascending=True)
data=df.copy()
filtered_data = data[data['Strain'].str.startswith("PCK-")]


sns.set_palette(palette=enmax_palette)

w=len(filtered_data)/24
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
with sns.color_palette():
    ax=sns.stripplot(
        filtered_data, x="Strain", 
        y="Titer", 
        hue="Time", 
        dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2)

    ax=sns.barplot(
        filtered_data, x="Strain", y="Titer", hue="Time",
        errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
        linewidth =line_size, edgecolor="0", ax=ax,saturation=1)
    legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic') 

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 5.5
# C:\Users\Carruthers\AppData\Local\Temp\ipykernel_13160\2224596945.py:32: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(legend_handles,['_','_','_','_', 'Inoculation','Induction','24 hr', '48 hr'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

# %% [markdown]
# ### BioLector KOs

# %%
#KO_Strains
fig="Biolector_KOs"
df = pd.read_csv('Figure_Data\\241118_Biolector_KOs.csv')
data=df.copy()


#def add_newline(label, max_length=15):
#    if len(label) <= max_length:
#        return label  # No need to modify
#    split_index = label.find(" ", max_length)  # Find the next space after max_length
#    if split_index == -1:  # If no space is found, return as-is
#        return label
#    return label[:split_index] + "\n" + label[split_index + 1:]

# Apply the function to the 'Strain' column
#data["Strain2"] = data["Strain"].apply(add_newline)

sns.set_palette(palette=enmax_palette)
plot_color = "#648FFF" 

w=len(filtered_data)/24
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
ax=sns.stripplot(
    data, x="Strain", 
    y="Titer", 
    dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2, color=plot_color)

ax=sns.barplot(
    data, x="Strain", y="Titer",
    errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
    linewidth =line_size, edgecolor="0", ax=ax,saturation=1, color=plot_color)
legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain Annotation', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic')

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 5.5

# %%
#KO_Strains
fig="Biolector_KOs2"
df = pd.read_csv('Figure_Data\\241118_Biolector_KOs3.csv')
data=df.copy()

#def add_newline(label, max_length=15):
#    if len(label) <= max_length:
#        return label  # No need to modify
#    split_index = label.find(" ", max_length)  # Find the next space after max_length
#    if split_index == -1:  # If no space is found, return as-is
#        return label
#    return label[:split_index] + "\n" + label[split_index + 1:]

# Apply the function to the 'Strain' column
#data["Strain2"] = data["Strain"].apply(add_newline)

sns.set_palette(palette=enmax_palette)
plot_color = "#648FFF" 

w=len(data)/12
print(w)
plt.figure(figsize=(w,2.5))

#plot stripplot overlaid on a barplot
ax=sns.stripplot(
    data, x="Strain", 
    y="Titer", hue = "Type",
    dodge=True, alpha=0.7, linewidth =line_size, edgecolor="0", zorder=2)

ax=sns.barplot(
    data, x="Strain", y="Titer", hue = "Type",
    errorbar="sd", zorder=0, capsize=0.2, errcolor="0", errwidth=line_size,
    linewidth =line_size, edgecolor="0", ax=ax,saturation=1)
legend_handles, labels = ax.get_legend_handles_labels()

#format axes and legend
plt.xlabel('Strain Annotation', labelpad=15)
plt.ylabel('Titer (mg/L)', labelpad=10)
plt.legend(legend_handles,['_','_','CRISPRi','Non-Target'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)

plt.ylim(0,)
plt.xticks(rotation='vertical',style='italic')

ax.set_xlim(-0.65,None)

plt.savefig(f'Figure_Export\\{fig}.svg',dpi=1200, bbox_inches = 'tight')
plt.show()
# Out:
# 8.5
# C:\Users\Carruthers\AppData\Local\Temp\ipykernel_33580\2203387326.py:39: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   plt.legend(legend_handles,['_','_','CRISPRi','Non-Target'],bbox_to_anchor=(0.5, 1.05), loc='lower center', ncol=4)
