# %% [markdown]
# ### Volcano plots from Top3 proteomics data
#
# - The notebook requires Top3 data from proteomics with individual replicates
# - Originally designed for iterative upload of DBTL data (7 rounds)
#     - Substitute with your own data of interest

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
import re
from adjustText import adjust_text

# %% [markdown]
# #### Import Top3 data of interest

# %% [markdown]
# Load Top3 data from each of the DBTL cycles for analysis

# %%
# Define the filenames and the samples of interest
filenames = [f'DBTL{i}.csv' for i in range(7)]
#filenames = [f'DBTL{0}.csv']

# Load CSV files and concatenate into a single dataframe
dataframes = [pd.read_csv(filename) for filename in filenames]
combined_df = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# Check header

# %%
combined_df.head()
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 3        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 4        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control        R1           119112382.0
# 1  Control        R2           149172095.3
# 2  Control        R3           138700868.7
# 3  Control        R4           100306326.3
# 4  Control        R5           114276780.7
#
#    %_of protein_abundance_Top3-method  log10_%_abundance  Cycle
# 0                            3.112624           0.493127      0
# 1                            3.712705           0.569690      0
# 2                            3.700489           0.568259      0
# 3                            2.650788           0.423375      0
# 4                            2.835433           0.452619      0

# %% [markdown]
# Translate Top3 proteins into locus identities and then transform all of the uploaded concatenated .csvs

# %%
# Load the name_df DataFrame for translation
name_df = pd.read_csv('proteomics_id_translator_240305.csv') 

# Create a dictionary from the name_df for fast lookup
translator_dict = pd.Series(name_df['locus'].values, index=name_df['extracted']).to_dict()

# Use the dictionary to map the Protein.Group names to locus names
combined_df['Protein.Group'] = combined_df['Protein.Group'].map(lambda x: translator_dict.get(x, x))

# Count the number of non-translated protein groups
nontranslated = combined_df['Protein.Group'].apply(lambda x: x not in translator_dict.values()).sum()
print(f"In total, N = {nontranslated}/{len(combined_df['Protein.Group'])} proteins were not translated to locus names")
# Out:
# In total, N = 19710/2544333 proteins were not translated to locus names

# %% [markdown]
# ### Initialize a DataFrame to store log2 and log10 values for all samples

# %% [markdown]
# Include samples across all cycles to be analyzed
#
# ##### These will be compared against your "controls"

# %%
samples_of_interest = [
    "PP_0368",
    "PP_0437",
    "PP_0528",
    "PP_0812",
    "PP_0813",
    "PP_0814",
    "PP_0815",
    "PP_1317",
    "PP_1506",
    "PP_2136",
    "PP_4120",
    "PP_4189",
    "PP_4191",
    "PP_4192"]

# %%
# samples_of_interest = [
#     "PP_0751_PP_0813_PP_0815",
#     "PP_0528_PP_0751_PP_0815",
#     "PP_0528_PP_0751_PP_0812_PP_0815",
#     "PP_0528_PP_0751_PP_0813_PP_0815",
#     "PP_0368_PP_0751_PP_0815",
#     "PP_0368_PP_0751_PP_0813_PP_0815",
#     "PP_0368_PP_0814_PP_0815",
#     "PP_0368_PP_0751_PP_0812_PP_0815",
#     "PP_0368_PP_0751_PP_0814_PP_0815",
#     "PP_0812_PP_0813_PP_0815"]

# %% [markdown]
# #### Define your controls
# - Pairwise comparison of samples_of_interest to the defined controls pooled across all cycles

# %%
# Initialize an empty DataFrame to store log2 and log10 results
log2_log10_results = pd.DataFrame()
sample_control_pairs = {sample: "Control" for sample in samples_of_interest}

# %% [markdown]
# #### Set thresholds for the volcano plots
# - p-value threshold and log2 fold_change threshold
# - filtering Top3 data

# %%
# Define thresholds for filtering
# Use 1 if simply looking for any differences between a strain and a control
fold_change_threshold = 1.1
log2_fold_change_threshold= np.log2(fold_change_threshold)

p_value_threshold = 0.05
top3_filter = 0.01

# %% [markdown]
# ### Generate volcano plots
# - Sample pairs vs. control

# %%
# Initialize the results DataFrame before the loop
log2_log10_results = pd.DataFrame()
replicates_to_include = ['R4', 'R5', 'R6']

for sample, control in sample_control_pairs.items():
    # Filter data for the current sample and its control
    if sample in ['PP_0812', 'PP_0813']:
        sample_data = combined_df[(combined_df['Sample'] == sample) & (combined_df['Replicate'].isin(replicates_to_include))]
    else:
        sample_data = combined_df[combined_df['Sample'] == sample]
    
    control_data = combined_df[combined_df['Sample'] == control]

    # Debug: Check if data is loaded correctly
    if sample_data.empty or control_data.empty:
        print(f"No data for {sample} or {control}")
        continue

# for sample, control in sample_control_pairs.items():
#     sample_data = combined_df[combined_df['Sample'] == sample]
#     control_data = combined_df[combined_df['Sample'] == control]
#     # Debug: Check if data is loaded correctly
#     if sample_data.empty or control_data.empty:
#         print(f"No data for {sample} or {control}")
#         continue

    # Compute mean %_of protein_abundance_Top3-method for each protein
    sample_mean = sample_data.groupby('Protein.Group')['%_of protein_abundance_Top3-method'].mean().reset_index()
    control_mean = control_data.groupby('Protein.Group')['%_of protein_abundance_Top3-method'].mean().reset_index()

    # Rename columns for clarity
    sample_mean.rename(columns={'%_of protein_abundance_Top3-method': 'sample_abundance'}, inplace=True)
    control_mean.rename(columns={'%_of protein_abundance_Top3-method': 'control_abundance'}, inplace=True)

    # Filter reference_mean to include only abundances > top3_filter
    sample_mean = sample_mean[sample_mean['sample_abundance'] > top3_filter]

    # Merge the data on Protein.Group
    merged_data = pd.merge(sample_mean, control_mean, on='Protein.Group', how='outer')

    # Calculate log2 fold change (fill missing values with NaN)
    merged_data['log2_change'] = np.log2(merged_data['sample_abundance'] / merged_data['control_abundance'])

    # Debug: Check if log2_change contains NaN values
    if merged_data['log2_change'].isna().all():
        print(f"All log2 fold changes are NaN for {sample} vs {control}")
        continue

    # Compute p-values (assume replicates data exists for actual p-value calculation)
    sample_reps = sample_data[['Protein.Group', '%_of protein_abundance_Top3-method']]
    control_reps = control_data[['Protein.Group', '%_of protein_abundance_Top3-method']]

    p_values = []
    for protein in merged_data['Protein.Group']:
        group1 = sample_reps[sample_reps['Protein.Group'] == protein]['%_of protein_abundance_Top3-method']
        group2 = control_reps[control_reps['Protein.Group'] == protein]['%_of protein_abundance_Top3-method']
        if not group1.empty and not group2.empty:
            _, p_val = ttest_ind(group1, group2, equal_var=False)
        else:
            p_val = np.nan
        p_values.append(p_val)

    # Add p-values and log10 transformation
    merged_data['p_value'] = p_values
    merged_data['log10_p_value'] = -np.log10(merged_data['p_value'])

    # Debug: Check if log10_p_value contains NaN values
    if merged_data['log10_p_value'].isna().all():
        print(f"All log10 p-values are NaN for {sample} vs {control}")
        continue

    # Filter based on plotting criteria
    filtered_data = merged_data[
        (merged_data['log2_change'].abs() > log2_fold_change_threshold) &
        (merged_data['log10_p_value'] > -np.log10(p_value_threshold))
    ]

    # Store filtered results in log2_log10_results
    if not filtered_data.empty:
        temp_results = filtered_data[['Protein.Group', 'log2_change', 'log10_p_value']].copy()
        temp_results.rename(
            columns={'log2_change': f'{sample}_log2_FC', 'log10_p_value': f'{sample}_log10_pval'},
            inplace=True
        )

        # Merge with the main results DataFrame
        if log2_log10_results.empty:
            log2_log10_results = temp_results
        else:
            log2_log10_results = pd.merge(
                log2_log10_results,
                temp_results,
                on='Protein.Group',
                how='outer'
            )

    # Create volcano plot for the current sample
    fold_change = merged_data['log2_change']
    p_values = merged_data['log10_p_value']

    plt.figure(figsize=(8, 6))
    plt.scatter(fold_change, p_values, s=15, alpha=0.25)
    plt.title(f"{sample} vs {control}")
    plt.xlabel("Log2(Fold Change)")
    plt.ylabel("Log10(P-Value)")
    plt.grid(False)
    plt.ylim(0,)
    plt.xlim(-10, 10)

    # Threshold lines
    plt.axvline(x=log2_fold_change_threshold, color='r', linestyle='--', linewidth=1)
    plt.axvline(x=-log2_fold_change_threshold, color='r', linestyle='--', linewidth=1)
    plt.axhline(y=-np.log10(p_value_threshold), color='g', linestyle='--', linewidth=1)

#     #Annotate significant points; this adds arrows to each of the plots and is computationally intensive, will probably crash if threshold zero
#     texts = []
#     labels = merged_data['Protein.Group']
#     for i, label in enumerate(labels):
#         if (fold_change[i] > log2_fold_change_threshold or fold_change[i] <-log2_fold_change_threshold) and p_values[i] > -np.log10(p_value_threshold):
#             text = plt.text(fold_change[i], p_values[i], label, fontsize=10)
#             texts.append(text)

#     if texts:
#          adjust_text(texts, arrowprops=dict(arrowstyle='-', color='red', lw=1))

#     #Show the plot
    plt.show()

# Save the filtered log2 and log10 values to a CSV file
if not log2_log10_results.empty:
    log2_log10_results.to_csv('Volcano_Results.csv', index=False)
    print("Log2 and Log10 values saved to 'Volcano_Results.csv'")
else:
    print("No significant results to save.")
# Out:
# C:\Users\dcarruth\AppData\Local\Temp\ipykernel_93840\1849285139.py:58: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   _, p_val = ttest_ind(group1, group2, equal_var=False)
# Log2 and Log10 values saved to 'Volcano_Results.csv'

# %% [markdown]
# ### Investigating genes that are upregulated amongst a subset of samples

# %%
len('Volcano_Results.csv')
# Out:
# 19

# %% [markdown]
# #### TCA Cycle

# %%
# Define the list of proteins
pathway_name = "Proteins_TCA_Superpathway"
proteins_txt = pd.read_csv('pathway-genes-TCA.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the TCA cycle were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 22 out of 23 genes in the TCA cycle were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                        Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0356      glcB                         malate synthase G              NaN         0.388386         0.239308         0.246120              NaN         0.443595              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            1.404471            2.278190            1.409925                 NaN            2.504748                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0751      mqo1             malate:quinone oxidoreductase              NaN         0.396637              NaN              NaN              NaN        -0.473893              NaN         0.263472              NaN              NaN              NaN              NaN         0.753768         0.646253                 NaN            6.235630                 NaN                 NaN                 NaN            5.015221                 NaN            1.555690                 NaN                 NaN                 NaN                 NaN            2.686356            4.156044
#        PP_0944     fumC1                class 2 fumarate hydratase              NaN              NaN         6.136625              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.361058                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1251      mqo2             malate:quinone oxidoreductase         0.522914         1.404729              NaN              NaN              NaN              NaN         1.464025         0.816116              NaN        -1.136931              NaN              NaN         0.943809              NaN            5.212140            2.362737                 NaN                 NaN                 NaN                 NaN            4.058260            1.610323                 NaN            1.689554                 NaN                 NaN            1.878110                 NaN
#        PP_1755     fumC2                class 2 fumarate hydratase              NaN              NaN         0.692618        -0.659759        -0.812313              NaN              NaN              NaN              NaN              NaN              NaN        -0.447859         0.708912              NaN                 NaN                 NaN            6.199761            8.504934            2.220304                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4189      sucA       2-oxoglutarate dehydrogenase system              NaN         0.290524        -0.188365        -0.661438        -0.551801        -0.773129        -0.570174              NaN              NaN              NaN              NaN        -2.754805        -0.343164        -0.359255                 NaN            7.409880            3.446183            8.070072            2.414752            9.570732            2.453221                 NaN                 NaN                 NaN                 NaN           12.870766            3.195646            7.544621
#        PP_4190      sdhB                   succinate dehydrogenase              NaN              NaN        -0.238509        -0.401611        -0.527412        -0.306692        -0.794292              NaN              NaN              NaN              NaN              NaN        -0.415324        -0.865801                 NaN                 NaN            1.919901            2.130445            1.446252            1.616528            2.473026                 NaN                 NaN                 NaN                 NaN                 NaN            1.738356            5.336580
#        PP_4191      sdhA                   succinate dehydrogenase         0.189438              NaN        -0.255413        -0.196629              NaN        -0.176176        -0.352091              NaN              NaN              NaN              NaN              NaN        -0.284332        -0.587579            3.196496                 NaN            3.083363            1.684446                 NaN            2.663864            2.044045                 NaN                 NaN                 NaN                 NaN                 NaN            4.770083            2.920848
#        PP_4192      sdhD                   succinate dehydrogenase              NaN              NaN              NaN        -0.491543        -0.517974              NaN              NaN         0.445886         0.532931              NaN              NaN              NaN              NaN        -0.283810                 NaN                 NaN                 NaN            5.704728            2.045463                 NaN                 NaN            3.125680            1.333206                 NaN                 NaN                 NaN                 NaN            1.425535
#        PP_4193      sdhC                   succinate dehydrogenase              NaN              NaN        -0.393866              NaN        -1.373388              NaN        -0.352953              NaN        -1.252465              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.528278                 NaN            1.524697                 NaN            2.255575                 NaN            4.562449                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4194      gltA                          citrate synthase        -0.212244              NaN              NaN         0.173430         0.226027              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN         0.454676            1.609933                 NaN                 NaN            1.923792            1.995956                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            2.107764
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### Branched Chain AA Superpathway

# %%
# Define the list of proteins
pathway_name = "Proteins_AA_Superpathway"
proteins_txt = pd.read_csv('pathway-genes-BRANCHED-CHAIN-AA-SYN-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# %% [markdown]
# #### Glycolysis Genes

# %%
# Define the list of proteins
pathway_name = "Glycolysis"
proteins_txt = pd.read_csv('pathway-genes-PWY1G01-2.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} cycle were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 26 out of 34 genes in the Glycolysis cycle were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                                          Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0415       rpe                            ribulose-5-phosphate 3-epimerase              NaN              NaN        -0.366499         0.213497              NaN              NaN              NaN              NaN        -0.192234              NaN              NaN              NaN         0.306503              NaN                 NaN                 NaN            4.981107            2.767403                 NaN                 NaN                 NaN                 NaN            1.829820                 NaN                 NaN                 NaN            2.665742                 NaN
#        PP_1009      gapA                    glyceraldehyde-3-phosphate dehydrogenase              NaN        -0.752818        -0.252604              NaN              NaN         0.182089        -0.572034        -0.447601        -1.078030              NaN              NaN              NaN        -0.648514        -0.432726                 NaN            5.397051            2.361465                 NaN                 NaN            1.468072            4.521777            4.380820            8.559868                 NaN                 NaN                 NaN            5.545975            4.163084
#        PP_1010       edd                                phosphogluconate dehydratase              NaN        -0.272269              NaN        -0.152296        -0.140362              NaN        -0.396858        -0.195067              NaN              NaN        -0.172372              NaN              NaN              NaN                 NaN            3.691268                 NaN            2.208118            2.942575                 NaN            1.553427            2.207297                 NaN                 NaN            1.783375                 NaN                 NaN                 NaN
#        PP_1011       glk                                                 glucokinase              NaN              NaN              NaN              NaN              NaN        -0.217464              NaN              NaN              NaN              NaN              NaN              NaN              NaN        -0.198374                 NaN                 NaN                 NaN                 NaN                 NaN            2.403796                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.411970
#        PP_1022     zwf-1                         glucose 6-phosphate-1-dehydrogenase              NaN              NaN         0.168286              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.126129                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1023       pgl                                   6-phosphogluconolactonase              NaN              NaN         0.235827              NaN         0.325316         0.386984         0.391316              NaN         0.593146        -0.409972              NaN              NaN         0.692070              NaN                 NaN                 NaN            3.209865                 NaN            1.915981            2.782003            2.292438                 NaN            1.932359            4.489745                 NaN                 NaN            4.920359                 NaN
#        PP_1024       eda                                           KHG/KDPG aldolase        -0.311405        -0.505757         0.492084         0.490707         0.490914         0.567566              NaN              NaN              NaN        -0.706530              NaN              NaN         0.391689              NaN            1.616924            2.725510            3.504495            3.223036            1.729247            4.386733                 NaN                 NaN                 NaN            2.297498                 NaN                 NaN            4.332899                 NaN
 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_3416      gnuK                                          D-gluconate kinase              NaN        -0.722960         0.191190        -0.266237        -0.373089              NaN        -1.256818        -0.449659        -0.476436         0.585574              NaN         0.462993        -0.801692        -0.552362                 NaN            2.842115            1.658540            2.079137            3.515195                 NaN            6.556196            1.560978            2.060254            4.228786                 NaN            3.432667            5.525305            4.533038
#        PP_3443       NaN                    glyceraldehyde-3-phosphate dehydrogenase              NaN              NaN         0.512356              NaN        -0.296400              NaN              NaN              NaN              NaN              NaN              NaN              NaN         0.534344              NaN                 NaN                 NaN            5.612969                 NaN            1.925158                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            2.385897                 NaN
#        PP_4701     pgi-2                               glucose 6-phosphate isomerase              NaN              NaN         1.216870              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            4.574268                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4715      tpiA                                  triose phosphate isomerase              NaN              NaN        -0.230864              NaN              NaN              NaN        -0.175704              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            3.105637                 NaN                 NaN                 NaN            1.528904                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4960       fba                              fructose-bisphosphate aldolase        -0.153960              NaN        -0.155441         0.328534         0.387084         0.376531              NaN              NaN         0.259017              NaN         0.281818         0.716477         0.721560         0.728776            1.852432                 NaN            1.587841            2.120680            2.635145            3.103475                 NaN                 NaN            2.331902                 NaN            3.447303            1.500558            3.898821            2.541157
#        PP_4963       pgk                                     phosphoglycerate kinase              NaN         0.276128        -0.161099              NaN              NaN              NaN         0.428312              NaN              NaN              NaN         0.154593              NaN         0.580976         0.659088                 NaN            3.299285            1.851864                 NaN                 NaN                 NaN            2.131107                 NaN                 NaN                 NaN            1.401472                 NaN            1.349372            1.686221
#        PP_4965      tktA                                             transketolase A              NaN              NaN              NaN              NaN         0.265555              NaN         0.398479         0.478838              NaN              NaN         0.179065              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN            3.084013                 NaN            1.959137            2.352363                 NaN                 NaN            1.428672                 NaN                 NaN                 NaN
#        PP_5040       fbp                         class 1 fructose-1,6-bisphosphatase              NaN        -0.214368        -0.254529        -0.313687        -0.277784        -0.512668              NaN        -0.230942        -0.302909        -0.236767              NaN              NaN              NaN         0.138414                 NaN            2.018150            1.717498            3.494261            7.622598            5.545634                 NaN            1.519720            2.518127            2.102399                 NaN                 NaN                 NaN            1.616911
#        PP_5056      gpmI 2,3-bisphosphoglycerate-independent phosphoglycerate mutase        -0.220186        -0.149076              NaN              NaN         0.226124              NaN         0.330697              NaN              NaN              NaN              NaN         0.614049         0.442760         0.313209            1.485873            1.965021                 NaN                 NaN            2.226027                 NaN            1.369584                 NaN                 NaN                 NaN                 NaN            2.109906            3.503450            2.096457
#        PP_5150      rpiA                              ribose-5-phosphate isomerase A              NaN         0.174729        -0.305413        -0.520287              NaN              NaN              NaN              NaN        -0.424217              NaN              NaN              NaN              NaN              NaN                 NaN            1.766740            5.993965            5.240436                 NaN                 NaN                 NaN                 NaN            1.424500                 NaN                 NaN                 NaN                 NaN                 NaN
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### Non-oxidative PP Pathway

# %%
# Define the second list of proteins
pathway_name = "Proteins_Non_Oxidative_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-NONOXIPENT-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
# Out:
# 1 out of 4 genes in the Proteins_Non_Oxidative_PP_Pathway were significantly changed across strains
# Those genes were:
# Gene Accession Gene name Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_2168       tal      transaldolase              NaN              NaN              NaN              NaN              NaN              NaN         1.150121              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.563552                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN

# %% [markdown]
# #### Oxidative PP Pathway

# %%
# Define the list of proteins
pathway_name = "Proteins_Oxidative_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-OXIDATIVEPENT-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 1 out of 5 genes in the Proteins_Oxidative_PP_Pathway were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                  Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_5351     zwf-3 glucose 6-phosphate 1-dehydrogenase              NaN         1.150998         1.387071              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            4.258971            1.433859                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### PP Pathway

# %%
# Define the list of proteins
pathway_name = "Proteins_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-PENTOSE-P-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

filtered_data = log2_log10_results.dropna(subset=[f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest])
matching_proteins = filtered_data[filtered_data['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)
# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
# Out:
# 0 out of 9 genes were significantly changed across strains
# Those genes were:
# Empty DataFrame
# Columns: [Gene Accession, Gene name, Enzymatic activity, PP_0368_log2_FC, PP_0437_log2_FC, PP_0528_log2_FC, PP_0812_log2_FC, PP_0813_log2_FC, PP_0814_log2_FC, PP_0815_log2_FC, PP_1317_log2_FC, PP_1506_log2_FC, PP_2136_log2_FC, PP_4120_log2_FC, PP_4189_log2_FC, PP_4191_log2_FC, PP_4192_log2_FC, PP_0368_log10_pval, PP_0437_log10_pval, PP_0528_log10_pval, PP_0812_log10_pval, PP_0813_log10_pval, PP_0814_log10_pval, PP_0815_log10_pval, PP_1317_log10_pval, PP_1506_log10_pval, PP_2136_log10_pval, PP_4120_log10_pval, PP_4189_log10_pval, PP_4191_log10_pval, PP_4192_log10_pval]
# Index: []

# %% [markdown]
# #### Full ETC

# %%
# Define the second list of proteins
pathway_name = "pathway-genes-PWY-Respiration_Full"
proteins_txt = pd.read_csv('pathway-genes-PWY-Respiration_Full.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 30 out of 53 genes were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                           Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0812      cyoA              cytochrome bo3 terminal oxidase              NaN              NaN        -0.201859              NaN              NaN              NaN        -1.741433              NaN              NaN              NaN              NaN              NaN              NaN         0.410980                 NaN                 NaN            2.031504                 NaN                 NaN                 NaN            5.718675                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.953312
#        PP_0813      cyoB              cytochrome bo3 terminal oxidase              NaN              NaN              NaN              NaN              NaN              NaN         0.229562              NaN              NaN              NaN              NaN         0.144774              NaN         0.521049                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            3.212869                 NaN                 NaN                 NaN                 NaN            1.302598                 NaN            2.463570
#        PP_1317      petA                       cytochrome bc1 complex              NaN              NaN         0.248208              NaN              NaN         0.608200         0.695331              NaN              NaN              NaN              NaN        -0.891016         1.362828         0.683140                 NaN                 NaN            1.993072                 NaN                 NaN            2.032194            1.979445                 NaN                 NaN                 NaN                 NaN            2.757612            2.103327            2.766594
#        PP_1319      petC                       cytochrome bc1 complex              NaN              NaN              NaN         0.428172         0.401476         0.694540         0.661762        -1.461012              NaN              NaN              NaN        -0.595606         1.326082         0.764077                 NaN                 NaN                 NaN            2.782673            3.318669            4.973991            1.418490            2.645575                 NaN                 NaN                 NaN            5.558117            2.623678            5.029422
#        PP_4120      nuoB NADH:ubiquinone reductase (H+-translocating)         0.283208         0.356224              NaN        -0.374203        -0.252624              NaN              NaN              NaN              NaN              NaN              NaN              NaN         0.289543              NaN            1.486447            4.852886                 NaN            1.949524            2.134321                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_5415      atpA                                 ATP synthase              NaN        -0.290365              NaN         0.657805         0.664721         0.555051         0.449153         0.262256         0.438823              NaN         0.309697              NaN         0.553929         0.344967                 NaN            4.294074                 NaN            2.488476            2.006763            2.139461            2.043108            2.477948            1.443561                 NaN            6.927919                 NaN            3.327959            1.961518
#        PP_5416      atpH                                 ATP synthase              NaN              NaN              NaN         0.706409         0.639870         0.423061              NaN              NaN              NaN              NaN         0.460121              NaN         0.530035              NaN                 NaN                 NaN                 NaN            9.602186            6.116991            1.885765                 NaN                 NaN                 NaN                 NaN            4.928212                 NaN            2.289159                 NaN
#        PP_5417      atpF                                 ATP synthase              NaN              NaN              NaN         0.582583         0.591271         0.449117              NaN         0.381177              NaN              NaN         0.393466              NaN         0.516882         0.181298                 NaN                 NaN                 NaN            3.429470            1.713619            2.748363                 NaN            2.391245                 NaN                 NaN            1.324767                 NaN            3.879017            1.492836
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "8-amino-7-oxononanoate biosynthesis"
proteins_txt = pd.read_csv('8-amino-7-oxononanoate biosynthesis.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 11 out of 20 genes were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                                               Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0363      bioF                                  8-amino-7-oxononanoate synthase              NaN         4.948147         2.276137              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            1.412259            0.702272                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0364      bioH                               pimeloyl-ACP methyl ester esterase              NaN         2.153040              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              Na
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "pyruvate_to_aceCoA"
proteins_txt = pd.read_csv('pyruvate_to_aceCoA.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 4 out of 4 genes were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                  Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0338      aceF         AceF-S-acetyldihydrolipoate              NaN         0.417881              NaN              NaN              NaN        -0.212638              NaN         0.334121              NaN              NaN              NaN              NaN              NaN         0.335403                 NaN            2.261722                 NaN                 NaN                 NaN            1.333662                 NaN            3.265091                 NaN                 NaN                 NaN                 NaN                 NaN            2.201861
#        PP_0339      aceE pyruvate dehydrogenase E1 component         0.186257         0.358541              NaN        -0.301413        -0.281034        -0.404250        -0.540122              NaN              NaN              NaN              NaN              NaN              NaN              NaN            1.751200            4.834314                 NaN            1.540401            4.313383           11.690939            1.379370                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4187      lpdG         dihydrolipoyl dehydrogenase        -0.213477              NaN              NaN        -0.720353        -0.526100        -0.788279        -0.542341        -0.416902        -0.787339        -0.253101        -0.567896        -2.516605        -0.387113        -0.734688            1.907906                 NaN                 NaN            7.442227            6.081902            8.682425            3.963584            2.905038            5.321065            1.659953            5.528544            11.71969            2.560842            5.783035
#        PP_5366       lpd         dihydrolipoyl dehydrogenase              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN         1.202863              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            4.010713                 NaN
# The genes were saved to 'locus_genes.csv'
