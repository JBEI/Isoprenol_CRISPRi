# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy.stats import linregress

# %%
input_dir = r'Figure_Data'
output_dir = r'Figure_Export'

# %%
# Incorporates all DBTL cycles
# filenames = [f'DBTL{i}.csv' for i in range(7)]
filenames = [f'DBTL{0}.csv']
input_paths = [os.path.join(input_dir, filename) for filename in filenames]

# Load CSVs and concatenate multiple files if necessary
dataframes = [pd.read_csv(input_path) for input_path in input_paths]
df = pd.concat(dataframes, ignore_index=True)

# %%
# Filter the dataframe for 'Control' samples
control_df = df[df['Sample'] == 'Control']

# Group by relevant protein identifiers and calculate the mean abundance
grouped_control_df = control_df.groupby(['Protein.Group', 'Protein.Names', 'Protein', 'Protein.Description']).agg({
    '%_of protein_abundance_Top3-method': 'mean'
}).reset_index()

# Sort the groups by mean abundance in descending order
sorted_grouped_control_df = grouped_control_df.sort_values(by='%_of protein_abundance_Top3-method', ascending=False)

# Assign ranks based on the sorted mean abundance
sorted_grouped_control_df['Rank'] = sorted_grouped_control_df['%_of protein_abundance_Top3-method'].rank(ascending=False, method='first')

# Sort by rank to ensure the dataframe is ordered by rank
ranked_df = sorted_grouped_control_df.sort_values(by='Rank')
ranked_df.to_csv('ranked_proteins.csv', index=False)

print("Dataframe saved to 'ranked_proteins.csv'")
ranked_df.head(25)
# Out:
# Dataframe saved to 'ranked_proteins.csv'
#      Protein.Group Protein.Names  Protein  \
# 0           P00552    KKA2_KLEPN      Neo
# 26          P32377    MVD1_YEAST     Mvd1
# 1434        Q88N55    CH60_PSEPK     Grol
# 25          P23181   AACC1_PSEAI    Aacc1
# 1857        Q88QN7   EFTU2_PSEPK     Tufb
# 44          Q835L3  Q835L3_ENTFA  Ef_1364
# 18          P0A157     RL7_PSEPK     Rpll
# 411         Q88DU2    DNAK_PSEPK     Dnak
# 1864        Q88QP4     RL1_PSEPK     Rpla
# 649         Q88FB2    SUCC_PSEPK     Succ
# 2047        Q8PW39  Q8PW39_METMA      Mvk
# 1843        Q88QM3     RL5_PSEPK     Rple
# 2049        Q9FD71   HMGCS_ENTFL     Mvas
# 1846        Q88QM6    RS17_PSEPK     Rpsq
# 1066        Q88KI7  Q88KI7_PSEPK     Hupb
# 650         Q88FB3  Q88FB3_PSEPK     Sucd
# 446         Q88DZ0    ILVC_PSEPK     Ilvc
# 1858        Q88QN8    EFG1_PSEPK     Fusa
# 1435        Q88N56    CH10_PSEPK     Gros
# 1856        Q88QN6    RS10_PSEPK     Rpsj
# 1345        Q88MH9    EFTS_PSEPK      Tsf
# 1859        Q88QN9     RS7_PSEPK     Rpsg
# 1848        Q88QM8    RL16_PSEPK     Rplp
# 1264        Q88M03  Q88M03_PSEPK     Rpsa
# 1854        Q88QN4     RL4_PSEPK     Rpld
#
#                                     Protein.Description  \
# 0                  Aminoglycoside 3'-phosphotransferase
# 26                    Diphosphomevalonate decarboxylase
# 1434                                  60 kDa chaperonin
# 25                     Gentamicin 3-N-acetyltransferase
# 1857                             Elongation factor Tu-B
# 44    Acetyl-CoA acetyltransferase/hydroxymethylglut...
# 18                         50S ribosomal protein L7/L12
# 411                              Chaperone protein DnaK
# 1864                           50S ribosomal protein L1
# 649      Succinyl-CoA ligase [ADP-forming] subunit beta
# 2047                                  Mevalonate kinase
# 1843                           50S ribosomal protein L5
# 2049                 Hydroxymethylglutaryl-CoA synthase
# 1846                          30S ribosomal protein S17
# 1066                        DNA-binding protein HU-beta
# 650     Succinyl-CoA ligase [ADP-forming] subunit alpha
# 446                         Ketol-acid reductoisomerase
# 1858                              Elongation factor G 1
# 1435                                  10 kDa chaperonin
# 1856                          30S ribosomal protein S10
# 1345                               Elongation factor Ts
# 1859                           30S ribosomal protein S7
# 1848                          50S ribosomal protein L16
# 1264                           30S ribosomal protein S1
# 1854                           50S ribosomal protein L4
#
#       %_of protein_abundance_Top3-method  Rank
# 0                               3.352559   1.0
# 26                              2.507166   2.0
# 1434                            2.283663   3.0
# 25                              1.973718   4.0
# 1857                            1.813564   5.0
# 44                              1.460456   6.0
# 18                              1.334310   7.0
# 411                             1.094669   8.0
# 1864                            1.037850   9.0
# 649                             0.991579  10.0
# 2047                            0.972202  11.0
# 1843                            0.793678  12.0
# 2049                            0.785364  13.0
# 1846                            0.775310  14.0
# 1066                            0.763672  15.0
# 650                             0.748213  16.0
# 446                             0.708089  17.0
# 1858                            0.699339  18.0
# 1435                            0.667305  19.0
# 1856                            0.602236  20.0
# 1345                            0.600327  21.0
# 1859                            0.577883  22.0
# 1848                            0.556932  23.0
# 1264                            0.555815  24.0
# 1854                            0.540607  25.0
