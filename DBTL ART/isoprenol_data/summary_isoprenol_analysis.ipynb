# %% [markdown]
# # Basic isoprenol analysis
#
# Make some basic plots for isoprenol comparison across DBTL cycles.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
isoprenol_files = [f'dbtl{i}_isoprenol.pkl' for i in [0, 1, 2, 3, 4, 5, 6]]
df_list = [pd.read_pickle(f) for f in isoprenol_files]
for i, df in enumerate(df_list):
    df['cycle'] = i

    
df_all = pd.concat(df_list).reset_index(drop = True)
df_all.head(3)
df_all['is_control'] = df_all['Line Name'].apply(lambda x: 'ontrol' in x)

# %%
# df6 = pd.read_excel('dbtl6_isoprenol_data_sheet3only.xlsx')
# df6 = df6.rename(columns = {'Concentration []':'Value',
#                            })
# df6['cycle'] = 6
# df_list.append(df6)
# df_all2 = pd.concat(df_list).reset_index(drop = True)
# df_all2.loc[df_all2['cycle'] == 6, 'is_control'] = df_all2.loc[df_all2['cycle'] == 6,'Line Name'].apply(lambda x: 'ontrol_P' in x)
# df_all2.loc[df_all2['cycle'] != 6, 'is_control'] = df_all2.loc[df_all2['cycle'] != 6,'Line Name'].apply(lambda x: 'ontrol' in x)

# %%
df_all
# Out:
#       Study ID                                         Study Name  Line ID  \
# 0       187352  CORRECTED: CRISPRi automation for enhanced iso...   187360
# 1       187352  CORRECTED: CRISPRi automation for enhanced iso...   187368
# 2       187352  CORRECTED: CRISPRi automation for enhanced iso...   187376
# 3       187352  CORRECTED: CRISPRi automation for enhanced iso...   187408
# 4       187352  CORRECTED: CRISPRi automation for enhanced iso...   187416
# ...        ...                                                ...      ...
# 1516    219427  CRISPRi automation for enhanced isoprenol prod...   219576
# 1517    219427  CRISPRi automation for enhanced isoprenol prod...   219571
# 1518    219427  CRISPRi automation for enhanced isoprenol prod...   219465
# 1519    219427  CRISPRi automation for enhanced isoprenol prod...   219473
# 1520    219427  CRISPRi automation for enhanced isoprenol prod...   219457
#
#                              Replicate Key  \
# 0     3475b66f-023e-4334-a86d-374b4094f346
# 1     0445a7bc-3aaf-401a-a0c4-e77922997140
# 2     086e7c52-b5ac-42ca-81d1-e170b23b37fc
# 3     8d8b104b-b36a-4c30-b5d9-1449e73fb218
# 4     63f68f0d-d4a8-4b64-b1ba-8412da15aecb
# ...                                    ...
# 1516  e0758715-6e77-45bd-a030-69fd91db5c0b
# 1517  860e403e-7b5f-49f6-b145-2bf7d899aa52
# 1518  bd9cae9b-c6eb-4e93-926b-56875cbcc727
# 1519  b7d03b6c-bc52-4a90-a8a2-9296d8d6bb2a
# 1520  016cda7f-91fe-46ad-aec9-6039aeb63d48
#
#                                Line Name Line Description Protocol  Assay ID  \
# 0                             Control-R1         BL1A1_NT   GC-FID    188815
# 1                             Control-R2         BL1B1_NT   GC-FID    188823
# 2                             Control-R3         BL1C1_NT   GC-FID    188831
# 3                             Control-R4         BL2A1_NT   GC-FID    188863
# 4                             Control-R5         BL2B1_NT   GC-FID    188871
# ...                                  ...              ...      ...       ...
# 1516  PP_0368_PP_0751_PP_0815_PP_1506-R1     DBTL6_P4_005   GC-FID    219792
# 1517                       Control_P3-R3     DBTL6_P3_048   GC-FID    219793
# 1518          PP_0815_PP_1506_PP_4120-R2     DBTL6_P1_038   GC-FID    219794
# 1519          PP_0815_PP_1506_PP_4120-R3     DBTL6_P1_046   GC-FID    219795
# 1520          PP_0815_PP_1506_PP_4120-R1     DBTL6_P1_030   GC-FID    219796
#
#                               Assay Name Formal Type       Measurement Type  \
# 0                             Control-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1                             Control-R2   cid:12988  3-METHYL-3-BUTEN-1-OL
# 2                             Control-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 3                             Control-R4   cid:12988  3-METHYL-3-BUTEN-1-OL
# 4                             Control-R5   cid:12988  3-METHYL-3-BUTEN-1-OL
# ...                                  ...         ...                    ...
# 1516  PP_0368_PP_0751_PP_0815_PP_1506-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1517                       Control_P3-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1518          PP_0815_PP_1506_PP_4120-R2   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1519          PP_0815_PP_1506_PP_4120-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1520          PP_0815_PP_1506_PP_4120-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
#
#       Compartment Units      Value  Hours  cycle  is_control
# 0               0  mg/L  177.33700   24.0      0        True
# 1               0  mg/L  181.88373   24.0      0        True
# 2               0  mg/L  169.40580   24.0      0        True
# 3               0  mg/L  161.67620   24.0      0        True
# 4               0  mg/L  136.42987   24.0      0        True
# ...           ...   ...        ...    ...    ...         ...
# 1516            0  mg/L  138.55210   48.0      6       False
# 1517            0  mg/L  132.53390   48.0      6        True
# 1518            0  mg/L   77.85280   48.0      6       False
# 1519            0  mg/L   77.30950   48.0      6       False
# 1520            0  mg/L   74.09180   48.0      6       False
#
# [1521 rows x 17 columns]

# %%
# df_all2

# %%
df_all.columns
# Out:
# Index(['Study ID', 'Study Name', 'Line ID', 'Replicate Key', 'Line Name',
#        'Line Description', 'Protocol', 'Assay ID', 'Assay Name', 'Formal Type',
#        'Measurement Type', 'Compartment', 'Units', 'Value', 'Hours', 'cycle',
#        'is_control'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,3]) & (~df_all['is_control'])),:],
               x = 'cycle',
               y = 'Value',
               cut = 0,
               palette= sns.color_palette('plasma'),
              ax = ax)

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axhline(control_mean_all, c='k', linestyle = '--')
fig.savefig('dbtl0_1_3_violin_compare.pdf')
# Out:
# /tmp/ipykernel_175/4290417705.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,3]) & (~df_all['is_control'])),:],
# /tmp/ipykernel_175/4290417705.py:2: UserWarning: The palette list has more values (6) than needed (3), which may not be intended.
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,3]) & (~df_all['is_control'])),:],

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5]) & (~df_all['is_control'])),:],
               x = 'cycle',
               y = 'Value',
               cut = 0,
               palette= sns.color_palette('flare'),
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axhline(control_mean_all, c='k', linestyle = '--')
fig.savefig('dbtl0_1_2_3_4_5_violin_compare.pdf')
fig.savefig('dbtl0_1_2_3_4_5_violin_compare.png')
# Out:
# /tmp/ipykernel_175/3616579099.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5]) & (~df_all['is_control'])),:],

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],
               y = 'cycle',
               x = 'Value',
               cut = 0,
               palette= sns.color_palette('flare', n_colors=7),
               orient = 'h',
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axvline(control_mean_all, c='k', linestyle = '--')
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('DBTL Cycle')
fig.savefig('dbtl0_1_2_3_4_5_6violin_compare_horiz.pdf')
fig.savefig('dbtl0_1_2_3_4_5_6violin_compare_horiz.png')
# Out:
# /tmp/ipykernel_175/2395501458.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],

# %%
fig, ax = plt.subplots(figsize = (4, 4))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],
               y = 'cycle',
               x = 'Value',
               cut = 0,
               palette= sns.color_palette('flare', n_colors=7),
               orient = 'h',
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axvline(control_mean_all, c='k', linestyle = '--')
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('DBTL Cycle')
fig.savefig('dbtl0_1_2_3_4_5_6violin_compare_horiz_small.pdf')
fig.savefig('dbtl0_1_2_3_4_5_6violin_compare_horiz_small.png')
# Out:
# /tmp/ipykernel_175/2312846341.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5]) & (df_all['is_control'])),:],
               x = 'cycle',
               y = 'Value',
               cut = 0,
               palette= sns.color_palette('flare'),
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axhline(control_mean_all, c='k', linestyle = '--')
fig.savefig('dbtl0_1_2_3_4_5_CONTROL_violin_compare.pdf')
fig.savefig('dbtl0_1_2_3_4_5_CONTROL_violin_compare.png')
# Out:
# /tmp/ipykernel_175/2346285959.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5]) & (df_all['is_control'])),:],

# %% [markdown]
# ## Make overall figure

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.boxplot(data = df_all.loc[(~df_all['is_control']),:],
               x = 'cycle',
               y = 'Value',
               ax = ax)

# max_titer_vals = [df_all.loc[df_all['cycle'] == i, 'Value'].max() for i in [0,1,2,3]]
# max_titer_df = df_all.loc[
#     df_all['Value'].isin(max_titer_vals),
#     :
# ]
# sns.lineplot(data = max_titer_df,
#                x = 'cycle',
#                y = 'Value',
#                ax = ax)
control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axhline(control_mean_all, c='k', linestyle = '--')
fig.savefig('all_isoprenol_comparison.png')

# %% [markdown]
# ## Look at single targets compared to whole distribution

# %%
df_all
# Out:
#       Study ID                                         Study Name  Line ID  \
# 0       187352  CORRECTED: CRISPRi automation for enhanced iso...   187360
# 1       187352  CORRECTED: CRISPRi automation for enhanced iso...   187368
# 2       187352  CORRECTED: CRISPRi automation for enhanced iso...   187376
# 3       187352  CORRECTED: CRISPRi automation for enhanced iso...   187408
# 4       187352  CORRECTED: CRISPRi automation for enhanced iso...   187416
# ...        ...                                                ...      ...
# 1516    219427  CRISPRi automation for enhanced isoprenol prod...   219576
# 1517    219427  CRISPRi automation for enhanced isoprenol prod...   219571
# 1518    219427  CRISPRi automation for enhanced isoprenol prod...   219465
# 1519    219427  CRISPRi automation for enhanced isoprenol prod...   219473
# 1520    219427  CRISPRi automation for enhanced isoprenol prod...   219457
#
#                              Replicate Key  \
# 0     3475b66f-023e-4334-a86d-374b4094f346
# 1     0445a7bc-3aaf-401a-a0c4-e77922997140
# 2     086e7c52-b5ac-42ca-81d1-e170b23b37fc
# 3     8d8b104b-b36a-4c30-b5d9-1449e73fb218
# 4     63f68f0d-d4a8-4b64-b1ba-8412da15aecb
# ...                                    ...
# 1516  e0758715-6e77-45bd-a030-69fd91db5c0b
# 1517  860e403e-7b5f-49f6-b145-2bf7d899aa52
# 1518  bd9cae9b-c6eb-4e93-926b-56875cbcc727
# 1519  b7d03b6c-bc52-4a90-a8a2-9296d8d6bb2a
# 1520  016cda7f-91fe-46ad-aec9-6039aeb63d48
#
#                                Line Name Line Description Protocol  Assay ID  \
# 0                             Control-R1         BL1A1_NT   GC-FID    188815
# 1                             Control-R2         BL1B1_NT   GC-FID    188823
# 2                             Control-R3         BL1C1_NT   GC-FID    188831
# 3                             Control-R4         BL2A1_NT   GC-FID    188863
# 4                             Control-R5         BL2B1_NT   GC-FID    188871
# ...                                  ...              ...      ...       ...
# 1516  PP_0368_PP_0751_PP_0815_PP_1506-R1     DBTL6_P4_005   GC-FID    219792
# 1517                       Control_P3-R3     DBTL6_P3_048   GC-FID    219793
# 1518          PP_0815_PP_1506_PP_4120-R2     DBTL6_P1_038   GC-FID    219794
# 1519          PP_0815_PP_1506_PP_4120-R3     DBTL6_P1_046   GC-FID    219795
# 1520          PP_0815_PP_1506_PP_4120-R1     DBTL6_P1_030   GC-FID    219796
#
#                               Assay Name Formal Type       Measurement Type  \
# 0                             Control-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1                             Control-R2   cid:12988  3-METHYL-3-BUTEN-1-OL
# 2                             Control-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 3                             Control-R4   cid:12988  3-METHYL-3-BUTEN-1-OL
# 4                             Control-R5   cid:12988  3-METHYL-3-BUTEN-1-OL
# ...                                  ...         ...                    ...
# 1516  PP_0368_PP_0751_PP_0815_PP_1506-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1517                       Control_P3-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1518          PP_0815_PP_1506_PP_4120-R2   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1519          PP_0815_PP_1506_PP_4120-R3   cid:12988  3-METHYL-3-BUTEN-1-OL
# 1520          PP_0815_PP_1506_PP_4120-R1   cid:12988  3-METHYL-3-BUTEN-1-OL
#
#       Compartment Units      Value  Hours  cycle  is_control
# 0               0  mg/L  177.33700   24.0      0        True
# 1               0  mg/L  181.88373   24.0      0        True
# 2               0  mg/L  169.40580   24.0      0        True
# 3               0  mg/L  161.67620   24.0      0        True
# 4               0  mg/L  136.42987   24.0      0        True
# ...           ...   ...        ...    ...    ...         ...
# 1516            0  mg/L  138.55210   48.0      6       False
# 1517            0  mg/L  132.53390   48.0      6        True
# 1518            0  mg/L   77.85280   48.0      6       False
# 1519            0  mg/L   77.30950   48.0      6       False
# 1520            0  mg/L   74.09180   48.0      6       False
#
# [1521 rows x 17 columns]

# %%
def make_target_compare_df(df, target, column_to_add = None):
    df_target = df.copy()
    if column_to_add is None:
        column_to_add = f'contains_{target}'
    df_target[column_to_add] = df_target['Line Name'].apply(
        lambda x: target in x
    )
    return df_target

# %%
target = 'PP_0812'
df_target = make_target_compare_df(df_all, target)
sns.boxplot(df_target, x = 'Value', hue = f'contains_{target}')
# Out:
# <Axes: xlabel='Value'>

# %%
targets = ['PP_0812', 'PP_0813', 'PP_0814', 'PP_0815', 'PP_1317', 'PP_0368', 'PP_0751']
fig, ax = plt.subplots(3,3,figsize = (10,10))
for i, t in enumerate(targets):
    a = fig.get_axes()[i]
    df_target = make_target_compare_df(df_all[df_all.cycle.isin([3,4,5])], t, 'Has Target')
    ax_title = f"{t} - N = {df_target['Has Target'].sum()}/{len(df_target)}"
    if i > 0:
        sns.violinplot(df_target, x = 'Value', hue = f'Has Target', ax = a, legend = None, cut = 0)
    else:
        sns.violinplot(df_target, x = 'Value', hue = f'Has Target', ax = a, cut = 0)

        
    a.set_title(ax_title)
    a.set_xlabel('')

# %%
top_N = 30
top_N_line_name_strings = df_all[df_all['cycle'].isin([3,4,5])].sort_values('Value', ascending = False).head(30)['Line Name'].values
print(top_N_line_name_strings)
top_N_targets = []
for s in top_N_line_name_strings:
    s = s[:-2]
    split_str = s.split('PP_')
    for substring in split_str[1:]:
        top_N_targets.append('PP_' + substring[:-1])
        
top_N_targets = list(set(top_N_targets))
# Out:
# ['PP_0368_PP_0751_PP_0815-R1' 'PP_0368_PP_0812_PP_0815-R1'
#  'PP_0368_PP_0814_PP_0815-R3' 'PP_0368_PP_0814_PP_0815-R2'
#  'PP_0368_PP_0751_PP_0815-R2' 'PP_0368_PP_0751_PP_0812_PP_0815-R1'
#  'PP_0368_PP_0812_PP_0815-R3' 'PP_0368_PP_0812_PP_0815-R2'
#  'PP_0812_PP_0813_PP_0815-R1' 'PP_0368_PP_0814_PP_0815-R1'
#  'PP_0751_PP_0815-R2' 'PP_0368_PP_0751_PP_0812_PP_0815-R2'
#  'PP_0814_PP_0815-R1' 'PP_0368_PP_0751_PP_0815-R3'
#  'PP_0528_PP_0812_PP_0815-R2' 'PP_0812_PP_0813_PP_0815-R3'
#  'PP_0528_PP_0812_PP_0815-R3' 'PP_0812_PP_0813_PP_0815-R2'
#  'PP_0751_PP_0815-R3' 'PP_0368_PP_0812_PP_0813_PP_0815-R1'
#  'PP_0814_PP_0815-R3' 'PP_0368_PP_0751_PP_0812_PP_0815-R3'
#  'PP_0813_PP_0814_PP_0815-R2' 'PP_0437_PP_0815_PP_1317-R3'
#  'PP_0751_PP_0815-R1' 'PP_0813_PP_0814_PP_0815-R3'
#  'PP_0528_PP_0812_PP_0815-R1' 'PP_0815_PP_2136-R1'
#  'PP_0813_PP_0814_PP_0815-R1' 'PP_0368_PP_0815-R1']

# %%
fig, ax = plt.subplots(3,4,figsize = (12,10), sharex = True)
for i, t in enumerate(top_N_targets):
    a = fig.get_axes()[i]
    df_target = make_target_compare_df(df_all[df_all.cycle.isin([3,4,5])], t, 'Has Target')
    ax_title = f"{t} - N = {df_target['Has Target'].sum()}/{len(df_target)}"
    if i > 0:
        sns.violinplot(df_target, x = 'Value', hue = f'Has Target', ax = a, legend = None, cut = 0, palette = ['gray', 'white'])
    else:
        sns.violinplot(df_target, x = 'Value', hue = f'Has Target', ax = a, cut = 0, palette = ['gray', 'white'])

        
    a.set_title(ax_title)
    a.set_xlabel('')
fig.suptitle(f'Titer distributions for strains in the top {top_N} titers')
fig.tight_layout()

# %%
fig, ax = plt.subplots(3,4,figsize = (12,10))
for i, t in enumerate(top_N_targets):
    a = fig.get_axes()[i]
    df_target = make_target_compare_df(df_all[df_all.cycle.isin([3,4,5])], t, 'Has Target')
    ax_title = f"{t} - N = {df_target['Has Target'].sum()}/{len(df_target)}"
    if i > 0:
        sns.boxplot(df_target, x = 'Value', hue = f'Has Target', ax = a, legend = None)
    else:
        sns.boxplot(df_target, x = 'Value', hue = f'Has Target', ax = a)

        
    a.set_title(ax_title)
    a.set_xlabel('')
fig.tight_layout()

# %%
top_N_targets
# Out:
# ['PP_0812',
#  'PP_0437',
#  'PP_0814',
#  'PP_0528',
#  'PP_0813',
#  'PP_0368',
#  'PP_1317',
#  'PP_0815',
#  'PP_2136',
#  'PP_0751']

# %%
df_all[df_all['Assay Name'] == 'PP_0815_PP_1317-R1']
# Out:
#      Study ID                                         Study Name  Line ID  \
# 553    188814  CRISPRi automation for enhanced isoprenol prod...   189646
# 771    194881  CRISPRi automation for enhanced isoprenol prod...   195056
# 957    209320  CRISPRi automation for enhanced isoprenol prod...   209489
#
#                             Replicate Key           Line Name  \
# 553  d11f1c0c-a97a-4443-8bbd-3b8ab54ded01  PP_0815_PP_1317-R1
# 771  b6b84262-10bc-4ba1-9a90-68c9db636365  PP_0815_PP_1317-R1
# 957  5f78a0fd-151d-4696-86f8-c384a122f3f3  PP_0815_PP_1317-R1
#
#     Line Description Protocol  Assay ID          Assay Name Formal Type  \
# 553     DBTL1_P4_005   GC-FID    189838  PP_0815_PP_1317-R1   cid:12988
# 771     DBTL2_P4_031   GC-FID    195250  PP_0815_PP_1317-R1   cid:12988
# 957     DBTL3_P4_025   GC-FID    209855  PP_0815_PP_1317-R1   cid:12988
#
#           Measurement Type  Compartment Units     Value  Hours  cycle  \
# 553  3-METHYL-3-BUTEN-1-OL            0  mg/L  453.2418   24.0      1
# 771  3-METHYL-3-BUTEN-1-OL            0  mg/L  460.8757   48.0      2
# 957  3-METHYL-3-BUTEN-1-OL            0  mg/L  402.1249   48.0      3
#
#      is_control
# 553       False
# 771       False
# 957       False

# %%
sns.color_palette('flare', as_cmap=True)

# %%
sns.color_palette('flare', n_colors=7)
# Out:
# [(0.9173814, 0.56750099, 0.4298371),
#  (0.89737819, 0.44322747, 0.37043052),
#  (0.8513284, 0.32604977, 0.36620106),
#  (0.75861834, 0.25356035, 0.40663694),
#  (0.64061624, 0.22016818, 0.43446845),
#  (0.52386353, 0.18939409, 0.44182449),
#  (0.40504765, 0.16574261, 0.42072062)]

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],
               y = 'cycle',
               x = 'Value',
               cut = 0,
               palette= sns.color_palette('flare', n_colors = 7),
               orient = 'h',
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axvline(control_mean_all, c='k', linestyle = '--')
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('DBTL Cycle')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.pdf')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.png')
# Out:
# /tmp/ipykernel_175/3878540083.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (~df_all['is_control'])),:],
# Text(0, 0.5, 'DBTL Cycle')

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (df_all['is_control'])),:],
               y = 'cycle',
               x = 'Value',
               cut = 0,
               palette= sns.color_palette('flare'),
               orient = 'h',
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axvline(control_mean_all, c='k', linestyle = '--')
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('DBTL Cycle')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.pdf')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.png')
# Out:
# /tmp/ipykernel_175/3578062747.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (df_all['is_control'])),:],
# /tmp/ipykernel_175/3578062747.py:2: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6]) & (df_all['is_control'])),:],
# Text(0, 0.5, 'DBTL Cycle')

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.violinplot(data = df_all.loc[(df_all['cycle'].isin([0,1,2,3,4, 5, 6])),:],
               y = 'cycle',
               x = 'Value',
               hue = 'is_control',
               cut = 0,
               # palette= sns.color_palette('flare'),
               orient = 'h',
               ax = ax
              )

control_mean_all = df_all.loc[df_all['is_control'], 'Value'].values.mean()
ax.axvline(control_mean_all, c='k', linestyle = '--')
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('DBTL Cycle')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.pdf')
# fig.savefig('dbtl0_1_2_3_4_5_violin_compare_horiz.png')
# Out:
# Text(0, 0.5, 'DBTL Cycle')

# %%
# df_all2

# %%
df_all['line_name_norep'] = df_all['Line Name'].apply(lambda x: x.split('-')[0])
df_all['line_name_cycle'] = df_all.apply(lambda x: f'{x["line_name_norep"]}_c{x["cycle"]}', axis = 1)
df_all['line_name_norep'].unique()
# Out:
# array(['Control', 'PP_0001', 'PP_0103', 'PP_0104', 'PP_0105', 'PP_0106',
#        'PP_0168', 'PP_0225', 'PP_0226', 'PP_0277', 'PP_0338', 'PP_0362',
#        'PP_0368', 'PP_0437', 'PP_0528', 'PP_0548', 'PP_0582', 'PP_0597',
#        'PP_0654', 'PP_0658', 'PP_0691', 'PP_0751', 'PP_0774', 'PP_0806',
#        'PP_0812', 'PP_0813', 'PP_0814', 'PP_0815', 'PP_0897', 'PP_0944',
],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize = (6,12))
sns.barplot(
    data = df_all[df_all['cycle'] == 6].sort_values('Value'),
    x = 'Value',
    y = 'line_name_cycle',
)
ax.set_title('All strains from cycle 6')
# Out:
# Text(0.5, 1.0, 'All strains from cycle 6')

# %%
agg_df = df_all.loc[:, ['line_name_cycle', 'Value']].groupby('line_name_cycle').agg(['mean', 'std']).sort_values(('Value', 'mean'))
agg_df.columns = agg_df.columns.droplevel()
agg_df = agg_df.reset_index()
agg_df
# Out:
#                         line_name_cycle        mean        std
# 0                            PP_1777_c0    0.000000   0.000000
# 1                            PP_3394_c0    0.000000   0.000000
# 2            PP_0751_PP_0812_PP_0815_c5    7.276867   1.819871
# 3                            PP_5064_c0   10.566533  18.301773
# 4                    PP_4120_PP_4189_c4   21.560467   4.487704
# ..                                  ...         ...        ...
# 494          PP_0368_PP_0751_PP_0815_c5  681.449667  37.582444
# 495  PP_0528_PP_0751_PP_0813_PP_0815_c6  719.633067   4.911731
# 496  PP_0528_PP_0751_PP_0812_PP_0815_c6  739.107700  29.407101
# 497          PP_0528_PP_0751_PP_0815_c6  743.629433   6.478223
# 498          PP_0751_PP_0813_PP_0815_c6  771.157433  48.684445
#
# [499 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize = (6,6))
lines_to_plot = agg_df.sort_values('mean', ascending = False).head(10)['line_name_cycle']
bp = sns.barplot(
    data = df_all[df_all['line_name_cycle'].isin(lines_to_plot)].sort_values('Value', ascending = False),
    x = 'Value',
    y = 'line_name_cycle',
    hue = 'cycle',
    dodge = False,
    width = 0.9,
    palette = 'plasma'
)
ax.set_title(f'Top {len(bp.get_yticklabels())} strains sorted by titer')
ax.axvline(control_mean_all, c = 'k', linestyle = '--')
ax.axvline(800, c = 'k')
ax.set_xlim([0, 1000])
sns.move_legend(ax, "upper right")
ax.set_xlabel('Isoprenol Titer (mg/L)')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Compare controls

# %%
control_df = df_all[df_all['is_control']].copy().loc[:,['Line Name', 'Assay Name', 'Value', 'cycle', 'is_control']].reset_index(drop=True)

# %%
control_df
# Out:
#         Line Name     Assay Name      Value  cycle  is_control
# 0      Control-R1     Control-R1  177.33700      0        True
# 1      Control-R2     Control-R2  181.88373      0        True
# 2      Control-R3     Control-R3  169.40580      0        True
# 3      Control-R4     Control-R4  161.67620      0        True
# 4      Control-R5     Control-R5  136.42987      0        True
# ..            ...            ...        ...    ...         ...
# 85  Control_P4-R2  Control_P4-R2  152.74660      6        True
# 86  Control_P3-R1  Control_P3-R1  152.38440      6        True
# 87  Control_P1-R2  Control_P1-R2  151.67210      6        True
# 88  Control_P4-R3  Control_P4-R3  151.42520      6        True
# 89  Control_P3-R3  Control_P3-R3  132.53390      6        True
#
# [90 rows x 5 columns]

# %%
sns.barplot(control_df,
            x = 'cycle',
            y = 'Value',
           errorbar = 'sd')
# Out:
# <Axes: xlabel='cycle', ylabel='Value'>

# %%
control_df.loc[
    (control_df['is_control']) & (control_df['cycle']>0),
    'control_plate'
] = control_df.loc[
    control_df['is_control'],
    'Line Name'].apply(lambda x: int(x[9])).astype(int)

# %%
cycle0_plate_list = pd.read_excel('../DBTL0_data/sample injection order.xlsx')
plate_dict = dict(zip(cycle0_plate_list['Sample Name in order injected'], cycle0_plate_list['Batch number']))
control_df.loc[control_df['cycle']==0,'control_plate'] = control_df.loc[control_df['cycle']==0,'Line Name'].apply(lambda x: plate_dict[x])
control_df['control_plate'] = control_df['control_plate'].astype(int)

# %%
control_df[control_df['cycle'] == 0]
# Out:
#       Line Name   Assay Name      Value  cycle  is_control  control_plate
# 0    Control-R1   Control-R1  177.33700      0        True              1
# 1    Control-R2   Control-R2  181.88373      0        True              1
# 2    Control-R3   Control-R3  169.40580      0        True              1
# 3    Control-R4   Control-R4  161.67620      0        True              1
# 4    Control-R5   Control-R5  136.42987      0        True              1
# 5    Control-R6   Control-R6  162.31847      0        True              1
# 6    Control-R7   Control-R7  162.12527      0        True              1
# 7    Control-R8   Control-R8  165.52560      0        True              2
# 8    Control-R9   Control-R9  165.55333      0        True              2
# 9   Control-R10  Control-R10  176.13507      0        True              2
# 10  Control-R11  Control-R11  192.63713      0        True              2
# 11  Control-R12  Control-R12  202.70480      0        True              2
# 12  Control-R13  Control-R13  123.84653      0        True              2
# 13  Control-R14  Control-R14  177.18560      0        True              2
# 14  Control-R15  Control-R15  168.02720      0        True              3
# 15  Control-R16  Control-R16  150.89067      0        True              3
# 16  Control-R17  Control-R17  197.79113      0        True              3
# 17  Control-R18  Control-R18  184.31093      0        True              3

# %%
fig, ax = plt.subplots(1,2)
sns.swarmplot(data = control_df.loc[(control_df['is_control']) & (control_df['cycle'] >= 0 ),:],   x = 'cycle', y = 'Value', hue = 'control_plate', ax = ax[0], legend = False)
sns.stripplot(data = control_df.loc[(control_df['is_control']) & (control_df['cycle'] >=0 ),:],   x = 'cycle', y = 'Value', hue = 'control_plate', ax = ax[1])
ax[1].set_ylim([0, 750])
ax[1].set_ylabel('')
# Out:
# Text(313.26767676767673, 0.5, '')

# %%
cycle_list = []
plate_list = []

for c in control_df.cycle.unique():
    for p in control_df.loc[control_df['cycle'] == c, 'control_plate'].unique():
        cycle_list.append(c)
        plate_list.append(p)
pctcv_df = pd.DataFrame.from_dict({'cycle':cycle_list, 'plate':plate_list})
pctcv_df
# Out:
#     cycle  plate
# 0       0      1
# 1       0      2
# 2       0      3
# 3       1      1
# 4       1      2
# 5       1      3
# 6       1      4
# 7       2      1
# 8       2      2
# 9       2      3
# 10      2      4
# 11      3      1
# 12      3      2
# 13      3      3
# 14      3      4
# 15      4      1
# 16      4      2
# 17      4      3
# 18      4      4
# 19      5      1
# 20      5      2
# 21      5      3
# 22      5      4
# 23      6      2
# 24      6      1
# 25      6      3
# 26      6      4

# %%
for idx, srs in pctcv_df.iterrows():
    pctcv_df.loc[idx, 'mean'] = control_df.loc[(control_df['is_control']) & (control_df['cycle'] == srs['cycle']) & (control_df['control_plate']==srs['plate']), 'Value'].mean()
    pctcv_df.loc[idx, 'std'] = control_df.loc[(control_df['is_control']) & (control_df['cycle'] == srs['cycle']) & (control_df['control_plate']==srs['plate']), 'Value'].std()
    
pctcv_df['pctcv'] =100* pctcv_df['std']/pctcv_df['mean']

# %%
pctcv_df
# Out:
#     cycle  plate        mean        std      pctcv
# 0       0      1  164.453763  14.704529   8.941437
# 1       0      2  171.941151  25.215323  14.665089
# 2       0      3  175.254983  20.295720  11.580680
# 3       1      1  159.815900   4.770185   2.984800
# 4       1      2  145.336167   0.992141   0.682653
# 5       1      3  150.547033   3.035781   2.016500
# 6       1      4  161.910367  16.266703  10.046734
# 7       2      1  156.108667  24.919387  15.962846
# 8       2      2  142.357633   3.679049   2.584371
# 9       2      3  169.956133   6.794727   3.997930
# 10      2      4  158.510933   9.805201   6.185820
# 11      3      1  170.323833  10.208591   5.993636
# 12      3      2  174.976200   9.521889   5.441819
# 13      3      3  185.291267   2.902189   1.566285
# 14      3      4  144.734367   2.695187   1.862161
# 15      4      1  156.939833   5.968796   3.803239
# 16      4      2  151.247567   8.314894   5.497539
# 17      4      3  153.758633   8.202361   5.334569
# 18      4      4  149.475033   7.334144   4.906601
# 19      5      1  154.568400   2.770661   1.792514
# 20      5      2  165.962133   7.696305   4.637386
# 21      5      3  163.917033  13.505110   8.238991
# 22      5      4  167.632333   6.754043   4.029082
# 23      6      2  161.757733   5.538352   3.423856
# 24      6      1  158.479267   7.078823   4.466719
# 25      6      3  147.546367  13.272148   8.995239
# 26      6      4  152.994833   1.707338   1.115945

# %%
fig, ax = plt.subplots(figsize = (6,10))
control_df['plate_cycle'] = control_df.apply(lambda x: f"plate: {int(x['control_plate'])} cycle: {x['cycle']}", axis = 1)
control_df
p=sns.swarmplot(data = control_df,   y = 'plate_cycle', x = 'Value', hue = 'cycle', palette = 'tab10')

# p = sns.stripplot(x="method", y="distance", data=planets, size=4, color=".7")
# plt.xticks(rotation=45, ha="right")
# p.set(yscale='log')

# plot the mean line
sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x="Value",
            y="plate_cycle",
            data=control_df,
            showfliers=False,
            showbox=False,
            showcaps=False,
            ax=p
           )
# Out:
# <Axes: xlabel='Value', ylabel='plate_cycle'>

# %%
pctcv_df
sns.barplot(data = pctcv_df, x = 'cycle', hue = 'plate', y = 'pctcv')
# Out:
# <Axes: xlabel='cycle', ylabel='pctcv'>

# %%
pctcv_df = df_all.loc[df_all['is_control'], ['line_name_norep', 'Value', 'cycle']]
pctcv_df['line_name_norep'] = 'control'
pctcv_df['line_name_cycle'] = pctcv_df['cycle'].apply(lambda x: f'control_c{x}')
pctcv_df = pctcv_df[['line_name_cycle', 'Value']].groupby('line_name_cycle').agg(['mean', 'std'])
pctcv_df.columns = pctcv_df.columns.droplevel()
pctcv_df['pctcv'] = 100*pctcv_df['std']/pctcv_df['mean']

# %%
fig, ax = plt.subplots(figsize = (3,3))
sns.barplot(data = pctcv_df,
            y = 'line_name_cycle',
            x = 'pctcv')
# Out:
# <Axes: xlabel='pctcv', ylabel='line_name_cycle'>

# %%
f = {'A':['sum','mean'], 'B':['prod']}

# %%
f = ['max', 'mean']
df_c = df_all[['cycle', 'Value']].groupby('cycle').agg(['max', 'mean'])
df_c.columns = df_c.columns.droplevel()
df_c = df_c.reset_index().melt(id_vars='cycle')
fig, ax = plt.subplots()
sns.swarmplot(df_c, x = 'cycle', y = 'value', hue = 'variable', ax = ax)
ax.axhline(180, c = 'k', linestyle = '--', label = 'control mean')
ax.legend()
