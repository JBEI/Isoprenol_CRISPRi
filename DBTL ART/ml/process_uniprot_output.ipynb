# %% [markdown]
# # Process protein data from uniprot
# Previously used this tool https://www.uniprot.org/id-mapping to map the protein IDs returned from proteomics to PP_/4-letter codes. This script parses the output and saves a table to convert between formats.

# %%
import edd_utils as eddu
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re 
import random
random.seed(1)

# %% [markdown]
# Import uniprot results and dataframe with original protein labels

# %%
uniprot_df = pd.read_csv('./data/proteomics_id_translator.tsv', delimiter='\t')
edd_df = pd.read_csv('./data/protein_id_conversion_df_init.csv')

# %%
uniprot_df.head(3)
# Out:
#      From   Entry    Reviewed    Entry Name  \
# 0  P0AE22  P0AE22    reviewed    APHA_ECOLI
# 1  A9GAJ9  A9GAJ9  unreviewed  A9GAJ9_SORC5
# 2  J5JYK1  J5JYK1  unreviewed  J5JYK1_BEAB2
#
#                                   Protein names                   Gene Names  \
# 0  Class B acid phosphatase (CBAP) (EC 3.1.3.2)  aphA napA yjbP b4055 JW4015
# 1        Methylmalonyl-CoA mutase (EC 5.4.99.2)                  mcm sce2716
# 2                           Polyketide synthase                    BBA_03810
#
#                                             Organism  Length  \
# 0                      Escherichia coli (strain K12)   237.0
# 1  Sorangium cellulosum (strain So ce56) (Polyang...   882.0
# 2  Beauveria bassiana (strain ARSEF 2860) (White ...  2413.0
#
#   Gene Names (ordered locus) Gene Names (ORF) Gene Names (primary)  \
# 0               b4055 JW4015              NaN                 aphA
# 1                    sce2716              NaN                  mcm
# 2                        NaN        BBA_03810                  NaN
#
#   Gene Names (synonym)
# 0            napA yjbP
# 1                  NaN
# 2                  NaN

# %%
edd_df.head(3)
# Out:
#             orig  has_6letter_substring extracted
# 0         P0AE22                   True    P0AE22
# 1  sp|A0A0M4F6K2                  False       NaN
# 2  sp|A0A140FVW8                  False       NaN

# %% [markdown]
# Rename uniprot df columns

# %%
uniprot_col_rename = {'Entry Name': 'entry_name', 'Protein names': 'protein_names',
                      'Gene Names': 'gene_names', 'Gene Names (ordered locus)': 'locus_name',
                     'Gene Names (primary)': 'primary_name', 'Gene Names (synonym)': 'synonym_name'}
uniprot_df = uniprot_df.rename(columns=uniprot_col_rename)
uniprot_df
# Out:
#         From   Entry    Reviewed    entry_name  \
# 0     P0AE22  P0AE22    reviewed    APHA_ECOLI
# 1     A9GAJ9  A9GAJ9  unreviewed  A9GAJ9_SORC5
# 2     J5JYK1  J5JYK1  unreviewed  J5JYK1_BEAB2
# 3     K4JH65  K4JH65  unreviewed  K4JH65_9ACTN
# 4     O77727  O77727    reviewed   K1C15_SHEEP
# ...      ...     ...         ...           ...
# 2875  Q88QV2  Q88QV2  unreviewed  Q88QV2_PSEPK
# 2876  Q88RH1  Q88RH1  unreviewed  Q88RH1_PSEPK
# 2877  Q88RH2  Q88RH2  unreviewed  Q88RH2_PSEPK
# 2878  Q8PW39  Q8PW39  unreviewed  Q8PW39_METMA
# 2879  Q9FD70  Q9FD70  unreviewed  Q9FD70_ENTFL
#
#                                           protein_names  \
# 0          Class B acid phosphatase (CBAP) (EC 3.1.3.2)
# 1                Methylmalonyl-CoA mutase (EC 5.4.99.2)
# 2                                   Polyketide synthase
# 3                       3 hydroxyacyl CoA dehydrogenase
# 4     Keratin, type I cytoskeletal 15 (Cytokeratin-1...
# ...                                                 ...
# 2875                 5-aminopentanamidase (EC 3.5.1.30)
# 2876            CoA-transferase family III (EC 2.8.3.-)
# 2877      glutaryl-CoA dehydrogenase (ETF) (EC 1.3.8.6)
# 2878         Mevalonate kinase (MK) (MVK) (EC 2.7.1.36)
# 2879  Acetyl-CoA acetyltransferase (EC 2.3.1.9) (Ace...
#
#                        gene_names  \
# 0     aphA napA yjbP b4055 JW4015
# 1                     mcm sce2716
# 2                       BBA_03810
# 3                            gdnD
# 4                           KRT15
# ...                           ...
# 2875                 davA PP_0382
# 2876                      PP_0159
# 2877                 gcdH PP_0158
# 2878                  mvk MM_1762
# 2879                         mvaE
#
#                                                Organism  Length    locus_name  \
# 0                         Escherichia coli (strain K12)   237.0  b4055 JW4015
# 1     Sorangium cellulosum (strain So ce56) (Polyang...   882.0       sce2716
# 2     Beauveria bassiana (strain ARSEF 2860) (White ...  2413.0           NaN
# 3                             Streptomyces sp. K01-0509   289.0           NaN
# 4                                    Ovis aries (Sheep)   453.0           NaN
# ...                                                 ...     ...           ...
# 2875  Pseudomonas putida (strain ATCC 47054 / DSM 61...   264.0       PP_0382
# 2876  Pseudomonas putida (strain ATCC 47054 / DSM 61...   406.0       PP_0159
# 2877  Pseudomonas putida (strain ATCC 47054 / DSM 61...   393.0       PP_0158
# 2878  Methanosarcina mazei (strain ATCC BAA-159 / DS...   301.0       MM_1762
# 2879     Enterococcus faecalis (Streptococcus faecalis)   803.0           NaN
#
#      Gene Names (ORF) primary_name synonym_name
# 0                 NaN         aphA    napA yjbP
# 1                 NaN          mcm          NaN
# 2           BBA_03810          NaN          NaN
# 3                 NaN         gdnD          NaN
# 4                 NaN        KRT15          NaN
# ...               ...          ...          ...
# 2875              NaN         davA          NaN
# 2876              NaN          NaN          NaN
# 2877              NaN         gcdH          NaN
# 2878              NaN          mvk          NaN
# 2879              NaN         mvaE          NaN
#
# [2880 rows x 12 columns]

# %% [markdown]
# ## Look at uniprot output

# %%
uniprot_df['Organism'].value_counts()
# Out:
# Organism
# Pseudomonas putida (strain ATCC 47054 / DSM 6125 / CFBP 8728 / NCIMB 11950 / KT2440)                               2843
# Homo sapiens (Human)                                                                                                 11
# Ovis aries (Sheep)                                                                                                    3
# Enterococcus faecalis (Streptococcus faecalis)                                                                        2
# Enterococcus faecalis (strain ATCC 700802 / V583)                                                                     2
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c) (Baker's yeast)                                                 1
# Caulobacter vibrioides (strain ATCC 19089 / CIP 103742 / CB 15) (Caulobacter crescentus)                              1
# Streptococcus pyogenes serotype M1                                                                                    1
# Streptomyces nanchangensis                                                                                            1
# Mycolicibacterium smegmatis (strain ATCC 700084 / mc(2)155) (Mycobacterium smegmatis)                                 1
# Kitasatospora aureofaciens (Streptomyces aureofaciens)                                                                1
# Escherichia coli (strain K12)                                                                                         1
# Pseudomonas aeruginosa                                                                                                1
# Sorangium cellulosum (strain So ce56) (Polyangium cellulosum (strain So ce56))                                        1
# Sus scrofa (Pig)                                                                                                      1
# Gallus gallus (Chicken)                                                                                               1
# Klebsiella pneumoniae                                                                                                 1
# Hevea brasiliensis (Para rubber tree) (Siphonia brasiliensis)                                                         1
# Streptomyces sp. K01-0509                                                                                             1
# Beauveria bassiana (strain ARSEF 2860) (White muscardine disease fungus) (Tritirachium shiotae)                       1
# Methanosarcina mazei (strain ATCC BAA-159 / DSM 3647 / Goe1 / Go1 / JCM 11833 / OCM 88) (Methanosarcina frisia)       1
# Name: count, dtype: int64

# %% [markdown]
# Create flag for whether or not entry is from putida

# %%
pp_string = 'Pseudomonas putida (strain ATCC 47054 / DSM 6125 / CFBP 8728 / NCIMB 11950 / KT2440)'
uniprot_df['is_putida'] = uniprot_df['Organism'] == pp_string

# %%
uniprot_df.loc[~uniprot_df['is_putida'], :]
# Out:
#         From   Entry    Reviewed    entry_name  \
# 0     P0AE22  P0AE22    reviewed    APHA_ECOLI
# 1     A9GAJ9  A9GAJ9  unreviewed  A9GAJ9_SORC5
# 2     J5JYK1  J5JYK1  unreviewed  J5JYK1_BEAB2
# 3     K4JH65  K4JH65  unreviewed  K4JH65_9ACTN
# 4     O77727  O77727    reviewed   K1C15_SHEEP
# 5     O82803  O82803    reviewed    SRPP_HEVBR
# 7     P00552  P00552    reviewed    KKA2_KLEPN
# 8     P00698  P00698    reviewed    LYSC_CHICK
# 9     P00761  P00761    reviewed      TRYP_PIG
# 10    P02539  P02539    reviewed    K2M1_SHEEP
# 11    P02768  P02768    reviewed    ALBU_HUMAN
# 12    P04264  P04264    reviewed    K2C1_HUMAN
# 37    P13645  P13645    reviewed   K1C10_HUMAN
# 38    P23181  P23181    reviewed   AACC1_PSEAI
# 39    P25690  P25690    reviewed    K1M2_SHEEP
# 40    P32377  P32377    reviewed    MVD1_YEAST
# 41    P35527  P35527    reviewed    K1C9_HUMAN
# 42    P35908  P35908    reviewed    K22E_HUMAN
# 57    P61626  P61626    reviewed    LYSC_HUMAN
# 58    P63165  P63165    reviewed   SUMO1_HUMAN
# 60    P78386  P78386    reviewed   KRT85_HUMAN
# 61    Q15323  Q15323    reviewed    K1H1_HUMAN
# 62    Q30CS2  Q30CS2  unreviewed  Q30CS2_KITAU
# 63    Q3L885  Q3L885  unreviewed  Q3L885_MYCS2
# 65    Q7WTF4  Q7WTF4  unreviewed  Q7WTF4_9ACTN
# 66    Q835L4  Q835L4  unreviewed  Q835L4_ENTFA
# 1101  Q88H72  Q88H72         NaN  Q88H72_PSEPK
# 2137  Q88NG2  Q88NG2         NaN  Q88NG2_PSEPK
# 2282  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2854  Q99ZW2  Q99ZW2    reviewed    CAS9_STRP1
# 2855  Q9A9Z2  Q9A9Z2    reviewed    XYLD_CAUVC
# 2856  Q9FD71  Q9FD71    reviewed   HMGCS_ENTFL
# 2857  Q9NSB2  Q9NSB2    reviewed   KRT84_HUMAN
# 2858  Q9NSB4  Q9NSB4    reviewed   KRT82_HUMAN
# 2860  Q835L3  Q835L3  unreviewed  Q835L3_ENTFA
# 2878  Q8PW39  Q8PW39  unreviewed  Q8PW39_METMA
# 2879  Q9FD70  Q9FD70  unreviewed  Q9FD70_ENTFL
#
#                                           protein_names  \
# 0          Class B acid phosphatase (CBAP) (EC 3.1.3.2)
# 1                Methylmalonyl-CoA mutase (EC 5.4.99.2)
# 2                                   Polyketide synthase
# 3                       3 hydroxyacyl CoA dehydrogenase
# 4     Keratin, type I cytoskeletal 15 (Cytokeratin-1...
# 5     Small rubber particle protein (HbSRPP) (22 kDa...
# 7     Aminoglycoside 3'-phosphotransferase (EC 2.7.1...
# 8     Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...
# 9                                 Trypsin (EC 3.4.21.4)
# 10    Keratin, type II microfibrillar (Low-sulfur ke...
# 11                                              Albumin
# 12    Keratin, type II cytoskeletal 1 (67 kDa cytoke...
# 37    Keratin, type I cytoskeletal 10 (Cytokeratin-1...
# 38    Gentamicin 3-N-acetyltransferase (EC 2.3.1.60)...
# 39    Keratin, type I microfibrillar, 47.6 kDa (Low-...
# 40    Diphosphomevalonate decarboxylase (EC 4.1.1.33...
# 41    Keratin, type I cytoskeletal 9 (Cytokeratin-9)...
# 42    Keratin, type II cytoskeletal 2 epidermal (Cyt...
# 57    Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...
# 58    Small ubiquitin-related modifier 1 (SUMO-1) (G...
# 60    Keratin, type II cuticular Hb5 (Hair keratin K...
# 61    Keratin, type I cuticular Ha1 (Hair keratin, t...
# 62                                              LipPks1
# 63                                  Polyketide synthase
# 65                                                NanA2
# 66     Hydroxymethylglutaryl-CoA synthase (EC 2.3.3.10)
# 1101                                            deleted
# 2137                                            deleted
# 2282                                            deleted
# 2854  CRISPR-associated endonuclease Cas9/Csn1 (EC 3...
# 2855  D-xylonate dehydratase (XyDHT) (EC 4.2.1.82) (...
# 2856  Hydroxymethylglutaryl-CoA synthase (HMG-CoA sy...
# 2857  Keratin, type II cuticular Hb4 (Keratin-84) (K...
# 2858  Keratin, type II cuticular Hb2 (Keratin-82) (K...
# 2860  Acetyl-CoA acetyltransferase (EC 2.3.1.9) (Ace...
# 2878         Mevalonate kinase (MK) (MVK) (EC 2.7.1.36)
# 2879  Acetyl-CoA acetyltransferase (EC 2.3.1.9) (Ace...
#
#                                              gene_names  \
# 0                           aphA napA yjbP b4055 JW4015
# 1                                           mcm sce2716
# 2                                             BBA_03810
# 3                                                  gdnD
# 4                                                 KRT15
# 5                                            SRPP HEVB3
# 7                                         neo kan nptII
# 8                                                   LYZ
# 9                                                   NaN
# 10                                                  NaN
# 11    ALB GIG20 GIG42 PRO0903 PRO1708 PRO2044 PRO261...
# 12                                            KRT1 KRTA
# 37                                            KRT10 KPP
# 38                                                aacC1
# 39                                                  NaN
# 40                         MVD1 ERG19 MPD YNR043W N3427
# 41                                                 KRT9
# 42                                     KRT2 KRT2A KRT2E
# 57                                              LYZ LZM
# 58                  SUMO1 SMT3C SMT3H3 UBL1 OK/SW-cl.43
# 60                                         KRT85 KRTHB5
# 61                               KRT31 HHA1 HKA1 KRTHA1
# 62                                              lipPks1
# 63                                       pks MSMEG_0408
# 65                                                nanA2
# 66                                              EF_1363
# 1101                                                NaN
# 2137                                                NaN
# 2282                                                NaN
# 2854                                 cas9 csn1 SPy_1046
# 2855                                       xylD CC_0819
# 2856                                               mvaS
# 2857                                       KRT84 KRTHB4
# 2858                                       KRT82 KRTHB2
# 2860                                            EF_1364
# 2878                                        mvk MM_1762
# 2879                                               mvaE
#
#                                                Organism  Length    locus_name  \
# 0                         Escherichia coli (strain K12)   237.0  b4055 JW4015
# 1     Sorangium cellulosum (strain So ce56) (Polyang...   882.0       sce2716
# 2     Beauveria bassiana (strain ARSEF 2860) (White ...  2413.0           NaN
# 3                             Streptomyces sp. K01-0509   289.0           NaN
# 4                                    Ovis aries (Sheep)   453.0           NaN
# 5     Hevea brasiliensis (Para rubber tree) (Siphoni...   204.0           NaN
# 7                                 Klebsiella pneumoniae   264.0           NaN
# 8                               Gallus gallus (Chicken)   147.0           NaN
# 9                                      Sus scrofa (Pig)   231.0           NaN
# 10                                   Ovis aries (Sheep)   109.0           NaN
# 11                                 Homo sapiens (Human)   609.0           NaN
# 12                                 Homo sapiens (Human)   644.0           NaN
# 37                                 Homo sapiens (Human)   584.0           NaN
# 38                               Pseudomonas aeruginosa   177.0           NaN
# 39                                   Ovis aries (Sheep)   404.0           NaN
# 40    Saccharomyces cerevisiae (strain ATCC 204508 /...   396.0       YNR043W
# 41                                 Homo sapiens (Human)   623.0           NaN
# 42                                 Homo sapiens (Human)   639.0           NaN
# 57                                 Homo sapiens (Human)   148.0           NaN
# 58                                 Homo sapiens (Human)   101.0           NaN
# 60                                 Homo sapiens (Human)   507.0           NaN
# 61                                 Homo sapiens (Human)   416.0           NaN
# 62    Kitasatospora aureofaciens (Streptomyces aureo...  2259.0           NaN
# 63    Mycolicibacterium smegmatis (strain ATCC 70008...  3652.0    MSMEG_0408
# 65                           Streptomyces nanchangensis  2223.0           NaN
# 66    Enterococcus faecalis (strain ATCC 700802 / V583)   383.0       EF_1363
# 1101                                                NaN     NaN           NaN
# 2137                                                NaN     NaN           NaN
# 2282                                                NaN     NaN           NaN
# 2854                 Streptococcus pyogenes serotype M1  1368.0      SPy_1046
# 2855  Caulobacter vibrioides (strain ATCC 19089 / CI...   595.0       CC_0819
# 2856     Enterococcus faecalis (Streptococcus faecalis)   383.0           NaN
# 2857                               Homo sapiens (Human)   600.0           NaN
# 2858                               Homo sapiens (Human)   513.0           NaN
# 2860  Enterococcus faecalis (strain ATCC 700802 / V583)   803.0       EF_1364
# 2878  Methanosarcina mazei (strain ATCC BAA-159 / DS...   301.0       MM_1762
# 2879     Enterococcus faecalis (Streptococcus faecalis)   803.0           NaN
#
#                                        Gene Names (ORF) primary_name  \
# 0                                                   NaN         aphA
# 1                                                   NaN          mcm
# 2                                             BBA_03810          NaN
# 3                                                   NaN         gdnD
# 4                                                   NaN        KRT15
# 5                                                   NaN         SRPP
# 7                                                   NaN          neo
# 8                                                   NaN          LYZ
# 9                                                   NaN          NaN
# 10                                                  NaN          NaN
# 11    GIG20 GIG42 PRO0903 PRO1708 PRO2044 PRO2619 PR...          ALB
# 12                                                  NaN         KRT1
# 37                                                  NaN        KRT10
# 38                                                  NaN        aacC1
# 39                                                  NaN          NaN
# 40                                                N3427         MVD1
# 41                                                  NaN         KRT9
# 42                                                  NaN         KRT2
# 57                                                  NaN          LYZ
# 58                                          OK/SW-cl.43        SUMO1
# 60                                                  NaN        KRT85
# 61                                                  NaN        KRT31
# 62                                                  NaN      lipPks1
# 63                                                  NaN          pks
# 65                                                  NaN        nanA2
# 66                                                  NaN          NaN
# 1101                                                NaN          NaN
# 2137                                                NaN          NaN
# 2282                                                NaN          NaN
# 2854                                                NaN         cas9
# 2855                                                NaN         xylD
# 2856                                                NaN         mvaS
# 2857                                                NaN        KRT84
# 2858                                                NaN        KRT82
# 2860                                                NaN          NaN
# 2878                                                NaN          mvk
# 2879                                                NaN         mvaE
#
#            synonym_name  is_putida
# 0             napA yjbP      False
# 1                   NaN      False
# 2                   NaN      False
# 3                   NaN      False
# 4                   NaN      False
# 5                 HEVB3      False
# 7             kan nptII      False
# 8                   NaN      False
# 9                   NaN      False
# 10                  NaN      False
# 11                  NaN      False
# 12                 KRTA      False
# 37                  KPP      False
# 38                  NaN      False
# 39                  NaN      False
# 40            ERG19 MPD      False
# 41                  NaN      False
# 42          KRT2A KRT2E      False
# 57                  LZM      False
# 58    SMT3C SMT3H3 UBL1      False
# 60               KRTHB5      False
# 61     HHA1 HKA1 KRTHA1      False
# 62                  NaN      False
# 63                  NaN      False
# 65                  NaN      False
# 66                  NaN      False
# 1101                NaN      False
# 2137                NaN      False
# 2282                NaN      False
# 2854               csn1      False
# 2855                NaN      False
# 2856                NaN      False
# 2857             KRTHB4      False
# 2858             KRTHB2      False
# 2860                NaN      False
# 2878                NaN      False
# 2879                NaN      False

# %%
uniprot_df.loc[uniprot_df['is_putida'],:]
# Out:
#         From   Entry    Reviewed    entry_name  \
# 6     O85207  O85207    reviewed    PHAG_PSEPK
# 13    P0A0Z9  P0A0Z9    reviewed    ARGA_PSEPK
# 14    P0A101  P0A101    reviewed    PCAJ_PSEPK
# 15    P0A116  P0A116    reviewed    DNAA_PSEPK
# 16    P0A118  P0A118    reviewed    DNAG_PSEPK
# ...      ...     ...         ...           ...
# 2873  Q88PL6  Q88PL6  unreviewed  Q88PL6_PSEPK
# 2874  Q88QV1  Q88QV1  unreviewed  Q88QV1_PSEPK
# 2875  Q88QV2  Q88QV2  unreviewed  Q88QV2_PSEPK
# 2876  Q88RH1  Q88RH1  unreviewed  Q88RH1_PSEPK
# 2877  Q88RH2  Q88RH2  unreviewed  Q88RH2_PSEPK
#
#                                           protein_names    gene_names  \
# 6     (R)-3-hydroxydecanoyl-ACP:CoA transacylase (EC...  phaG PP_1408
# 13    Amino-acid acetyltransferase (EC 2.3.1.1) (N-a...  argA PP_5185
# 14    3-oxoadipate CoA-transferase subunit B (EC 2.8...  pcaJ PP_3952
# 15       Chromosomal replication initiator protein DnaA  dnaA PP_0010
# 16                           DNA primase (EC 2.7.7.101)  dnaG PP_0388
# ...                                                 ...           ...
# 2873      Sec translocon accessory complex subunit YajC  yajC PP_0834
# 2874          Tryptophan 2-monooxygenase (EC 1.13.12.3)  davB PP_0383
# 2875                 5-aminopentanamidase (EC 3.5.1.30)  davA PP_0382
# 2876            CoA-transferase family III (EC 2.8.3.-)       PP_0159
# 2877      glutaryl-CoA dehydrogenase (ETF) (EC 1.3.8.6)  gcdH PP_0158
#
#                                                Organism  Length locus_name  \
# 6     Pseudomonas putida (strain ATCC 47054 / DSM 61...   295.0    PP_1408
# 13    Pseudomonas putida (strain ATCC 47054 / DSM 61...   432.0    PP_5185
# 14    Pseudomonas putida (strain ATCC 47054 / DSM 61...   213.0    PP_3952
# 15    Pseudomonas putida (strain ATCC 47054 / DSM 61...   506.0    PP_0010
# 16    Pseudomonas putida (strain ATCC 47054 / DSM 61...   660.0    PP_0388
# ...                                                 ...     ...        ...
# 2873  Pseudomonas putida (strain ATCC 47054 / DSM 61...   111.0    PP_0834
# 2874  Pseudomonas putida (strain ATCC 47054 / DSM 61...   560.0    PP_0383
# 2875  Pseudomonas putida (strain ATCC 47054 / DSM 61...   264.0    PP_0382
# 2876  Pseudomonas putida (strain ATCC 47054 / DSM 61...   406.0    PP_0159
# 2877  Pseudomonas putida (strain ATCC 47054 / DSM 61...   393.0    PP_0158
#
#      Gene Names (ORF) primary_name synonym_name  is_putida
# 6                 NaN         phaG          NaN       True
# 13                NaN         argA          NaN       True
# 14                NaN         pcaJ          NaN       True
# 15                NaN         dnaA          NaN       True
# 16                NaN         dnaG          NaN       True
# ...               ...          ...          ...        ...
# 2873              NaN         yajC          NaN       True
# 2874              NaN         davB          NaN       True
# 2875              NaN         davA          NaN       True
# 2876              NaN          NaN          NaN       True
# 2877              NaN         gcdH          NaN       True
#
# [2843 rows x 13 columns]

# %% [markdown]
# ## Count how many genes have locus names or primary gene names

# %%
print(f"For p-putida proteins, there are N = {sum(uniprot_df.loc[uniprot_df['is_putida'], 'locus_name'].isna())} rows where locus_name is NaN")
print(f"There are N = {sum(uniprot_df['locus_name'].isna())} rows where locus_name is NaN")
uniprot_df.loc[uniprot_df['locus_name'].isna()]
# Out:
# For p-putida proteins, there are N = 0 rows where locus_name is NaN
# There are N = 28 rows where locus_name is NaN
#         From   Entry    Reviewed    entry_name  \
# 2     J5JYK1  J5JYK1  unreviewed  J5JYK1_BEAB2
# 3     K4JH65  K4JH65  unreviewed  K4JH65_9ACTN
# 4     O77727  O77727    reviewed   K1C15_SHEEP
# 5     O82803  O82803    reviewed    SRPP_HEVBR
# 7     P00552  P00552    reviewed    KKA2_KLEPN
# 8     P00698  P00698    reviewed    LYSC_CHICK
# 9     P00761  P00761    reviewed      TRYP_PIG
# 10    P02539  P02539    reviewed    K2M1_SHEEP
# 11    P02768  P02768    reviewed    ALBU_HUMAN
# 12    P04264  P04264    reviewed    K2C1_HUMAN
# 37    P13645  P13645    reviewed   K1C10_HUMAN
# 38    P23181  P23181    reviewed   AACC1_PSEAI
# 39    P25690  P25690    reviewed    K1M2_SHEEP
# 41    P35527  P35527    reviewed    K1C9_HUMAN
# 42    P35908  P35908    reviewed    K22E_HUMAN
# 57    P61626  P61626    reviewed    LYSC_HUMAN
# 58    P63165  P63165    reviewed   SUMO1_HUMAN
# 60    P78386  P78386    reviewed   KRT85_HUMAN
# 61    Q15323  Q15323    reviewed    K1H1_HUMAN
# 62    Q30CS2  Q30CS2  unreviewed  Q30CS2_KITAU
# 65    Q7WTF4  Q7WTF4  unreviewed  Q7WTF4_9ACTN
# 1101  Q88H72  Q88H72         NaN  Q88H72_PSEPK
# 2137  Q88NG2  Q88NG2         NaN  Q88NG2_PSEPK
# 2282  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2856  Q9FD71  Q9FD71    reviewed   HMGCS_ENTFL
# 2857  Q9NSB2  Q9NSB2    reviewed   KRT84_HUMAN
# 2858  Q9NSB4  Q9NSB4    reviewed   KRT82_HUMAN
# 2879  Q9FD70  Q9FD70  unreviewed  Q9FD70_ENTFL
#
#                                           protein_names  \
# 2                                   Polyketide synthase
# 3                       3 hydroxyacyl CoA dehydrogenase
# 4     Keratin, type I cytoskeletal 15 (Cytokeratin-1...
# 5     Small rubber particle protein (HbSRPP) (22 kDa...
# 7     Aminoglycoside 3'-phosphotransferase (EC 2.7.1...
# 8     Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...
# 9                                 Trypsin (EC 3.4.21.4)
# 10    Keratin, type II microfibrillar (Low-sulfur ke...
# 11                                              Albumin
# 12    Keratin, type II cytoskeletal 1 (67 kDa cytoke...
# 37    Keratin, type I cytoskeletal 10 (Cytokeratin-1...
# 38    Gentamicin 3-N-acetyltransferase (EC 2.3.1.60)...
# 39    Keratin, type I microfibrillar, 47.6 kDa (Low-...
# 41    Keratin, type I cytoskeletal 9 (Cytokeratin-9)...
# 42    Keratin, type II cytoskeletal 2 epidermal (Cyt...
# 57    Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...
# 58    Small ubiquitin-related modifier 1 (SUMO-1) (G...
# 60    Keratin, type II cuticular Hb5 (Hair keratin K...
# 61    Keratin, type I cuticular Ha1 (Hair keratin, t...
# 62                                              LipPks1
# 65                                                NanA2
# 1101                                            deleted
# 2137                                            deleted
# 2282                                            deleted
# 2856  Hydroxymethylglutaryl-CoA synthase (HMG-CoA sy...
# 2857  Keratin, type II cuticular Hb4 (Keratin-84) (K...
# 2858  Keratin, type II cuticular Hb2 (Keratin-82) (K...
# 2879  Acetyl-CoA acetyltransferase (EC 2.3.1.9) (Ace...
#
#                                              gene_names  \
# 2                                             BBA_03810
# 3                                                  gdnD
# 4                                                 KRT15
# 5                                            SRPP HEVB3
# 7                                         neo kan nptII
# 8                                                   LYZ
# 9                                                   NaN
# 10                                                  NaN
# 11    ALB GIG20 GIG42 PRO0903 PRO1708 PRO2044 PRO261...
# 12                                            KRT1 KRTA
# 37                                            KRT10 KPP
# 38                                                aacC1
# 39                                                  NaN
# 41                                                 KRT9
# 42                                     KRT2 KRT2A KRT2E
# 57                                              LYZ LZM
# 58                  SUMO1 SMT3C SMT3H3 UBL1 OK/SW-cl.43
# 60                                         KRT85 KRTHB5
# 61                               KRT31 HHA1 HKA1 KRTHA1
# 62                                              lipPks1
# 65                                                nanA2
# 1101                                                NaN
# 2137                                                NaN
# 2282                                                NaN
# 2856                                               mvaS
# 2857                                       KRT84 KRTHB4
# 2858                                       KRT82 KRTHB2
# 2879                                               mvaE
#
#                                                Organism  Length locus_name  \
# 2     Beauveria bassiana (strain ARSEF 2860) (White ...  2413.0        NaN
# 3                             Streptomyces sp. K01-0509   289.0        NaN
# 4                                    Ovis aries (Sheep)   453.0        NaN
# 5     Hevea brasiliensis (Para rubber tree) (Siphoni...   204.0        NaN
# 7                                 Klebsiella pneumoniae   264.0        NaN
# 8                               Gallus gallus (Chicken)   147.0        NaN
# 9                                      Sus scrofa (Pig)   231.0        NaN
# 10                                   Ovis aries (Sheep)   109.0        NaN
# 11                                 Homo sapiens (Human)   609.0        NaN
# 12                                 Homo sapiens (Human)   644.0        NaN
# 37                                 Homo sapiens (Human)   584.0        NaN
# 38                               Pseudomonas aeruginosa   177.0        NaN
# 39                                   Ovis aries (Sheep)   404.0        NaN
# 41                                 Homo sapiens (Human)   623.0        NaN
# 42                                 Homo sapiens (Human)   639.0        NaN
# 57                                 Homo sapiens (Human)   148.0        NaN
# 58                                 Homo sapiens (Human)   101.0        NaN
# 60                                 Homo sapiens (Human)   507.0        NaN
# 61                                 Homo sapiens (Human)   416.0        NaN
# 62    Kitasatospora aureofaciens (Streptomyces aureo...  2259.0        NaN
# 65                           Streptomyces nanchangensis  2223.0        NaN
# 1101                                                NaN     NaN        NaN
# 2137                                                NaN     NaN        NaN
# 2282                                                NaN     NaN        NaN
# 2856     Enterococcus faecalis (Streptococcus faecalis)   383.0        NaN
# 2857                               Homo sapiens (Human)   600.0        NaN
# 2858                               Homo sapiens (Human)   513.0        NaN
# 2879     Enterococcus faecalis (Streptococcus faecalis)   803.0        NaN
#
#                                        Gene Names (ORF) primary_name  \
# 2                                             BBA_03810          NaN
# 3                                                   NaN         gdnD
# 4                                                   NaN        KRT15
# 5                                                   NaN         SRPP
# 7                                                   NaN          neo
# 8                                                   NaN          LYZ
# 9                                                   NaN          NaN
# 10                                                  NaN          NaN
# 11    GIG20 GIG42 PRO0903 PRO1708 PRO2044 PRO2619 PR...          ALB
# 12                                                  NaN         KRT1
# 37                                                  NaN        KRT10
# 38                                                  NaN        aacC1
# 39                                                  NaN          NaN
# 41                                                  NaN         KRT9
# 42                                                  NaN         KRT2
# 57                                                  NaN          LYZ
# 58                                          OK/SW-cl.43        SUMO1
# 60                                                  NaN        KRT85
# 61                                                  NaN        KRT31
# 62                                                  NaN      lipPks1
# 65                                                  NaN        nanA2
# 1101                                                NaN          NaN
# 2137                                                NaN          NaN
# 2282                                                NaN          NaN
# 2856                                                NaN         mvaS
# 2857                                                NaN        KRT84
# 2858                                                NaN        KRT82
# 2879                                                NaN         mvaE
#
#            synonym_name  is_putida
# 2                   NaN      False
# 3                   NaN      False
# 4                   NaN      False
# 5                 HEVB3      False
# 7             kan nptII      False
# 8                   NaN      False
# 9                   NaN      False
# 10                  NaN      False
# 11                  NaN      False
# 12                 KRTA      False
# 37                  KPP      False
# 38                  NaN      False
# 39                  NaN      False
# 41                  NaN      False
# 42          KRT2A KRT2E      False
# 57                  LZM      False
# 58    SMT3C SMT3H3 UBL1      False
# 60               KRTHB5      False
# 61     HHA1 HKA1 KRTHA1      False
# 62                  NaN      False
# 65                  NaN      False
# 1101                NaN      False
# 2137                NaN      False
# 2282                NaN      False
# 2856                NaN      False
# 2857             KRTHB4      False
# 2858             KRTHB2      False
# 2879                NaN      False

# %%
print(f"For p-putida proteins, there are N = {sum(uniprot_df.loc[uniprot_df['is_putida'], 'primary_name'].isna())} rows where primary_name is NaN")
print(f"There are N = {sum(uniprot_df['primary_name'].isna())} rows where primary_name is NaN")
uniprot_df.loc[uniprot_df['primary_name'].isna()]
# Out:
# For p-putida proteins, there are N = 1323 rows where primary_name is NaN
# There are N = 1332 rows where primary_name is NaN
#         From   Entry    Reviewed    entry_name  \
# 2     J5JYK1  J5JYK1  unreviewed  J5JYK1_BEAB2
# 9     P00761  P00761    reviewed      TRYP_PIG
# 10    P02539  P02539    reviewed    K2M1_SHEEP
# 27    P0A149  P0A149    reviewed    Y002_PSEPK
# 39    P25690  P25690    reviewed    K1M2_SHEEP
# ...      ...     ...         ...           ...
# 2849  Q88RW0  Q88RW0  unreviewed  Q88RW0_PSEPK
# 2850  Q88RW1  Q88RW1  unreviewed  Q88RW1_PSEPK
# 2851  Q88RW2  Q88RW2  unreviewed  Q88RW2_PSEPK
# 2860  Q835L3  Q835L3  unreviewed  Q835L3_ENTFA
# 2876  Q88RH1  Q88RH1  unreviewed  Q88RH1_PSEPK
#
#                                           protein_names gene_names  \
# 2                                   Polyketide synthase  BBA_03810
# 9                                 Trypsin (EC 3.4.21.4)        NaN
# 10    Keratin, type II microfibrillar (Low-sulfur ke...        NaN
# 27                      Uncharacterized protein PP_0002    PP_0002
# 39    Keratin, type I microfibrillar, 47.6 kDa (Low-...        NaN
# ...                                                 ...        ...
# 2849                          Transcriptional regulator    PP_0019
# 2850                           TIGR04255 family protein    PP_0018
# 2851                          Transcriptional regulator    PP_0017
# 2860  Acetyl-CoA acetyltransferase (EC 2.3.1.9) (Ace...    EF_1364
# 2876            CoA-transferase family III (EC 2.8.3.-)    PP_0159
#
#                                                Organism  Length locus_name  \
# 2     Beauveria bassiana (strain ARSEF 2860) (White ...  2413.0        NaN
# 9                                      Sus scrofa (Pig)   231.0        NaN
# 10                                   Ovis aries (Sheep)   109.0        NaN
# 27    Pseudomonas putida (strain ATCC 47054 / DSM 61...   263.0    PP_0002
# 39                                   Ovis aries (Sheep)   404.0        NaN
# ...                                                 ...     ...        ...
# 2849  Pseudomonas putida (strain ATCC 47054 / DSM 61...   232.0    PP_0019
# 2850  Pseudomonas putida (strain ATCC 47054 / DSM 61...   280.0    PP_0018
# 2851  Pseudomonas putida (strain ATCC 47054 / DSM 61...   119.0    PP_0017
# 2860  Enterococcus faecalis (strain ATCC 700802 / V583)   803.0    EF_1364
# 2876  Pseudomonas putida (strain ATCC 47054 / DSM 61...   406.0    PP_0159
#
#      Gene Names (ORF) primary_name synonym_name  is_putida
# 2           BBA_03810          NaN          NaN      False
# 9                 NaN          NaN          NaN      False
# 10                NaN          NaN          NaN      False
# 27                NaN          NaN          NaN       True
# 39                NaN          NaN          NaN      False
# ...               ...          ...          ...        ...
# 2849              NaN          NaN          NaN       True
# 2850              NaN          NaN          NaN       True
# 2851              NaN          NaN          NaN       True
# 2860              NaN          NaN          NaN      False
# 2876              NaN          NaN          NaN       True
#
# [1332 rows x 13 columns]

# %% [markdown]
# ## Create dataframe to convert between proteomics label and different uniprot labels

# %%
edd_df
edd_df = edd_df[edd_df['has_6letter_substring']]

# %%
edd_df['locus'] = [uniprot_df.loc[uniprot_df['From'] == x, 'locus_name'].values[0] for x in edd_df['extracted']]
edd_df['primary_name'] = [uniprot_df.loc[uniprot_df['From'] == x, 'primary_name'].values[0] for x in edd_df['extracted']]
edd_df['organism'] = [uniprot_df.loc[uniprot_df['From'] == x, 'Organism'].values[0] for x in edd_df['extracted']]
edd_df['is_putida'] = edd_df['organism'] == pp_string
# Out:
# /tmp/ipykernel_2440/216559954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edd_df['locus'] = [uniprot_df.loc[uniprot_df['From'] == x, 'locus_name'].values[0] for x in edd_df['extracted']]
# /tmp/ipykernel_2440/216559954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edd_df['primary_name'] = [uniprot_df.loc[uniprot_df['From'] == x, 'primary_name'].values[0] for x in edd_df['extracted']]
# /tmp/ipykernel_2440/216559954.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edd_df['organism'] = [uniprot_df.loc[uniprot_df['From'] == x, 'Organism'].values[0] for x in edd_df['extracted']]
# /tmp/ipykernel_2440/216559954.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   edd_df['is_putida'] = edd_df['organism'] == pp_string

# %%
edd_df.head(3)
# Out:
#                           orig  has_6letter_substring extracted         locus  \
# 0                       P0AE22                   True    P0AE22  b4055 JW4015
# 62  sp|A9GAJ9|A9GAJ9_SORC5 Mcm                   True    A9GAJ9       sce2716
# 63                   sp|J5JYK1                   True    J5JYK1           NaN
#
#    primary_name                                           organism  is_putida
# 0          aphA                      Escherichia coli (strain K12)      False
# 62          mcm  Sorangium cellulosum (strain So ce56) (Polyang...      False
# 63          NaN  Beauveria bassiana (strain ARSEF 2860) (White ...      False

# %%
edd_df.to_csv('./data/proteomics_id_translator.csv', index=False, header=True)
