# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
MAX_ABUNDANCE_THRESHOLD = 0.3

# %%
top3_files = []
for file in os.listdir("."):
    if (file.startswith('DBTL') & (file.endswith(".csv"))):
        top3_files.append(file)
top3_files
# Out:
# ['DBTL0_Plate1_Top3_Full_list_proteins_20230224-053921.csv',
#  'DBTL0_Plate2_Top3_Full_list_proteins_20230224-055157.csv',
#  'DBTL0_Plate3_Top3_Full_list_proteins_20230303-212530.csv',
#  'DBTL1_Plate1_Top3_Full_list_proteins_20230928-015658.csv',
#  'DBTL1_Plate2_Top3_Full_list_proteins_20230928-021027.csv',
#  'DBTL2_Top3_Full_list_proteins_20231213-155313.csv',
#  'DBTL3_Top3_Full_list_proteins_20240221-033259.csv']

# %% [markdown]
# ## Merge dataframes

# %% [markdown]
# ### Add plate information for DBTL0
# In DBTL0, one of the proteomics plates had way lower intensity

# %%
plate_mapping_df = pd.read_excel('../sample injection order.xlsx')
plate_mapping_df['Batch number'].value_counts()
# Out:
# Batch number
# 3    228
# 1     96
# 2     96
# Name: count, dtype: int64

# %%
plate_mapping_dict = dict(zip(list(plate_mapping_df['Sample Name in order injected']), list(plate_mapping_df['Batch number'])))

# %%
df_list = []
for f in top3_files:
    print(f)
    df = pd.read_csv(f)
    current_cycle = int(f[4])
    group_idx = f.find('Plate')
    if group_idx != -1:
        group = f[group_idx + 5]
    else:
        group = None
    print(f'Cycle: {current_cycle}\t Group/plate: {group}')
    df['group'] = group
    df['cycle'] = current_cycle
    df['Line Name'] = df.apply(lambda x: f"{x['Sample']}-{x['Replicate']}", axis = 1)
    if current_cycle == 0:
        df['plate_number'] = df['Line Name'].apply(lambda x: plate_mapping_dict[x])
    else:
        df['plate_number'] = 1
    df_list.append(df)
# Out:
# DBTL0_Plate1_Top3_Full_list_proteins_20230224-053921.csv
# Cycle: 0	 Group/plate: 1
# DBTL0_Plate2_Top3_Full_list_proteins_20230224-055157.csv
# Cycle: 0	 Group/plate: 2
# DBTL0_Plate3_Top3_Full_list_proteins_20230303-212530.csv
# Cycle: 0	 Group/plate: 3
# DBTL1_Plate1_Top3_Full_list_proteins_20230928-015658.csv
# Cycle: 1	 Group/plate: 1
# DBTL1_Plate2_Top3_Full_list_proteins_20230928-021027.csv
# Cycle: 1	 Group/plate: 2
# DBTL2_Top3_Full_list_proteins_20231213-155313.csv
# Cycle: 2	 Group/plate: None
# DBTL3_Top3_Full_list_proteins_20240221-033259.csv
# Cycle: 3	 Group/plate: None

# %%
df_full = pd.concat(df_list)

# %% [markdown]
# ## Update df_full

# %% [markdown]
# Change replicates from string to number

# %%
df_full['Replicate']=df_full['Replicate'].apply(lambda x: x[1:])

# %% [markdown]
# Add PP_ numbers to data

# %%
translation_df = pd.read_csv('../proteomics_id_translator.csv', header = 0, index_col = False)
translation_df
# Out:
#                              original extracted         locus primary_name  \
# 0                           sp|Q9A9Z2    Q9A9Z2       CC_0819         xylD
# 1              tr|Q835L3|Q835L3_ENTFA    Q835L3       EF_1364         mvaE
# 2               sp|Q9FD71|HMGCS_ENTFL    Q9FD71           NaN         mvaS
# 3                              P0AE22    P0AE22  b4055 JW4015         aphA
# 4     sp|P00698|LYSC_CHICK Lysozyme C    P00698           NaN          LYZ
# ...                               ...       ...           ...          ...
# 2733           tr|Q88QV1|Q88QV1_PSEPK    Q88QV1       PP_0383         davB
# 2734           tr|Q88QV2|Q88QV2_PSEPK    Q88QV2       PP_0382         davA
# 2735           tr|Q88RH1|Q88RH1_PSEPK    Q88RH1       PP_0159          NaN
# 2736           tr|Q88RH2|Q88RH2_PSEPK    Q88RH2       PP_0158         gcdH
# 2737   sp|Q88P68|Q88P68_PSEPK Pp_0985    Q88P68           NaN          NaN
#
#                                                organism  is_putida
# 0     Caulobacter vibrioides (strain ATCC 19089 / CB...      False
# 1     Enterococcus faecalis (strain ATCC 700802 / V583)      False
# 2        Enterococcus faecalis (Streptococcus faecalis)      False
# 3                         Escherichia coli (strain K12)      False
# 4                               Gallus gallus (Chicken)      False
# ...                                                 ...        ...
# 2733  Pseudomonas putida (strain ATCC 47054 / DSM 61...       True
# 2734  Pseudomonas putida (strain ATCC 47054 / DSM 61...       True
# 2735  Pseudomonas putida (strain ATCC 47054 / DSM 61...       True
# 2736  Pseudomonas putida (strain ATCC 47054 / DSM 61...       True
# 2737                                                NaN      False
#
# [2738 rows x 6 columns]

# %%
ext_to_organism = dict(translation_df[['extracted', 'organism']].values)
ext_to_locus = dict(translation_df[['extracted', 'locus']].values)
ext_to_primary = dict(translation_df[['extracted', 'primary_name']].values)

# %%
any(df_full['Protein.Group'].unique() == 'Q88QV1')
# Out:
# True

# %%
len(df_full['Protein.Group'].unique())
# Out:
# 2118

# %%
# [p for p in df_full['Protein.Group'].unique() if p in translation_df['extracted']]
len([p for p in df_full['Protein.Group'].unique() if p in translation_df['extracted'].unique()])
# Out:
# 2113

# %%
df_full
# Out:
#        Protein.Group Protein.Names Protein  \
# 0             P00552    KKA2_KLEPN     Neo
# 1             P00552    KKA2_KLEPN     Neo
# 2             P00552    KKA2_KLEPN     Neo
# 3             P00552    KKA2_KLEPN     Neo
# 4             P00552    KKA2_KLEPN     Neo
# ...              ...           ...     ...
# 305788        Q9Z408     CSD_PSEPK    Csda
# 305789        Q9Z408     CSD_PSEPK    Csda
# 305790        Q9Z408     CSD_PSEPK    Csda
# 305791        Q9Z408     CSD_PSEPK    Csda
# 305792        Q9Z408     CSD_PSEPK    Csda
#
#                          Protein.Description              Sample Replicate  \
# 0       Aminoglycoside 3'-phosphotransferase             Control         1
# 1       Aminoglycoside 3'-phosphotransferase             Control         2
# 2       Aminoglycoside 3'-phosphotransferase             Control         3
# 3       Aminoglycoside 3'-phosphotransferase             Control         4
# 4       Aminoglycoside 3'-phosphotransferase             Control         5
# ...                                      ...                 ...       ...
# 305788         Probable cysteine desulfurase  PP_0368_PP_4189_P4         2
# 305789         Probable cysteine desulfurase  PP_0368_PP_4189_P4         3
# 305790         Probable cysteine desulfurase     PP_4189_PP_4192         1
# 305791         Probable cysteine desulfurase     PP_4189_PP_4192         2
# 305792         Probable cysteine desulfurase     PP_4189_PP_4192         3
#
#         Top_3pep_counts_mean  %_of protein_abundance_Top3-method  \
# 0               1.191124e+08                            3.112624
# 1               1.491721e+08                            3.712705
# 2               1.387009e+08                            3.700489
# 3               1.003063e+08                            2.650788
# 4               1.142768e+08                            2.835433
# ...                      ...                                 ...
# 305788          1.318040e+05                            0.006630
# 305789          1.668348e+05                            0.008851
# 305790          1.792609e+05                            0.009231
# 305791          1.231874e+05                            0.006716
# 305792          1.876213e+05                            0.010204
#
#         log10_%_abundance group  cycle              Line Name  plate_number
# 0                0.493127     1      0             Control-R1             1
# 1                0.569690     1      0             Control-R2             1
# 2                0.568259     1      0             Control-R3             1
# 3                0.423375     1      0             Control-R4             1
# 4                0.452619     1      0             Control-R5             1
# ...                   ...   ...    ...                    ...           ...
# 305788          -2.178455  None      3  PP_0368_PP_4189_P4-R2             1
# 305789          -2.052990  None      3  PP_0368_PP_4189_P4-R3             1
# 305790          -2.034763  None      3     PP_4189_PP_4192-R1             1
# 305791          -2.172877  None      3     PP_4189_PP_4192-R2             1
# 305792          -1.991247  None      3     PP_4189_PP_4192-R3             1
#
# [1716921 rows x 13 columns]

# %%
df_full[df_full['Protein'] == 'Neo']
# Out:
#     Protein.Group Protein.Names Protein                   Protein.Description  \
# 0          P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1          P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2          P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 3          P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 4          P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# ..            ...           ...     ...                                   ...
# 361        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 362        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 363        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 364        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 365        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#                  Sample Replicate  Top_3pep_counts_mean  \
# 0               Control         1          1.191124e+08
# 1               Control         2          1.491721e+08
# 2               Control         3          1.387009e+08
# 3               Control         4          1.003063e+08
# 4               Control         5          1.142768e+08
# ..                  ...       ...                   ...
# 361  PP_0368_PP_4189_P4         2          2.627000e+07
# 362  PP_0368_PP_4189_P4         3          5.870756e+07
# 363     PP_4189_PP_4192         1          8.037235e+07
# 364     PP_4189_PP_4192         2          4.805442e+07
# 365     PP_4189_PP_4192         3          5.263339e+07
#
#      %_of protein_abundance_Top3-method  log10_%_abundance group  cycle  \
# 0                              3.112624           0.493127     1      0
# 1                              3.712705           0.569690     1      0
# 2                              3.700489           0.568259     1      0
# 3                              2.650788           0.423375     1      0
# 4                              2.835433           0.452619     1      0
# ..                                  ...                ...   ...    ...
# 361                            1.321528           0.121077  None      3
# 362                            3.114706           0.493417  None      3
# 363                            4.138642           0.616858  None      3
# 364                            2.619930           0.418290  None      3
# 365                            2.862411           0.456732  None      3
#
#                  Line Name  plate_number
# 0               Control-R1             1
# 1               Control-R2             1
# 2               Control-R3             1
# 3               Control-R4             1
# 4               Control-R5             1
# ..                     ...           ...
# 361  PP_0368_PP_4189_P4-R2             1
# 362  PP_0368_PP_4189_P4-R3             1
# 363     PP_4189_PP_4192-R1             1
# 364     PP_4189_PP_4192-R2             1
# 365     PP_4189_PP_4192-R3             1
#
# [987 rows x 13 columns]

# %%
df_full['Protein.Names'].unique()
# Out:
# array(['KKA2_KLEPN', 'TRYP_PIG', 'K2C1_HUMAN', ..., 'Q88PK3_PSEPK',
#        'HSCB_PSEPK', 'RS20_PSEPK'], dtype=object)

# %%
[p for p in df_full['Protein.Names'].unique() if p.upper().find('ENTFL')>-1]
# Out:
# ['HMGCS_ENTFL']

# %%
any(df_full['Protein'] == 'ENTFA')
# Out:
# False

# %%
proteins_to_keep = ['neo', 'aacC1', 'mvaS', 'mcm', 'aphA', 'MVD1', 'mvk', 'cas9', 'ef_1364']
# proteins_to_keep = ['neo', 'aacC1', 'mvaS', 'mcm', 'aphA', 'MVD1', 'mvk', 'cas9', 'mvaE']

proteins_to_keep_lower = [s.lower() for s in proteins_to_keep]

df_full['protein_lower'] = [p.lower() for p in df_full['Protein']]

# %%
[p for p in proteins_to_keep_lower if p in df_full['protein_lower'].unique()]
# Out:
# ['neo', 'aacc1', 'mvas', 'apha', 'mvd1', 'mvk', 'cas9', 'ef_1364']

# %%
df_full.loc[df_full['Protein.Group'] == 'Q835L3',:]
# Out:
#      Protein.Group Protein.Names  Protein  \
# 3936        Q835L3  Q835L3_ENTFA  Ef_1364
# 3937        Q835L3  Q835L3_ENTFA  Ef_1364
# 3938        Q835L3  Q835L3_ENTFA  Ef_1364
# 3939        Q835L3  Q835L3_ENTFA  Ef_1364
# 3940        Q835L3  Q835L3_ENTFA  Ef_1364
# ...            ...           ...      ...
# 8047        Q835L3  Q835L3_ENTFA  Ef_1364
# 8048        Q835L3  Q835L3_ENTFA  Ef_1364
# 8049        Q835L3  Q835L3_ENTFA  Ef_1364
# 8050        Q835L3  Q835L3_ENTFA  Ef_1364
# 8051        Q835L3  Q835L3_ENTFA  Ef_1364
#
#                                     Protein.Description              Sample  \
# 3936  Acetyl-CoA acetyltransferase/hydroxymethylglut...             Control
# 3937  Acetyl-CoA acetyltransferase/hydroxymethylglut...             Control
# 3938  Acetyl-CoA acetyltransferase/hydroxymethylglut...             Control
# 3939  Acetyl-CoA acetyltransferase/hydroxymethylglut...             Control
# 3940  Acetyl-CoA acetyltransferase/hydroxymethylglut...             Control
# ...                                                 ...                 ...
# 8047  Acetyl-CoA acetyltransferase/hydroxymethylglut...  PP_0368_PP_4189_P4
# 8048  Acetyl-CoA acetyltransferase/hydroxymethylglut...  PP_0368_PP_4189_P4
# 8049  Acetyl-CoA acetyltransferase/hydroxymethylglut...     PP_4189_PP_4192
# 8050  Acetyl-CoA acetyltransferase/hydroxymethylglut...     PP_4189_PP_4192
# 8051  Acetyl-CoA acetyltransferase/hydroxymethylglut...     PP_4189_PP_4192
#
#      Replicate  Top_3pep_counts_mean  %_of protein_abundance_Top3-method  \
# 3936         1          5.645667e+07                            1.475316
# 3937         2          5.065667e+07                            1.260781
# 3938         3          5.043000e+07                            1.345454
# 3939         4          4.569667e+07                            1.207623
# 3940         5          4.793000e+07                            1.189238
# ...        ...                   ...                                 ...
# 8047         2          1.630529e+07                            0.820248
# 8048         3          1.904978e+07                            1.010678
# 8049         1          1.827141e+07                            0.940856
# 8050         2          1.381909e+07                            0.753418
# 8051         3          1.459603e+07                            0.793790
#
#       log10_%_abundance group  cycle              Line Name  plate_number  \
# 3936           0.168885     1      0             Control-R1             1
# 3937           0.100640     1      0             Control-R2             1
# 3938           0.128869     1      0             Control-R3             1
# 3939           0.081931     1      0             Control-R4             1
# 3940           0.075269     1      0             Control-R5             1
# ...                 ...   ...    ...                    ...           ...
# 8047          -0.086055  None      3  PP_0368_PP_4189_P4-R2             1
# 8048           0.004613  None      3  PP_0368_PP_4189_P4-R3             1
# 8049          -0.026477  None      3     PP_4189_PP_4192-R1             1
# 8050          -0.122964  None      3     PP_4189_PP_4192-R2             1
# 8051          -0.100295  None      3     PP_4189_PP_4192-R3             1
#
#      protein_lower
# 3936       ef_1364
# 3937       ef_1364
# 3938       ef_1364
# 3939       ef_1364
# 3940       ef_1364
# ...            ...
# 8047       ef_1364
# 8048       ef_1364
# 8049       ef_1364
# 8050       ef_1364
# 8051       ef_1364
#
# [987 rows x 14 columns]

# %%
df_full['Protein.Group'].value_counts()
# Out:
# Protein.Group
# P00552    987
# Q88MD8    987
# Q88MF9    987
# Q88MF5    987
# Q88MF3    987
#          ...
# Q88KP3     96
# Q88KN6     96
# Q88GW9     96
# Q88PC3     96
# Q88LY6     96
# Name: count, Length: 2118, dtype: int64

# %%
df_full.loc[:, 'organism'] = df_full.loc[:, 'Protein.Group'].apply(lambda x: ext_to_organism[x] if x in ext_to_organism.keys() else None)
df_full.loc[:, 'locus'] = df_full.loc[:, 'Protein.Group'].apply(lambda x: ext_to_locus[x] if x in ext_to_locus.keys() else None)
df_full.loc[:, 'primary'] = df_full.loc[:, 'Protein.Group'].apply(lambda x: ext_to_primary[x] if x in ext_to_primary.keys() else None)
df_full.loc[:, 'is_putida'] = df_full.loc[:, 'organism'].apply(lambda x: x == 'Pseudomonas putida (strain ATCC 47054 / DSM 6125 / CFBP 8728 / NCIMB 11950 / KT2440)')

# %%
df_full.head(3)
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control         1          1.191124e+08
# 1  Control         2          1.491721e+08
# 2  Control         3          1.387009e+08
#
#    %_of protein_abundance_Top3-method  log10_%_abundance group  cycle  \
# 0                            3.112624           0.493127     1      0
# 1                            3.712705           0.569690     1      0
# 2                            3.700489           0.568259     1      0
#
#     Line Name  plate_number protein_lower               organism locus  \
# 0  Control-R1             1           neo  Klebsiella pneumoniae   NaN
# 1  Control-R2             1           neo  Klebsiella pneumoniae   NaN
# 2  Control-R3             1           neo  Klebsiella pneumoniae   NaN
#
#   primary  is_putida
# 0     neo      False
# 1     neo      False
# 2     neo      False

# %%
df_full.loc[df_full['protein_lower'].isin(proteins_to_keep_lower), 'Protein'].value_counts()
# Out:
# Protein
# Neo        987
# Apha       987
# Aacc1      987
# Mvd1       987
# Ef_1364    987
# Mvk        987
# Cas9       987
# Mvas       987
# Name: count, dtype: int64

# %%
df_full.loc[df_full['primary'].isin(proteins_to_keep_lower), 'Protein'].value_counts()
# Out:
# Protein
# Neo     987
# Mvk     987
# Cas9    987
# Name: count, dtype: int64

# %% [markdown]
# ### Filter out proteins if they aren't putida, in the list of separate proteins to keep, or have 'pp' at the start of their name

# %%
df_full.loc[:,'filter_foreign_tokeep'] = (df_full['is_putida'] | df_full['protein_lower'].isin(proteins_to_keep_lower) | [p[:2] == 'pp' for p in df_full['protein_lower']])
print(df_full.loc[~df_full['filter_foreign_tokeep'], 'protein_lower'].unique())
print(f'pre-filter len(df): {len(df_full)}')
df_full = df_full[df_full['filter_foreign_tokeep']]
print(f'post-filter len(df): {len(df_full)}')
# Out:
# /tmp/ipykernel_12957/3735379651.py:1: FutureWarning: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are deprecated and will raise in a future version. Wrap the object in a Series, Index, or np.array before operating instead.
#   df_full.loc[:,'filter_foreign_tokeep'] = (df_full['is_putida'] | df_full['protein_lower'].isin(proteins_to_keep_lower) | [p[:2] == 'pp' for p in df_full['protein_lower']])
# ['tryp_pig' 'krt1' 'krt10' 'krt9' 'krt2' 'lippks1' 'krt15' 'ibpb' 'pabb'
#  'slyx']
# pre-filter len(df): 1716921
# post-filter len(df): 1711113

# %%
df_full['Protein'].unique()[:50]
# Out:
# array(['Neo', 'Arga', 'Dnaa', 'Dnan', 'Rsmg', 'Ihfa', 'Ihfb', 'Pp_1224',
#        'Adk', 'Pal', 'Yidc', 'Hpf', 'Pp_0002', 'Parb', 'Rpll', 'Rpsu',
#        'Rpon', 'Tolb', 'Mnme', 'Apha', 'Aacc1', 'Mvd1', 'Alla', 'Argb',
#        'Argc2', 'Argd', 'Pp_0396', 'Rpsk', 'Seld', 'Hisd', 'Pp_1352',
#        'Argg', 'Argj', 'Argh', 'Infa', 'Ftsz', 'Ef_1364', 'Pp_1157',
#        'Atpf', 'Atph', 'Atpa', 'Atpg', 'Atpd', 'Atpc', 'Glmu', 'Glms',
#        'Pp_5400', 'Pp_5395', 'Pp_5392', 'Pp_5391'], dtype=object)

# %% [markdown]
# ## Get final name for proteins

# %%
has_locus = ~df_full['locus'].isna()
df_full.loc[has_locus, 'final_protein_name'] = df_full.loc[has_locus, 'locus']
df_full.loc[~has_locus, 'final_protein_name'] = df_full.loc[~has_locus, 'protein_lower']
# Out:
# /tmp/ipykernel_12957/2821783229.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_full.loc[has_locus, 'final_protein_name'] = df_full.loc[has_locus, 'locus']

# %% [markdown]
# ## Remove proteins that aren't in each run

# %%
cycles = [0,1,2,3]
unique_proteins = set(df_full.loc[df_full['cycle'] == cycles[0], 'final_protein_name'])
for c in cycles[1:]:
    unique_proteins = unique_proteins.intersection(
        set(
            df_full.loc[df_full['cycle'] == c, 'final_protein_name'].unique()
        )
    )
shared_unique_proteins = list(unique_proteins)
print(len(shared_unique_proteins))
# Out:
# 1427

# %%
df_full = df_full.loc[df_full['final_protein_name'].isin(shared_unique_proteins), :]

# %% [markdown]
# ## Get control mean for each run

# %%
df_full.head(3)
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control         1          1.191124e+08
# 1  Control         2          1.491721e+08
# 2  Control         3          1.387009e+08
#
#    %_of protein_abundance_Top3-method  log10_%_abundance group  cycle  \
# 0                            3.112624           0.493127     1      0
# 1                            3.712705           0.569690     1      0
# 2                            3.700489           0.568259     1      0
#
#     Line Name  plate_number protein_lower               organism locus  \
# 0  Control-R1             1           neo  Klebsiella pneumoniae   NaN
# 1  Control-R2             1           neo  Klebsiella pneumoniae   NaN
# 2  Control-R3             1           neo  Klebsiella pneumoniae   NaN
#
#   primary  is_putida  filter_foreign_tokeep final_protein_name
# 0     neo      False                   True                neo
# 1     neo      False                   True                neo
# 2     neo      False                   True                neo

# %%
df_full['is_control'] = df_full['Sample'].apply(lambda x: 'ontrol' in x)
control_mean_df = df_full.loc[df_full['is_control'], ['final_protein_name', 'Top_3pep_counts_mean', 'cycle', 'plate_number']].groupby(['final_protein_name', 'cycle', 'plate_number']).mean()
control_mean_df
# Out:
#                                        Top_3pep_counts_mean
# final_protein_name cycle plate_number
# EF_1364            0     1                     5.565429e+07
#                          2                     8.121857e+07
#                          3                     1.327726e+07
#                    1     1                     2.352441e+07
#                    2     1                     5.580900e+06
# ...                                                     ...
# pp_0985            0     2                     5.270041e+06
#                          3                     7.070051e+06
#                    1     1                     1.039243e+06
#                    2     1                     1.352591e+06
#                    3     1                     2.840772e+06
#
# [8527 rows x 1 columns]

# %%
divide_by_control = lambda x: x['Top_3pep_counts_mean']/control_mean_df.loc[x['final_protein_name'], x['cycle'], x['plate_number']].values[0]
df_full.loc[:, 'normalized_top3'] = df_full.apply(divide_by_control, axis = 1)

# %%
df_full[df_full['is_control']].head(5)
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 3        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 4        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control         1          1.191124e+08
# 1  Control         2          1.491721e+08
# 2  Control         3          1.387009e+08
# 3  Control         4          1.003063e+08
# 4  Control         5          1.142768e+08
#
#    %_of protein_abundance_Top3-method  log10_%_abundance group  ...  \
# 0                            3.112624           0.493127     1  ...
# 1                            3.712705           0.569690     1  ...
# 2                            3.700489           0.568259     1  ...
# 3                            2.650788           0.423375     1  ...
# 4                            2.835433           0.452619     1  ...
#
#    plate_number protein_lower               organism locus primary is_putida  \
# 0             1           neo  Klebsiella pneumoniae   NaN     neo     False
# 1             1           neo  Klebsiella pneumoniae   NaN     neo     False
# 2             1           neo  Klebsiella pneumoniae   NaN     neo     False
# 3             1           neo  Klebsiella pneumoniae   NaN     neo     False
# 4             1           neo  Klebsiella pneumoniae   NaN     neo     False
#
#   filter_foreign_tokeep  final_protein_name  is_control normalized_top3
# 0                  True                 neo        True        0.977287
# 1                  True                 neo        True        1.223919
# 2                  True                 neo        True        1.138006
# 3                  True                 neo        True        0.822988
# 4                  True                 neo        True        0.937612
#
# [5 rows x 22 columns]

# %%
df_full['final_line_name'] = df_full.apply(lambda x: f"{x['Sample']}-R{x['Replicate']}_c{x['cycle']}" , axis = 1)

# %%
idx_to_drop = (
    (df_full['Sample'] == 'PP_0528_PP_0815_PP_1317') & 
    (df_full['cycle'] == 3)
)
df_full = df_full[~idx_to_drop]

# %%
df_full[df_full['cycle'] == 0].value_counts(['final_line_name'])
# df_full[df_full['cycle'] == 0].value_counts(['final_protein_name'])
# Out:
# final_line_name
# PP_3394-R2_c0                1416
# PP_0582-R2_c0                1416
# PP_1607_NT2_xylS_Pm-R3_c0    1416
# PP_1157-R1_c0                1416
# PP_1157-R2_c0                1416
#                              ...
# PP_1457-R3_c0                1415
# PP_1457-R2_c0                1415
# PP_1457-R1_c0                1415
# PP_1394-R3_c0                1415
# PP_5420-R3_c0                1415
# Name: count, Length: 420, dtype: int64

# %% [markdown]
# ## Look at distribution of intensities for each run

# %%
# df_full['plate_and_cycle'] = [f"{df_full.loc[i, 'plate']}_{df_full.loc[i,'cycle']}" for i in df_full.index]
# df_full['plate_and_cycle'] = df_full.apply(lambda x: f"{x['plate']}_{x['cycle']}", axis = 1)

# %%
# sns.histplot(
#     data = df_full[(df_full['is_control']) & (~df_full['Top_3pep_counts_mean'].isna())],
#     x = 'Top_3pep_counts_mean',
#     hue = 'plate_and_cycle',
#     log_scale = True
# )

# %%
# any(df_full.loc[(df_full['is_control']) & (~df_full['Top_3pep_counts_mean'].isna()), 'Top_3pep_counts_mean']==0)

# %%
# fig, ax= plt.subplots()
# sns.violinplot(
#     data = df_full[(~df_full['is_control']) & (~df_full['Top_3pep_counts_mean'].isna()) & (df_full['Top_3pep_counts_mean']>0)],
#     x = 'Top_3pep_counts_mean',
#     hue = 'plate_and_cycle',
#     log_scale = True
# )

# %%
# fig, ax= plt.subplots()
# sns.violinplot(
#     data = df_full[(df_full['is_control']) & (~df_full['Top_3pep_counts_mean'].isna()) & (df_full['Top_3pep_counts_mean']>0)],
#     x = 'Top_3pep_counts_mean',
#     hue = 'plate_and_cycle',
#     log_scale = True
# )

# %% [markdown]
# ## Make pivot table for single-rep top3 mean counts

# %% [markdown]
# ### add final name column
# Combine condition, DBTL cycle, and rep so that there are no duplicate entries

# %%
df_full.head(3)
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control         1          1.191124e+08
# 1  Control         2          1.491721e+08
# 2  Control         3          1.387009e+08
#
#    %_of protein_abundance_Top3-method  log10_%_abundance group  ...  \
# 0                            3.112624           0.493127     1  ...
# 1                            3.712705           0.569690     1  ...
# 2                            3.700489           0.568259     1  ...
#
#    protein_lower               organism  locus primary is_putida  \
# 0            neo  Klebsiella pneumoniae    NaN     neo     False
# 1            neo  Klebsiella pneumoniae    NaN     neo     False
# 2            neo  Klebsiella pneumoniae    NaN     neo     False
#
#   filter_foreign_tokeep final_protein_name  is_control  normalized_top3  \
# 0                  True                neo        True         0.977287
# 1                  True                neo        True         1.223919
# 2                  True                neo        True         1.138006
#
#   final_line_name
# 0   Control-R1_c0
# 1   Control-R2_c0
# 2   Control-R3_c0
#
# [3 rows x 23 columns]

# %% [markdown]
# Update replicate number for one set of runs specifically

# %%
df_full['final_line_name'].value_counts()
# Out:
# final_line_name
# PP_0812_PP_2095-R2_c1    1427
# PP_0437_PP_0814-R1_c2    1427
# PP_0437_PP_0814-R3_c2    1427
# PP_0437_PP_1769-R1_c2    1427
# PP_0437_PP_1769-R2_c2    1427
#                          ...
# PP_0277-R2_c0            1415
# PP_0277-R3_c0            1415
# PP_0654-R1_c0            1415
# PP_0654-R2_c0            1415
# PP_0814-R2_c0            1415
# Name: count, Length: 981, dtype: int64

# %% [raw]
# df_full

# %%
df_full
# Out:
#        Protein.Group Protein.Names Protein  \
# 0             P00552    KKA2_KLEPN     Neo
# 1             P00552    KKA2_KLEPN     Neo
# 2             P00552    KKA2_KLEPN     Neo
# 3             P00552    KKA2_KLEPN     Neo
# 4             P00552    KKA2_KLEPN     Neo
# ...              ...           ...     ...
# 305788        Q9Z408     CSD_PSEPK    Csda
# 305789        Q9Z408     CSD_PSEPK    Csda
# 305790        Q9Z408     CSD_PSEPK    Csda
# 305791        Q9Z408     CSD_PSEPK    Csda
# 305792        Q9Z408     CSD_PSEPK    Csda
#
#                          Protein.Description              Sample Replicate  \
# 0       Aminoglycoside 3'-phosphotransferase             Control         1
# 1       Aminoglycoside 3'-phosphotransferase             Control         2
# 2       Aminoglycoside 3'-phosphotransferase             Control         3
# 3       Aminoglycoside 3'-phosphotransferase             Control         4
# 4       Aminoglycoside 3'-phosphotransferase             Control         5
# ...                                      ...                 ...       ...
# 305788         Probable cysteine desulfurase  PP_0368_PP_4189_P4         2
# 305789         Probable cysteine desulfurase  PP_0368_PP_4189_P4         3
# 305790         Probable cysteine desulfurase     PP_4189_PP_4192         1
# 305791         Probable cysteine desulfurase     PP_4189_PP_4192         2
# 305792         Probable cysteine desulfurase     PP_4189_PP_4192         3
#
#         Top_3pep_counts_mean  %_of protein_abundance_Top3-method  \
# 0               1.191124e+08                            3.112624
# 1               1.491721e+08                            3.712705
# 2               1.387009e+08                            3.700489
# 3               1.003063e+08                            2.650788
# 4               1.142768e+08                            2.835433
# ...                      ...                                 ...
# 305788          1.318040e+05                            0.006630
# 305789          1.668348e+05                            0.008851
# 305790          1.792609e+05                            0.009231
# 305791          1.231874e+05                            0.006716
# 305792          1.876213e+05                            0.010204
#
#         log10_%_abundance group  ...  protein_lower  \
# 0                0.493127     1  ...            neo
# 1                0.569690     1  ...            neo
# 2                0.568259     1  ...            neo
# 3                0.423375     1  ...            neo
# 4                0.452619     1  ...            neo
# ...                   ...   ...  ...            ...
# 305788          -2.178455  None  ...           csda
# 305789          -2.052990  None  ...           csda
# 305790          -2.034763  None  ...           csda
# 305791          -2.172877  None  ...           csda
# 305792          -1.991247  None  ...           csda
#
#                                                  organism    locus primary  \
# 0                                   Klebsiella pneumoniae      NaN     neo
# 1                                   Klebsiella pneumoniae      NaN     neo
# 2                                   Klebsiella pneumoniae      NaN     neo
# 3                                   Klebsiella pneumoniae      NaN     neo
# 4                                   Klebsiella pneumoniae      NaN     neo
# ...                                                   ...      ...     ...
# 305788  Pseudomonas putida (strain ATCC 47054 / DSM 61...  PP_1529    csdA
# 305789  Pseudomonas putida (strain ATCC 47054 / DSM 61...  PP_1529    csdA
# 305790  Pseudomonas putida (strain ATCC 47054 / DSM 61...  PP_1529    csdA
# 305791  Pseudomonas putida (strain ATCC 47054 / DSM 61...  PP_1529    csdA
# 305792  Pseudomonas putida (strain ATCC 47054 / DSM 61...  PP_1529    csdA
#
#        is_putida filter_foreign_tokeep final_protein_name  is_control  \
# 0          False                  True                neo        True
# 1          False                  True                neo        True
# 2          False                  True                neo        True
# 3          False                  True                neo        True
# 4          False                  True                neo        True
# ...          ...                   ...                ...         ...
# 305788      True                  True            PP_1529       False
# 305789      True                  True            PP_1529       False
# 305790      True                  True            PP_1529       False
# 305791      True                  True            PP_1529       False
# 305792      True                  True            PP_1529       False
#
#         normalized_top3           final_line_name
# 0              0.977287             Control-R1_c0
# 1              1.223919             Control-R2_c0
# 2              1.138006             Control-R3_c0
# 3              0.822988             Control-R4_c0
# 4              0.937612             Control-R5_c0
# ...                 ...                       ...
# 305788         0.914931  PP_0368_PP_4189_P4-R2_c3
# 305789         1.158101  PP_0368_PP_4189_P4-R3_c3
# 305790         1.244358     PP_4189_PP_4192-R1_c3
# 305791         0.855118     PP_4189_PP_4192-R2_c3
# 305792         1.302393     PP_4189_PP_4192-R3_c3
#
# [1394943 rows x 23 columns]

# %% [markdown]
# ### Add isoprenol to the top3 data

# %%
isoprenol_df = pd.read_csv('../normalized_proteomics_pivot.csv')
isoprenol_df = isoprenol_df.loc[:, ['line_name_rep_cycle', 'isoprenol']]
isoprenol_df.shape
isoprenol_df['line_name_rep_cycle'] = isoprenol_df['line_name_rep_cycle'].apply(lambda x: f'{x[:-1]}{int(x[-1])-1}')
isoprenol_df['line_name_rep_cycle']
isoprenol_df = isoprenol_df.set_index('line_name_rep_cycle')
isoprenol_df.head(3)
# Out:
#                      isoprenol
# line_name_rep_cycle
# Control-R10_c0        1.024392
# Control-R11_c0        1.120367
# Control-R12_c0        1.178920

# %%
def merge_isoprenol_data(df_prot, df_isoprenol):
    print(
        f'Found N = {len([line_name for line_name in df_isoprenol.index if line_name in df_prot.index])} matching indices'
    )
    df_out = pd.merge(left = df_prot, right = df_isoprenol, how='inner', left_index=True, right_index=True)
    return df_out

# %%
df_pivot_singlerep = df_full.pivot(index = 'final_line_name', columns='final_protein_name', values='Top_3pep_counts_mean')
df_pivot_singlerep_norm = df_full.pivot(index = 'final_line_name', columns='final_protein_name', values='normalized_top3')
df_pivot_singlerep_abundance = df_full.pivot(index = 'final_line_name', columns='final_protein_name', values='%_of protein_abundance_Top3-method')

df_pivot_singlerep = merge_isoprenol_data(df_pivot_singlerep, isoprenol_df)
df_pivot_singlerep_norm = merge_isoprenol_data(df_pivot_singlerep_norm, isoprenol_df)
df_pivot_singlerep_abundance = merge_isoprenol_data(df_pivot_singlerep_abundance, isoprenol_df)

df_pivot_singlerep = df_pivot_singlerep.dropna(axis = 'columns', how = 'any')
df_pivot_singlerep_norm = df_pivot_singlerep_norm.dropna(axis = 'columns', how = 'any')
df_pivot_singlerep_abundance = df_pivot_singlerep_abundance.dropna(axis = 'columns', how = 'any')

df_pivot_singlerep.to_csv('top3_singlerep.csv')
df_pivot_singlerep_norm.to_csv('top3_singlerep_norm.csv')
df_pivot_singlerep_abundance.to_csv('top3_singlerep_abundance.csv')
# Out:
# Found N = 939 matching indices
# Found N = 939 matching indices
# Found N = 939 matching indices

# %%
df_pivot = df_pivot_singlerep.copy()
df_pivot_norm = df_pivot_singlerep_norm.copy()
df_pivot_abundance = df_pivot_singlerep_abundance.copy()

# %%
def add_line_cycle(x):
    rep_idx = x.index('-R')
    name = x[:rep_idx]
    c_idx = x.index('c')
    cycle = x[c_idx+1:]
    rep = x[rep_idx+2:c_idx-1]
    name_cycle = f"{name}_c{cycle}"
    assert len(x) == len(name_cycle)+len(rep)+2, print(f'name: {x} name_cycle: {name_cycle}')
    return name_cycle
_=[add_line_cycle(x) for x in df_pivot.index]

# %%
df_pivot.head(3)
# Out:
#                      EF_1364       MM_1762        PP_0001        PP_0002  \
# Control-R10_c0  8.458000e+07  4.033667e+07  786768.666667  575493.000000
# Control-R11_c0  8.238000e+07  4.183667e+07  795890.566667  502817.800000
# Control-R12_c0  8.366333e+07  4.402333e+07  914329.333333  297034.333333
#
#                       PP_0003        PP_0004        PP_0005    PP_0006  \
# Control-R10_c0  906661.666667  585435.000000  246149.400000  1861924.0
# Control-R11_c0  839299.000000  564741.233333  237367.933333  1771418.0
# Control-R12_c0  848661.666667  619902.666667  486974.666667  1911236.0
#
#                      PP_0010       PP_0011  ...       PP_5416       PP_5417  \
# Control-R10_c0  1.097381e+06  3.876297e+06  ...  2.517358e+06  4.890000e+06
# Control-R11_c0  1.011488e+06  4.106196e+06  ...  2.711258e+06  5.450000e+06
# Control-R12_c0  8.953613e+05  4.255051e+06  ...  2.644439e+06  4.926667e+06
#
#                     SPy_1046       YNR043W         aacc1  b4055 JW4015  \
# Control-R10_c0  2.039252e+06  1.008967e+08  8.048551e+07  1.464667e+07
# Control-R11_c0  1.789548e+06  1.118167e+08  8.348041e+07  1.642041e+07
# Control-R12_c0  1.756136e+06  1.062000e+08  8.400000e+07  1.206000e+07
#
#                         mvas           neo       pp_0985  isoprenol
# Control-R10_c0  3.275000e+07  1.320085e+08  6.587633e+06   1.024392
# Control-R11_c0  3.413667e+07  1.283020e+08  5.247480e+06   1.120367
# Control-R12_c0  3.279000e+07  1.447949e+08  4.376667e+06   1.178920
#
# [3 rows x 1402 columns]

# %%
df_list = [df_pivot, df_pivot_norm, df_pivot_abundance]
df_names = ['top3', 'top3_norm', 'top3_abundance']
for i, df in enumerate(df_list):
    df_list[i] = df_list[i].reset_index(names = 'line_rep_cycle')
    df_list[i]['line_cycle'] = df_list[i]['line_rep_cycle'].apply(lambda x: add_line_cycle(x))
    df_list[i] = df_list[i].drop(columns = 'line_rep_cycle')
    columns_to_mean = df_list[i].columns[:-1]
    df_list[i] = df_list[i].groupby(by = 'line_cycle').mean()
    df_list[i].to_csv(f'{df_names[i]}.csv')
