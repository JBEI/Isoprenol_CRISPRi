# %% [markdown]
# # Process protein data from uniprot
# Previously used this tool https://www.uniprot.org/id-mapping to map the protein IDs returned from proteomics to PP_/4-letter codes. This script parses the output and saves a table to convert between formats.

# %%
import edd_utils as eddu
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re 
import random
random.seed(1)

# %% [markdown]
# Import uniprot results and dataframe with original protein labels

# %%
uniprot_df = pd.read_csv('./data/uniprot_db_DBTL0_DBTL1_proteins.tsv', delimiter='\t')
edd_df = pd.read_csv('./data/protein_id_conversion_df_init.csv')

# %%
uniprot_df.head(3)
# Out:
#      From   Entry    Reviewed    Entry Name  \
# 0  Q88P31  Q88P31  unreviewed  Q88P31_PSEPK
# 1  Q88C32  Q88C32  unreviewed  Q88C32_PSEPK
# 2  Q88RL1  Q88RL1    reviewed    ZNUC_PSEPK
#
#                                        Protein names        Gene Names  \
# 0  Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...  zwfA zwf PP_1022
# 1  Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...       zwf PP_5351
# 2  Zinc import ATP-binding protein ZnuC (EC 7.2.2...      znuC PP_0118
#
#                                             Organism  Length  \
# 0  Pseudomonas putida (strain ATCC 47054 / DSM 61...   489.0
# 1  Pseudomonas putida (strain ATCC 47054 / DSM 61...   485.0
# 2  Pseudomonas putida (strain ATCC 47054 / DSM 61...   257.0
#
#   Gene Names (ordered locus) Gene Names (primary) Gene Names (synonym)
# 0                    PP_1022                 zwfA                  zwf
# 1                    PP_5351                  zwf                  NaN
# 2                    PP_0118                 znuC                  NaN

# %%
edd_df.head(3)
# Out:
#                       original extracted
# 0                       P0AE22    P0AE22
# 1   sp|A9GAJ9|A9GAJ9_SORC5 Mcm    A9GAJ9
# 2  sp|K4JH65|K4JH65_9ACTN Gdnd    K4JH65

# %% [markdown]
# Rename uniprot df columns

# %%
uniprot_col_rename = {'Entry Name': 'entry_name', 'Protein names': 'protein_names',
                      'Gene Names': 'gene_names', 'Gene Names (ordered locus)': 'locus_name',
                     'Gene Names (primary)': 'primary_name', 'Gene Names (synonym)': 'synonym_name'}
uniprot_df = uniprot_df.rename(columns=uniprot_col_rename)
uniprot_df
# Out:
#         From   Entry    Reviewed    entry_name  \
# 0     Q88P31  Q88P31  unreviewed  Q88P31_PSEPK
# 1     Q88C32  Q88C32  unreviewed  Q88C32_PSEPK
# 2     Q88RL1  Q88RL1    reviewed    ZNUC_PSEPK
# 3     Q88F24  Q88F24    reviewed    ZIPA_PSEPK
# 4     Q88E29  Q88E29  unreviewed  Q88E29_PSEPK
# ...      ...     ...         ...           ...
# 2733  P04264  P04264    reviewed    K2C1_HUMAN
# 2734  Q835L3  Q835L3  unreviewed  Q835L3_ENTFA
# 2735  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2736  P00761  P00761    reviewed      TRYP_PIG
# 2737  Q88H72  Q88H72         NaN  Q88H72_PSEPK
#
#                                           protein_names        gene_names  \
# 0     Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...  zwfA zwf PP_1022
# 1     Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...       zwf PP_5351
# 2     Zinc import ATP-binding protein ZnuC (EC 7.2.2...      znuC PP_0118
# 3                            Cell division protein ZipA      zipA PP_4275
# 4     P-loop guanosine triphosphatase-dependent zinc...      zinU PP_4639
# ...                                                 ...               ...
# 2733  Keratin, type II cytoskeletal 1 (67 kDa cytoke...         KRT1 KRTA
# 2734  Acetyl-CoA acetyltransferase/hydroxymethylglut...           EF_1364
# 2735                                            deleted               NaN
# 2736                              Trypsin (EC 3.4.21.4)               NaN
# 2737                                            deleted               NaN
#
#                                                Organism  Length locus_name  \
# 0     Pseudomonas putida (strain ATCC 47054 / DSM 61...   489.0    PP_1022
# 1     Pseudomonas putida (strain ATCC 47054 / DSM 61...   485.0    PP_5351
# 2     Pseudomonas putida (strain ATCC 47054 / DSM 61...   257.0    PP_0118
# 3     Pseudomonas putida (strain ATCC 47054 / DSM 61...   297.0    PP_4275
# 4     Pseudomonas putida (strain ATCC 47054 / DSM 61...   323.0    PP_4639
# ...                                                 ...     ...        ...
# 2733                               Homo sapiens (Human)   644.0        NaN
# 2734  Enterococcus faecalis (strain ATCC 700802 / V583)   803.0    EF_1364
# 2735                                                NaN     NaN        NaN
# 2736                                   Sus scrofa (Pig)   231.0        NaN
# 2737                                                NaN     NaN        NaN
#
#      primary_name synonym_name
# 0            zwfA          zwf
# 1             zwf          NaN
# 2            znuC          NaN
# 3            zipA          NaN
# 4            zinU          NaN
# ...           ...          ...
# 2733         KRT1         KRTA
# 2734          NaN          NaN
# 2735          NaN          NaN
# 2736          NaN          NaN
# 2737          NaN          NaN
#
# [2738 rows x 11 columns]

# %% [markdown]
# ## Look at uniprot output

# %%
uniprot_df['Organism'].value_counts()
# Out:
# Organism
# Pseudomonas putida (strain ATCC 47054 / DSM 6125 / CFBP 8728 / NCIMB 11950 / KT2440)                               2712
# Homo sapiens (Human)                                                                                                  6
# Caulobacter vibrioides (strain ATCC 19089 / CB15) (Caulobacter crescentus)                                            1
# Enterococcus faecalis (strain ATCC 700802 / V583)                                                                     1
# Ovis aries (Sheep)                                                                                                    1
# Gallus gallus (Chicken)                                                                                               1
# Saccharomyces cerevisiae (strain ATCC 204508 / S288c) (Baker's yeast)                                                 1
# Hevea brasiliensis (Para rubber tree) (Siphonia brasiliensis)                                                         1
# Pseudomonas aeruginosa                                                                                                1
# Escherichia coli (strain K12)                                                                                         1
# Streptococcus pyogenes serotype M1                                                                                    1
# Streptomyces sp. K01-0509                                                                                             1
# Kitasatospora aureofaciens (Streptomyces aureofaciens)                                                                1
# Sorangium cellulosum (strain So ce56) (Polyangium cellulosum (strain So ce56))                                        1
# Enterococcus faecalis (Streptococcus faecalis)                                                                        1
# Methanosarcina mazei (strain ATCC BAA-159 / DSM 3647 / Goe1 / Go1 / JCM 11833 / OCM 88) (Methanosarcina frisia)       1
# Streptomyces nanchangensis                                                                                            1
# Klebsiella pneumoniae                                                                                                 1
# Mycolicibacterium smegmatis (strain ATCC 700084 / mc(2)155) (Mycobacterium smegmatis)                                 1
# Sus scrofa (Pig)                                                                                                      1
# Name: count, dtype: int64

# %% [markdown]
# Create flag for whether or not entry is from putida

# %%
pp_string = 'Pseudomonas putida (strain ATCC 47054 / DSM 6125 / CFBP 8728 / NCIMB 11950 / KT2440)'
uniprot_df['is_putida'] = uniprot_df['Organism'] == pp_string

# %%
uniprot_df.loc[~uniprot_df['is_putida'], :]
# Out:
#         From   Entry    Reviewed    entry_name  \
# 88    Q9A9Z2  Q9A9Z2    reviewed    XYLD_CAUVC
# 552   Q3L885  Q3L885  unreviewed  Q3L885_MYCS2
# 686   P00552  P00552    reviewed    KKA2_KLEPN
# 690   Q7WTF4  Q7WTF4  unreviewed  Q7WTF4_9ACTN
# 698   Q8PW39  Q8PW39  unreviewed  Q8PW39_METMA
# 699   Q9FD71  Q9FD71    reviewed   HMGCS_ENTFL
# 792   A9GAJ9  A9GAJ9  unreviewed  A9GAJ9_SORC5
# 832   Q30CS2  Q30CS2  unreviewed  Q30CS2_KITAU
# 1036  K4JH65  K4JH65  unreviewed  K4JH65_9ACTN
# 1338  Q99ZW2  Q99ZW2    reviewed    CAS9_STRP1
# 1431  P0AE22  P0AE22    reviewed    APHA_ECOLI
# 1491  P23181  P23181    reviewed   AACC1_PSEAI
# 1492  O82803  O82803    reviewed    SRPP_HEVBR
# 2725  P32377  P32377    reviewed    MVD1_YEAST
# 2726  P00698  P00698    reviewed    LYSC_CHICK
# 2727  P35527  P35527    reviewed    K1C9_HUMAN
# 2728  P78386  P78386    reviewed   KRT85_HUMAN
# 2729  Q9NSB2  Q9NSB2    reviewed   KRT84_HUMAN
# 2730  P35908  P35908    reviewed    K22E_HUMAN
# 2731  O77727  O77727    reviewed   K1C15_SHEEP
# 2732  P13645  P13645    reviewed   K1C10_HUMAN
# 2733  P04264  P04264    reviewed    K2C1_HUMAN
# 2734  Q835L3  Q835L3  unreviewed  Q835L3_ENTFA
# 2735  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2736  P00761  P00761    reviewed      TRYP_PIG
# 2737  Q88H72  Q88H72         NaN  Q88H72_PSEPK
#
#                                           protein_names  \
# 88    D-xylonate dehydratase (XyDHT) (EC 4.2.1.82) (...
# 552   Polyketide synthase (Type I modular polyketide...
# 686   Aminoglycoside 3'-phosphotransferase (EC 2.7.1...
# 690                                               NanA2
# 698          Mevalonate kinase (MK) (MVK) (EC 2.7.1.36)
# 699   Hydroxymethylglutaryl-CoA synthase (HMG-CoA sy...
# 792              Methylmalonyl-CoA mutase (EC 5.4.99.2)
# 832                                             LipPks1
# 1036                    3 hydroxyacyl CoA dehydrogenase
# 1338  CRISPR-associated endonuclease Cas9/Csn1 (EC 3...
# 1431       Class B acid phosphatase (CBAP) (EC 3.1.3.2)
# 1491  Gentamicin 3-N-acetyltransferase (EC 2.3.1.60)...
# 1492  Small rubber particle protein (HbSRPP) (22 kDa...
# 2725  Diphosphomevalonate decarboxylase (EC 4.1.1.33...
# 2726  Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...
# 2727  Keratin, type I cytoskeletal 9 (Cytokeratin-9)...
# 2728  Keratin, type II cuticular Hb5 (Hair keratin K...
# 2729  Keratin, type II cuticular Hb4 (Keratin-84) (K...
# 2730  Keratin, type II cytoskeletal 2 epidermal (Cyt...
# 2731  Keratin, type I cytoskeletal 15 (Cytokeratin-1...
# 2732  Keratin, type I cytoskeletal 10 (Cytokeratin-1...
# 2733  Keratin, type II cytoskeletal 1 (67 kDa cytoke...
# 2734  Acetyl-CoA acetyltransferase/hydroxymethylglut...
# 2735                                            deleted
# 2736                              Trypsin (EC 3.4.21.4)
# 2737                                            deleted
#
#                         gene_names  \
# 88                    xylD CC_0819
# 552                 pks MSMEG_0408
# 686                  neo kan nptII
# 690                          nanA2
# 698                    mvk MM_1762
# 699                           mvaS
# 792                    mcm sce2716
# 832                        lipPks1
# 1036                          gdnD
# 1338            cas9 csn1 SPy_1046
# 1431   aphA napA yjbP b4055 JW4015
# 1491                         aacC1
# 1492                    SRPP HEVB3
# 2725  MVD1 ERG19 MPD YNR043W N3427
# 2726                           LYZ
# 2727                          KRT9
# 2728                  KRT85 KRTHB5
# 2729                  KRT84 KRTHB4
# 2730              KRT2 KRT2A KRT2E
# 2731                         KRT15
# 2732                     KRT10 KPP
# 2733                     KRT1 KRTA
# 2734                       EF_1364
# 2735                           NaN
# 2736                           NaN
# 2737                           NaN
#
#                                                Organism  Length    locus_name  \
# 88    Caulobacter vibrioides (strain ATCC 19089 / CB...   595.0       CC_0819
# 552   Mycolicibacterium smegmatis (strain ATCC 70008...  3652.0    MSMEG_0408
# 686                               Klebsiella pneumoniae   264.0           NaN
# 690                          Streptomyces nanchangensis  2223.0           NaN
# 698   Methanosarcina mazei (strain ATCC BAA-159 / DS...   301.0       MM_1762
# 699      Enterococcus faecalis (Streptococcus faecalis)   383.0           NaN
# 792   Sorangium cellulosum (strain So ce56) (Polyang...   882.0       sce2716
# 832   Kitasatospora aureofaciens (Streptomyces aureo...  2259.0           NaN
# 1036                          Streptomyces sp. K01-0509   289.0           NaN
# 1338                 Streptococcus pyogenes serotype M1  1368.0      SPy_1046
# 1431                      Escherichia coli (strain K12)   237.0  b4055 JW4015
# 1491                             Pseudomonas aeruginosa   177.0           NaN
# 1492  Hevea brasiliensis (Para rubber tree) (Siphoni...   204.0           NaN
# 2725  Saccharomyces cerevisiae (strain ATCC 204508 /...   396.0       YNR043W
# 2726                            Gallus gallus (Chicken)   147.0           NaN
# 2727                               Homo sapiens (Human)   623.0           NaN
# 2728                               Homo sapiens (Human)   507.0           NaN
# 2729                               Homo sapiens (Human)   600.0           NaN
# 2730                               Homo sapiens (Human)   639.0           NaN
# 2731                                 Ovis aries (Sheep)   453.0           NaN
# 2732                               Homo sapiens (Human)   584.0           NaN
# 2733                               Homo sapiens (Human)   644.0           NaN
# 2734  Enterococcus faecalis (strain ATCC 700802 / V583)   803.0       EF_1364
# 2735                                                NaN     NaN           NaN
# 2736                                   Sus scrofa (Pig)   231.0           NaN
# 2737                                                NaN     NaN           NaN
#
#      primary_name synonym_name  is_putida
# 88           xylD          NaN      False
# 552           pks          NaN      False
# 686           neo    kan nptII      False
# 690         nanA2          NaN      False
# 698           mvk          NaN      False
# 699          mvaS          NaN      False
# 792           mcm          NaN      False
# 832       lipPks1          NaN      False
# 1036         gdnD          NaN      False
# 1338         cas9         csn1      False
# 1431         aphA    napA yjbP      False
# 1491        aacC1          NaN      False
# 1492         SRPP        HEVB3      False
# 2725         MVD1    ERG19 MPD      False
# 2726          LYZ          NaN      False
# 2727         KRT9          NaN      False
# 2728        KRT85       KRTHB5      False
# 2729        KRT84       KRTHB4      False
# 2730         KRT2  KRT2A KRT2E      False
# 2731        KRT15          NaN      False
# 2732        KRT10          KPP      False
# 2733         KRT1         KRTA      False
# 2734          NaN          NaN      False
# 2735          NaN          NaN      False
# 2736          NaN          NaN      False
# 2737          NaN          NaN      False

# %%
uniprot_df.loc[uniprot_df['is_putida'],:]
# Out:
#         From   Entry    Reviewed    entry_name  \
# 0     Q88P31  Q88P31  unreviewed  Q88P31_PSEPK
# 1     Q88C32  Q88C32  unreviewed  Q88C32_PSEPK
# 2     Q88RL1  Q88RL1    reviewed    ZNUC_PSEPK
# 3     Q88F24  Q88F24    reviewed    ZIPA_PSEPK
# 4     Q88E29  Q88E29  unreviewed  Q88E29_PSEPK
# ...      ...     ...         ...           ...
# 2720  Q88RW0  Q88RW0  unreviewed  Q88RW0_PSEPK
# 2721  Q88RW1  Q88RW1  unreviewed  Q88RW1_PSEPK
# 2722  Q88RW2  Q88RW2  unreviewed  Q88RW2_PSEPK
# 2723  P0A149  P0A149    reviewed    Y002_PSEPK
# 2724  Q88K32  Q88K32  unreviewed  Q88K32_PSEPK
#
#                                           protein_names        gene_names  \
# 0     Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...  zwfA zwf PP_1022
# 1     Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...       zwf PP_5351
# 2     Zinc import ATP-binding protein ZnuC (EC 7.2.2...      znuC PP_0118
# 3                            Cell division protein ZipA      zipA PP_4275
# 4     P-loop guanosine triphosphatase-dependent zinc...      zinU PP_4639
# ...                                                 ...               ...
# 2720                          Transcriptional regulator           PP_0019
# 2721                           TIGR04255 family protein           PP_0018
# 2722                          Transcriptional regulator           PP_0017
# 2723                    Uncharacterized protein PP_0002           PP_0002
# 2724  Ribonucleoside hydrolase (EC 3.2.2.-, EC 3.2.2.3)       Nuh PP_2460
#
#                                                Organism  Length locus_name  \
# 0     Pseudomonas putida (strain ATCC 47054 / DSM 61...   489.0    PP_1022
# 1     Pseudomonas putida (strain ATCC 47054 / DSM 61...   485.0    PP_5351
# 2     Pseudomonas putida (strain ATCC 47054 / DSM 61...   257.0    PP_0118
# 3     Pseudomonas putida (strain ATCC 47054 / DSM 61...   297.0    PP_4275
# 4     Pseudomonas putida (strain ATCC 47054 / DSM 61...   323.0    PP_4639
# ...                                                 ...     ...        ...
# 2720  Pseudomonas putida (strain ATCC 47054 / DSM 61...   232.0    PP_0019
# 2721  Pseudomonas putida (strain ATCC 47054 / DSM 61...   280.0    PP_0018
# 2722  Pseudomonas putida (strain ATCC 47054 / DSM 61...   119.0    PP_0017
# 2723  Pseudomonas putida (strain ATCC 47054 / DSM 61...   263.0    PP_0002
# 2724  Pseudomonas putida (strain ATCC 47054 / DSM 61...   322.0    PP_2460
#
#      primary_name synonym_name  is_putida
# 0            zwfA          zwf       True
# 1             zwf          NaN       True
# 2            znuC          NaN       True
# 3            zipA          NaN       True
# 4            zinU          NaN       True
# ...           ...          ...        ...
# 2720          NaN          NaN       True
# 2721          NaN          NaN       True
# 2722          NaN          NaN       True
# 2723          NaN          NaN       True
# 2724          Nuh          NaN       True
#
# [2712 rows x 12 columns]

# %% [markdown]
# ## Count how many genes have locus names or primary gene names

# %%
print(f"For p-putida proteins, there are N = {sum(uniprot_df.loc[uniprot_df['is_putida'], 'locus_name'].isna())} rows where locus_name is NaN")
print(f"There are N = {sum(uniprot_df['locus_name'].isna())} rows where locus_name is NaN")
uniprot_df.loc[uniprot_df['locus_name'].isna()]
# Out:
# For p-putida proteins, there are N = 0 rows where locus_name is NaN
# There are N = 18 rows where locus_name is NaN
#         From   Entry    Reviewed    entry_name  \
# 686   P00552  P00552    reviewed    KKA2_KLEPN
# 690   Q7WTF4  Q7WTF4  unreviewed  Q7WTF4_9ACTN
# 699   Q9FD71  Q9FD71    reviewed   HMGCS_ENTFL
# 832   Q30CS2  Q30CS2  unreviewed  Q30CS2_KITAU
# 1036  K4JH65  K4JH65  unreviewed  K4JH65_9ACTN
# 1491  P23181  P23181    reviewed   AACC1_PSEAI
# 1492  O82803  O82803    reviewed    SRPP_HEVBR
# 2726  P00698  P00698    reviewed    LYSC_CHICK
# 2727  P35527  P35527    reviewed    K1C9_HUMAN
# 2728  P78386  P78386    reviewed   KRT85_HUMAN
# 2729  Q9NSB2  Q9NSB2    reviewed   KRT84_HUMAN
# 2730  P35908  P35908    reviewed    K22E_HUMAN
# 2731  O77727  O77727    reviewed   K1C15_SHEEP
# 2732  P13645  P13645    reviewed   K1C10_HUMAN
# 2733  P04264  P04264    reviewed    K2C1_HUMAN
# 2735  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2736  P00761  P00761    reviewed      TRYP_PIG
# 2737  Q88H72  Q88H72         NaN  Q88H72_PSEPK
#
#                                           protein_names        gene_names  \
# 686   Aminoglycoside 3'-phosphotransferase (EC 2.7.1...     neo kan nptII
# 690                                               NanA2             nanA2
# 699   Hydroxymethylglutaryl-CoA synthase (HMG-CoA sy...              mvaS
# 832                                             LipPks1           lipPks1
# 1036                    3 hydroxyacyl CoA dehydrogenase              gdnD
# 1491  Gentamicin 3-N-acetyltransferase (EC 2.3.1.60)...             aacC1
# 1492  Small rubber particle protein (HbSRPP) (22 kDa...        SRPP HEVB3
# 2726  Lysozyme C (EC 3.2.1.17) (1,4-beta-N-acetylmur...               LYZ
# 2727  Keratin, type I cytoskeletal 9 (Cytokeratin-9)...              KRT9
# 2728  Keratin, type II cuticular Hb5 (Hair keratin K...      KRT85 KRTHB5
# 2729  Keratin, type II cuticular Hb4 (Keratin-84) (K...      KRT84 KRTHB4
# 2730  Keratin, type II cytoskeletal 2 epidermal (Cyt...  KRT2 KRT2A KRT2E
# 2731  Keratin, type I cytoskeletal 15 (Cytokeratin-1...             KRT15
# 2732  Keratin, type I cytoskeletal 10 (Cytokeratin-1...         KRT10 KPP
# 2733  Keratin, type II cytoskeletal 1 (67 kDa cytoke...         KRT1 KRTA
# 2735                                            deleted               NaN
# 2736                              Trypsin (EC 3.4.21.4)               NaN
# 2737                                            deleted               NaN
#
#                                                Organism  Length locus_name  \
# 686                               Klebsiella pneumoniae   264.0        NaN
# 690                          Streptomyces nanchangensis  2223.0        NaN
# 699      Enterococcus faecalis (Streptococcus faecalis)   383.0        NaN
# 832   Kitasatospora aureofaciens (Streptomyces aureo...  2259.0        NaN
# 1036                          Streptomyces sp. K01-0509   289.0        NaN
# 1491                             Pseudomonas aeruginosa   177.0        NaN
# 1492  Hevea brasiliensis (Para rubber tree) (Siphoni...   204.0        NaN
# 2726                            Gallus gallus (Chicken)   147.0        NaN
# 2727                               Homo sapiens (Human)   623.0        NaN
# 2728                               Homo sapiens (Human)   507.0        NaN
# 2729                               Homo sapiens (Human)   600.0        NaN
# 2730                               Homo sapiens (Human)   639.0        NaN
# 2731                                 Ovis aries (Sheep)   453.0        NaN
# 2732                               Homo sapiens (Human)   584.0        NaN
# 2733                               Homo sapiens (Human)   644.0        NaN
# 2735                                                NaN     NaN        NaN
# 2736                                   Sus scrofa (Pig)   231.0        NaN
# 2737                                                NaN     NaN        NaN
#
#      primary_name synonym_name  is_putida
# 686           neo    kan nptII      False
# 690         nanA2          NaN      False
# 699          mvaS          NaN      False
# 832       lipPks1          NaN      False
# 1036         gdnD          NaN      False
# 1491        aacC1          NaN      False
# 1492         SRPP        HEVB3      False
# 2726          LYZ          NaN      False
# 2727         KRT9          NaN      False
# 2728        KRT85       KRTHB5      False
# 2729        KRT84       KRTHB4      False
# 2730         KRT2  KRT2A KRT2E      False
# 2731        KRT15          NaN      False
# 2732        KRT10          KPP      False
# 2733         KRT1         KRTA      False
# 2735          NaN          NaN      False
# 2736          NaN          NaN      False
# 2737          NaN          NaN      False

# %%
print(f"For p-putida proteins, there are N = {sum(uniprot_df.loc[uniprot_df['is_putida'], 'primary_name'].isna())} rows where primary_name is NaN")
print(f"There are N = {sum(uniprot_df['primary_name'].isna())} rows where primary_name is NaN")
uniprot_df.loc[uniprot_df['primary_name'].isna()]
# Out:
# For p-putida proteins, there are N = 1231 rows where primary_name is NaN
# There are N = 1235 rows where primary_name is NaN
#         From   Entry    Reviewed    entry_name  \
# 1493  Q88BX7  Q88BX7  unreviewed  Q88BX7_PSEPK
# 1494  Q88BY6  Q88BY6  unreviewed  Q88BY6_PSEPK
# 1495  Q88BY7  Q88BY7  unreviewed  Q88BY7_PSEPK
# 1496  Q88BY9  Q88BY9  unreviewed  Q88BY9_PSEPK
# 1497  Q88BZ1  Q88BZ1  unreviewed  Q88BZ1_PSEPK
# ...      ...     ...         ...           ...
# 2723  P0A149  P0A149    reviewed    Y002_PSEPK
# 2734  Q835L3  Q835L3  unreviewed  Q835L3_ENTFA
# 2735  Q88P68  Q88P68         NaN  Q88P68_PSEPK
# 2736  P00761  P00761    reviewed      TRYP_PIG
# 2737  Q88H72  Q88H72         NaN  Q88H72_PSEPK
#
#                                           protein_names gene_names  \
# 1493             Transcriptional regulator, DeoR family    PP_5410
# 1494                      PIN domain-containing protein    PP_5401
# 1495     IrrE N-terminal-like domain-containing protein    PP_5400
# 1496  N(4)-bis(aminopropyl)spermidine synthase C-ter...    PP_5395
# 1497       Beta-propeller fold lactonase family protein    PP_5392
# ...                                                 ...        ...
# 2723                    Uncharacterized protein PP_0002    PP_0002
# 2734  Acetyl-CoA acetyltransferase/hydroxymethylglut...    EF_1364
# 2735                                            deleted        NaN
# 2736                              Trypsin (EC 3.4.21.4)        NaN
# 2737                                            deleted        NaN
#
#                                                Organism  Length locus_name  \
# 1493  Pseudomonas putida (strain ATCC 47054 / DSM 61...   258.0    PP_5410
# 1494  Pseudomonas putida (strain ATCC 47054 / DSM 61...   213.0    PP_5401
# 1495  Pseudomonas putida (strain ATCC 47054 / DSM 61...   355.0    PP_5400
# 1496  Pseudomonas putida (strain ATCC 47054 / DSM 61...   281.0    PP_5395
# 1497  Pseudomonas putida (strain ATCC 47054 / DSM 61...   340.0    PP_5392
# ...                                                 ...     ...        ...
# 2723  Pseudomonas putida (strain ATCC 47054 / DSM 61...   263.0    PP_0002
# 2734  Enterococcus faecalis (strain ATCC 700802 / V583)   803.0    EF_1364
# 2735                                                NaN     NaN        NaN
# 2736                                   Sus scrofa (Pig)   231.0        NaN
# 2737                                                NaN     NaN        NaN
#
#      primary_name synonym_name  is_putida
# 1493          NaN          NaN       True
# 1494          NaN          NaN       True
# 1495          NaN          NaN       True
# 1496          NaN          NaN       True
# 1497          NaN          NaN       True
# ...           ...          ...        ...
# 2723          NaN          NaN       True
# 2734          NaN          NaN      False
# 2735          NaN          NaN      False
# 2736          NaN          NaN      False
# 2737          NaN          NaN      False
#
# [1235 rows x 12 columns]

# %% [markdown]
# ## Create dataframe to convert between proteomics label and different uniprot labels

# %%
edd_df
# Out:
#                          original extracted
# 0                          P0AE22    P0AE22
# 1      sp|A9GAJ9|A9GAJ9_SORC5 Mcm    A9GAJ9
# 2     sp|K4JH65|K4JH65_9ACTN Gdnd    K4JH65
# 3                       sp|O77727    O77727
# 4                       sp|O82803    O82803
# ...                           ...       ...
# 2733       tr|Q88QV1|Q88QV1_PSEPK    Q88QV1
# 2734       tr|Q88QV2|Q88QV2_PSEPK    Q88QV2
# 2735       tr|Q88RH1|Q88RH1_PSEPK    Q88RH1
# 2736       tr|Q88RH2|Q88RH2_PSEPK    Q88RH2
# 2737       tr|Q8PW39|Q8PW39_METMA    Q8PW39
#
# [2738 rows x 2 columns]

# %%
edd_df['locus'] = [uniprot_df.loc[uniprot_df['From'] == x, 'locus_name'].values[0] for x in edd_df['extracted']]
edd_df['primary_name'] = [uniprot_df.loc[uniprot_df['From'] == x, 'primary_name'].values[0] for x in edd_df['extracted']]
edd_df['organism'] = [uniprot_df.loc[uniprot_df['From'] == x, 'Organism'].values[0] for x in edd_df['extracted']]
edd_df['is_putida'] = edd_df['organism'] == pp_string

# %%
edd_df.head(3)
# Out:
#                       original extracted         locus primary_name  \
# 0                       P0AE22    P0AE22  b4055 JW4015         aphA
# 1   sp|A9GAJ9|A9GAJ9_SORC5 Mcm    A9GAJ9       sce2716          mcm
# 2  sp|K4JH65|K4JH65_9ACTN Gdnd    K4JH65           NaN         gdnD
#
#                                             organism  is_putida
# 0                      Escherichia coli (strain K12)      False
# 1  Sorangium cellulosum (strain So ce56) (Polyang...      False
# 2                          Streptomyces sp. K01-0509      False

# %%
edd_df.to_csv('./data/proteomics_id_translator.csv', index=False, header=True)
