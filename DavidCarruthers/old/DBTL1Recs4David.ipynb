# %% [markdown]
# # Produce two and three knock-downs recommendations

# %% [markdown]
# This notebook explains how to produce recommendations for knockdown of two and three genes for the CRISPRi project with David Carruthers and Taek Soon Lee.

# %% [markdown]
# Tested using "ART Prod v.master.535f34c" kernel on skynet.ese.lbl

# %% [markdown]
# ## Input and output

# %% [markdown]
# Required files to run this notebook:
#
# - ``Sample name, CRISPRi target gene, Uniprot ID.xlsx`` : file with mapping from Uniprot protein IDs to PP_XXXX gene numbers
#
# Files generated by running this notebook:
#
# - ``CRISPRi_double_targets.csv`` : file with double knock-down recommendations
# - ``CRISPRi_triple_targets.csv`` : file with triple knock-down recommendations

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import edd_utils as eddu
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re 
import random

# %% [markdown]
# ### User parameters

# %%
user_params = {
    'output_dir'  : './results',
    'protein_map' : './data/Sample name, CRISPRi target gene, Uniprot ID.xlsx',
    'double_targets_file': f'./data/CRISPRi_double_targets.csv',
    'triple_targets_file': f'./data/CRISPRi_triple_targets.csv',
}

# %%
ls
# Out:
# data/  DBTL1Recs4David.ipynb  results/

# %% [markdown]
# ### Useful functions

# %%
def create_strain_names(df: pd.DataFrame):
    "Creates strain names by reading Line Description and eliminating Biolector culture info."
    strains = [
        line_name.split('_')[1] for line_name in df["Line Description"].to_list()
    ]
    return strains

# %%
def plot_titers(df_prod, df_control_stat, product='Isoprenol'):
    "Plots isprenols titers as well as CV"
    "NOT REALLY WORKING AS OF NOW"
    
    ## Create fig
    fig, ax = plt.subplots(figsize=(25, 5))
    sns.set_style("white")
    
    ## Plot production in salmon color
    g = sns.scatterplot(data=df_prod, 
                      x='Strain',
                      y=product,
                      color='salmon',
                  )
    ## Surround controls with black edge 
    #To do so, have to figure out where on the x axis the control 'NT' is
    
    all_x_lbls = g.get_xticklabels()
    lbl_text = [lbl.get_text() for lbl in all_x_lbls]
    x_index = lbl_text.index('NT')
    
    #use the NT x location to place control points
    
    plt.scatter(np.ones(df_control_stat['Isoprenol'].shape)*x_index, df_control_stat[product],
                marker='o', color="None", edgecolor='k', label='Control'
                )
    ## Label axes
    g.set_xticklabels(df_prod.index.unique(), fontsize=10, rotation = 90)
    ax.set_ylabel(product+" [uM]", fontsize=10, color='salmon')
    ax.set_xlabel("Strains", fontsize=10)
    ax2 = plt.twinx()
    g2 = sns.scatterplot(data=df_prod,
                    x='Strain',
                    y='CV[%]', 
                    color='gray', marker='o',
                        ax=ax2)
    plt.scatter([1], df_control_stat['CV[%]'].iloc[0],
                marker='o', color="None",  edgecolor='k', label='Control'
                )
    ax2.set_ylabel("CV[%]", fontsize=10, color='gray')
    sns.despine(left=True, bottom=True)
    ax.legend()

    fig.savefig(
        f"{user_params['output_dir']}/titer_cv.png",
        transparent=True,
        bbox_inches="tight",
        dpi=300,
    )

# %%
def find_library_stats(df):
    """Find mean, std and quartiles of the target transcription level from the whole library excluding the target strain"""
    
    stat_names = ['Library_mean', 'Library_std', 'Library_Q1', 'Library_Q3']
    for n in stat_names:
        df.loc[n] = None
        df.loc[n].astype('float64')

    no_data =[]
    for target in df['Target'].dropna():
        if target in df_targets.columns:
            # Exclude the target strain from the mean
            ind = df.index[df['Target']==target].tolist()       
            ind.extend(stat_names)

            mean = df.drop(index=ind)[target].mean()
            df.loc['Library_mean', target] = mean

            std = df.drop(index=ind)[target].std()
            df.loc['Library_std', target] = std

            q1 = df.drop(index=ind)[target].quantile(.25)
            q3 = df.drop(index=ind)[target].quantile(.75)
            df.loc['Library_Q1', target] = q1
            df.loc['Library_Q3', target] = q3
        else:
            #no_data.append((df_targets[df_targets.loc[:,"Target"]==target].index.tolist(),target))
            no_data.append(target)
            
    print(f"Data for these {len(no_data)} proteins was not present:")
    print(no_data)
            
        
    return df

# %%
def find_fold_changes(df):
    """Find fold changes of the transcription in the targeted strain vs library"""
    
    col_names = [
        'Target:Control', 
        'Target:Library_mean', 
        'Target:Library_Q1', 
        'Target:Library_Q3',
        'Z-score'
    ]
    df[col_names] = None

    no_data = []
    for target in df['Target'].dropna():
        if target in df.columns:
            ind = df.index[df['Target']==target][0]

            df.loc[
                ind, 'Target:Control'
            ] = df.loc[ind, target] / df.loc[control_strain, target]

            mean = df.loc['Library_mean'][target]
            std = df.loc['Library_std'][target]

            df.loc[
                ind, 'Target:Library_mean'
            ] = df.loc[ind, target] / mean

            df.loc[
                ind, 'Target:Library_Q1'
            ] = df.loc[ind, target] / df.loc['Library_Q1'][target]
            df.loc[
                ind, 'Target:Library_Q3'
            ] = df.loc[ind, target] / df.loc['Library_Q3'][target]

            df.loc[
                ind, 'Z-score'
            ] = (df.loc[ind, target] - mean) / std
        else:
            no_data.append(target)
            
    print("Data for these "+str(len(no_data))+" proteins was not present:")
    print(no_data)
    
    return df

# %%
def choose_targets(df_targets, size, n_instances, weighting=True, verbose=0):
    "Choose recommended double and triple targets for CRISPRi knockdown"

    targets_list = list(df_targets['Target'])
    targets = set()
    tries = 0
    if weighting:
        weights = df_targets['Weight']
    else:
        weights = None
    
    while len(targets) < n_instances:
        new_target = tuple(sorted(random.sample(
            targets_list, counts=weights, k=size
        ))) # random sampling without replacement
        # new_target = sorted(random.choices(targets_list, weights=weights, k=size))
        # Check that the targets are not the same (sample function could provide repeated targets)
        # and if the combination was already chosen
        if len(set(new_target)) == size and new_target not in targets:
            targets.add(new_target)
        tries += 1
        
    if verbose:
        print(tries)
        
    return list(targets)

# %%
 def plot_double_targets(targets_double, df_targets):
    "Plot double targets chosen with the function above"    
        
    fig, ax = plt.subplots(figsize=(7, 11), nrows=2)
    fig.patch.set_facecolor("white")

    n_targets = len(df_targets)
    
    target1 = [target[0] for target in targets_double]
    target2 = [target[1] for target in targets_double]

    x = [df_targets[df_targets['Target']==target].index[0] for target in target1]
    y = [df_targets[df_targets['Target']==target].index[0] for target in target2]

    ax[0].plot(x, y, 'o')
    ax[0].set_xlabel('Target 1')
    ax[0].set_ylabel('Target 2')
    ax[0].set_yticks(range(n_targets), df_targets['Target'].values)
    ax[0].set_xticks(range(n_targets), df_targets['Target'].values, rotation='vertical')
    ax[0].set_title("Double targets")

    x.extend(y)
    ax[1].hist(x, bins=range(n_targets+1), rwidth=0.9, align='left')
    ax[1].set_xticks(range(n_targets), df_targets['Target'].values, rotation='vertical')
    t = ax[1].set_ylabel("Frequency of targets")

# %%
 def plot_triple_targets(targets_triple, df_targets):
    "Plot triple targets chosen with the function above"    
   
    fig, ax = plt.subplots(figsize=(7, 5))
    fig.patch.set_facecolor("white")
    
    n_targets = len(df_targets)

    target1 = [target[0] for target in targets_triple]
    target2 = [target[1] for target in targets_triple]
    target3 = [target[2] for target in targets_triple]

    x = [df_targets[df_targets['Target']==target].index[0] for target in target1]
    y = [df_targets[df_targets['Target']==target].index[0] for target in target2]
    z = [df_targets[df_targets['Target']==target].index[0] for target in target3]

    x.extend(y)
    x.extend(z)
    ax.hist(x, bins=range(n_targets+1), rwidth=0.8, align='left')
    ax.set_xticks(range(n_targets), df_targets['Target'].values, rotation='vertical')
    # ax.set_xticks(range(n_targets), range(n_targets), rotation='vertical')
    t = ax.set_ylabel("Frequency of targets")

# %% [markdown]
# ## Download the data

# %% [markdown]
# These are the [Experiment Data Depot](https://pubs.acs.org/doi/full/10.1021/acssynbio.7b00204) server, the corresponding username and the slug (address) for the study to be downloaded:

# %%
study_slug_1 = 'crispri-automation-for-isoprenol-production-in-p-p'
edd_server   = 'edd.jbei.org'
username     = 'pckinnunen'

# %% [markdown]
# We try connecting to the server with our login and password:

# %%
try:
    session = eddu.login(edd_server=edd_server, user=username)
except:
    print('ERROR! Connection to EDD failed. We will try to load data from disk...')
else:
    print('OK! Connection to EDD successful. We will try to load data from EDD...')
# Out:
# Password for pckinnunen:  ········
# OK! Connection to EDD successful. We will try to load data from EDD...

# %% [markdown]
# And then we try to export the study from the EDD instance:

# %%
try:
    df = eddu.export_study(session, study_slug_1, edd_server=edd_server)
except (NameError, AttributeError, KeyError):
    print(f'ERROR! Not able to export the study.')
# Out:
# 100%|██████████| 1182270/1182270 [01:03<00:00, 18585.82it/s]

# %% [markdown]
# There are lots of data here (particularly the biolector data takes a lot of space):

# %% [markdown]
# Let's have a look at the different protocols (types of data) that are includeed in the study:

# %%
df['Protocol'].unique()
# Out:
# array(['Biolector', 'GC-FID', 'Global Proteomics'], dtype=object)

# %% [markdown]
# ## Preprocess and inspect data

# %% [markdown]
# View the dataframe - Approximately 1mm rows and 15 columns.

# %%
df
# Out:
#          Study ID                                         Study Name  Line ID  \
# 0          174984  CRISPRi automation for isoprenol production in...   175000
# 1          174984  CRISPRi automation for isoprenol production in...   175000
# 2          174984  CRISPRi automation for isoprenol production in...   175000
# 3          174984  CRISPRi automation for isoprenol production in...   175000
# 4          174984  CRISPRi automation for isoprenol production in...   175000
# ...           ...                                                ...      ...
# 1182265    174984  CRISPRi automation for isoprenol production in...   175409
# 1182266    174984  CRISPRi automation for isoprenol production in...   175416
# 1182267    174984  CRISPRi automation for isoprenol production in...   175401
# 1182268    174984  CRISPRi automation for isoprenol production in...   175408
# 1182269    174984  CRISPRi automation for isoprenol production in...   175415
#
#                                 Replicate Key   Line Name Line Description  \
# 0        5457c5b3-222c-41b3-8ea9-6b89b807635e  Control-R1         BL1A1_NT
# 1        5457c5b3-222c-41b3-8ea9-6b89b807635e  Control-R1         BL1A1_NT
# 2        5457c5b3-222c-41b3-8ea9-6b89b807635e  Control-R1         BL1A1_NT
# 3        5457c5b3-222c-41b3-8ea9-6b89b807635e  Control-R1         BL1A1_NT
# 4        5457c5b3-222c-41b3-8ea9-6b89b807635e  Control-R1         BL1A1_NT
# ...                                       ...         ...              ...
# 1182265  973dabc2-3963-4074-bab2-b0d238a6c6c4  PP_5416-R2    BL10B5_IY2022
# 1182266  c4c6b68c-ff3d-4508-8ab8-647cd03a542b  PP_5416-R3    BL10C5_IY2022
# 1182267  c047889a-5a7b-44e5-bd20-bdf25e782759  PP_5420-R1    BL10A4_IY2019
# 1182268  68460590-ea65-4029-90f5-ee602c11690d  PP_5420-R2    BL10B4_IY2019
# 1182269  9ff50030-1548-45d7-9449-bb59e3bf3a09  PP_5420-R3    BL10C4_IY2019
#
#                   Protocol  Assay ID  Assay Name               Formal Type  \
# 0                Biolector    175420  Control-R1                       NaN
# 1                Biolector    175420  Control-R1                       NaN
# 2                Biolector    175420  Control-R1                       NaN
# 3                Biolector    175420  Control-R1                       NaN
# 4                Biolector    175420  Control-R1                       NaN
# ...                    ...       ...         ...                       ...
# 1182265  Global Proteomics    177370  PP_5416-R2  sp|Q9Z408|CSD_PSEPK Csda
# 1182266  Global Proteomics    177377  PP_5416-R3  sp|Q9Z408|CSD_PSEPK Csda
# 1182267  Global Proteomics    177362  PP_5420-R1  sp|Q9Z408|CSD_PSEPK Csda
# 1182268  Global Proteomics    177369  PP_5420-R2  sp|Q9Z408|CSD_PSEPK Csda
# 1182269  Global Proteomics    177376  PP_5420-R3  sp|Q9Z408|CSD_PSEPK Csda
#
#                       Measurement Type  Compartment   Units       Value  \
# 0                  Total Biomass Input            0     NaN        3.15
# 1                  Total Biomass Input            0     NaN        3.12
# 2                  Total Biomass Input            0     NaN        3.14
# 3                  Total Biomass Input            0     NaN        3.13
# 4                  Total Biomass Input            0     NaN        3.16
# ...                                ...          ...     ...         ...
# 1182265  Probable cysteine desulfurase            0  counts  1051686.97
# 1182266  Probable cysteine desulfurase            0  counts   992141.10
# 1182267  Probable cysteine desulfurase            0  counts   594914.52
# 1182268  Probable cysteine desulfurase            0  counts   386573.66
# 1182269  Probable cysteine desulfurase            0  counts  1419732.20
#
#             Hours
# 0         0.01028
# 1         0.09361
# 2         0.17694
# 3         0.26028
# 4         0.34361
# ...           ...
# 1182265  24.00000
# 1182266  24.00000
# 1182267  24.00000
# 1182268  24.00000
# 1182269  24.00000
#
# [1182270 rows x 15 columns]

# %% [markdown]
# Also - How many columns contain variables, and how many different entries are in each column?

# %%
df[:].nunique()
# Out:
# Study ID                 1
# Study Name               1
# Line ID                426
# Replicate Key          426
# Line Name              426
# Line Description       422
# Protocol                 3
# Assay ID              1266
# Assay Name             426
# Formal Type           2696
# Measurement Type      2005
# Compartment              1
# Units                    2
# Value               775676
# Hours                 2718
# dtype: int64

# %% [markdown]
# This dataframe represents a signle study ID+name. We can see that there are 426 lines, but for some reason only 422 Descriptions. Also, unclear to me why the Assay Name column has the same number of unique values as the Line ID.
#
# There are only a few unique units + protocols. I'm curious what they are:

# %%
print('Unique protocols')
print(df['Protocol'].unique())
print('Unique Units')
print(df['Units'].unique())
# Out:
# Unique protocols
# ['Biolector' 'GC-FID' 'Global Proteomics']
# Unique Units
# [nan 'mg/L' 'counts']

# %% [markdown]
# ### Eliminate biolector data

# %% [markdown]
# For our current purposes, we don't need the biolector data, so let's get rid of it (we can always recover it later):

# %%
df['Protocol']=='Biolector'
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1182265    False
# 1182266    False
# 1182267    False
# 1182268    False
# 1182269    False
# Name: Protocol, Length: 1182270, dtype: bool

# %%
df2 = df.loc[df['Protocol']!='Biolector']

# %% [markdown]
# And we still have over a million entries of data:

# %%
df2.shape
# Out:
# (1033140, 15)

# %% [markdown]
# Let's just keep the basic data types:

# %%
df2 = df2.loc[:,['Line Name', 'Line Description', 'Protocol','Formal Type', 'Measurement Type', 'Value']]

# %% [markdown]
# Let's have a look a the lines we have here:

# %%
line_desc = df2['Line Description'].unique()
len(line_desc), line_desc
# Out:
# (420,
#  array(['BL1A2_IY1586', 'BL1A3_IY1587', 'BL1A4_IY1588', 'BL1A5_IY1589',
#         'BL1A6_IY1590', 'BL1A7_IY1591', 'BL1A8_IY1592', 'BL1B2_IY1586',
#         'BL1B3_IY1587', 'BL1B4_IY1588', 'BL1B5_IY1589', 'BL1B6_IY1590',
#         'BL1B7_IY1591', 'BL1B8_IY1592', 'BL1C2_IY1586', 'BL1C3_IY1587',
#         'BL1C4_IY1588', 'BL1C5_IY1589', 'BL1C6_IY1590', 'BL1C7_IY1591',
#         'BL1C8_IY1592', 'BL1D1_IY1593', 'BL1D2_IY1594', 'BL1D3_IY1595',
#         'BL1D4_IY1596', 'BL1D5_IY1597', 'BL1D6_IY1452_pIY1081',
#         '**BL1D7_IY1655', '**BL1D8_IY1656', '**BL1E1_IY1593',
#         '**BL1E2_IY1594', '**BL1E3_IY1595', 'BL1E4_IY1596', 'BL1E5_IY1597',
#         'BL1E6_IY1452_pIY1081', 'BL1E7_IY1655', 'BL1E8_IY1656',
#         'BL1F1_IY1593', 'BL1F2_IY1594', 'BL1F3_IY1595', 'BL1F4_IY1596',
#         'BL1F5_IY1597', 'BL1F6_IY1452_pIY1081', 'BL1F7_IY1655',
#         'BL1F8_IY1656', 'BL2A2_IY1452_pIY1079', 'BL2A3_IY1452_pIY1080',
#         'BL2A4_IY1657', 'BL2A5_IY1658', 'BL2A6_IY1659', 'BL2A7_IY1660',
#         'BL2A8_IY1661', 'BL2B2_IY1452_pIY1079', 'BL2B3_IY1452_pIY1080',
#         'BL2B4_IY1657', 'BL2B5_IY1658', 'BL2B6_IY1659', 'BL2B7_IY1660',
#         'BL2B8_IY1661', 'BL2C2_IY1452_pIY1079', 'BL2C3_IY1452_pIY1080',
#         'BL2C4_IY1657', 'BL2C5_IY1658', 'BL2C6_IY1659', 'BL2C7_IY1660',
#         'PP_4012-R2', 'PP_4185-R2', 'PP_4186-R2', 'PP_4119-R2',
#         'PP_4120-R2', 'PP_2112-R3', 'PP_2339-R3', 'PP_4011-R3',
#         'PP_4012-R3', 'PP_4185-R3', 'PP_4186-R3', 'PP_4119-R3',
#         'PP_4120-R3', 'PP_4123-R1', 'PP_4128-R1', 'PP_5420-R1',
#         'PP_5416-R1', 'PP_1607_NT1-R4', 'PP_4679-R4', 'PP_4678-R4',
#         'PP_4123-R2', 'PP_4128-R2', 'PP_5420-R2', 'PP_5416-R2',
#         'PP_1607_NT1-R5', 'PP_4679-R5', 'PP_4678-R5', 'PP_4123-R3',
#         'PP_4128-R3', 'PP_5420-R3', 'PP_5416-R3', 'PP_1607_NT1-R6',
#         'PP_4679-R6', 'PP_4678-R6', 'Control-R1', 'Control-R2',
#         'Control-R3', 'Control-R4', 'Control-R5', 'Control-R6',
#         'Control-R7', 'Control-R8', 'Control-R9', 'Control-R10',
#         'Control-R11', 'Control-R12', 'Control-R13', 'Control-R14',
#         'Control-R15', 'Control-R16', 'Control-R17', 'Control-R18'],
#        dtype=object))

# %%
df2['Formal Type'].unique()
# Out:
# array(['cid:12988', 'sp|O85207|PHAG_PSEPK Phag',
#        'sp|P00552|KKA2_KLEPN Neo', ..., 'sp|Q88RM6|Q88RM6_PSEPK Pp_0103',
#        'sp|Q88RS8|Q88RS8_PSEPK Pp_0051', 'sp|Q88RV6|Q88RV6_PSEPK Pp_0023'],
#       dtype=object)

# %%
df2['Protocol'].unique()
# Out:
# array(['GC-FID', 'Global Proteomics'], dtype=object)

# %%
df2[df2['Protocol']=='GC-FID']['Measurement Type'].unique()
# Out:
# array(['3-METHYL-3-BUTEN-1-OL'], dtype=object)

# %%
df2
# Out:
#           Line Name Line Description           Protocol  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID
# ...             ...              ...                ...
# 1182265  PP_5416-R2    BL10B5_IY2022  Global Proteomics
# 1182266  PP_5416-R3    BL10C5_IY2022  Global Proteomics
# 1182267  PP_5420-R1    BL10A4_IY2019  Global Proteomics
# 1182268  PP_5420-R2    BL10B4_IY2019  Global Proteomics
# 1182269  PP_5420-R3    BL10C4_IY2019  Global Proteomics
#
#                       Formal Type               Measurement Type         Value
# 149130                  cid:12988          3-METHYL-3-BUTEN-1-OL  2.989604e+02
# 149131                  cid:12988          3-METHYL-3-BUTEN-1-OL  1.673975e+02
# 149132                  cid:12988          3-METHYL-3-BUTEN-1-OL  3.405714e+02
# 149133                  cid:12988          3-METHYL-3-BUTEN-1-OL  3.485097e+02
# 149134                  cid:12988          3-METHYL-3-BUTEN-1-OL  2.151588e+02
# ...                           ...                            ...           ...
# 1182265  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase  1.051687e+06
# 1182266  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase  9.921411e+05
# 1182267  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase  5.949145e+05
# 1182268  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase  3.865737e+05
# 1182269  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase  1.419732e+06
#
# [1033140 rows x 6 columns]

# %%
df2.head()
# Out:
#          Line Name Line Description Protocol Formal Type  \
# 149130  PP_4549-R1     BL1A2_IY1586   GC-FID   cid:12988
# 149131  PP_4550-R1     BL1A3_IY1587   GC-FID   cid:12988
# 149132  PP_0368-R1     BL1A4_IY1588   GC-FID   cid:12988
# 149133  PP_2136-R1     BL1A5_IY1589   GC-FID   cid:12988
# 149134  PP_0774-R1     BL1A6_IY1590   GC-FID   cid:12988
#
#              Measurement Type     Value
# 149130  3-METHYL-3-BUTEN-1-OL  298.9604
# 149131  3-METHYL-3-BUTEN-1-OL  167.3975
# 149132  3-METHYL-3-BUTEN-1-OL  340.5714
# 149133  3-METHYL-3-BUTEN-1-OL  348.5097
# 149134  3-METHYL-3-BUTEN-1-OL  215.1588

# %% [markdown]
# ### Get strain names

# %% [markdown]
# Next we stores the Strain names (from the line description) in a separate column for later use:

# %%
df2["Strain"] = create_strain_names(df2)

# %%
df2
# Out:
#           Line Name Line Description           Protocol  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID
# ...             ...              ...                ...
# 1182265  PP_5416-R2    BL10B5_IY2022  Global Proteomics
# 1182266  PP_5416-R3    BL10C5_IY2022  Global Proteomics
# 1182267  PP_5420-R1    BL10A4_IY2019  Global Proteomics
# 1182268  PP_5420-R2    BL10B4_IY2019  Global Proteomics
# 1182269  PP_5420-R3    BL10C4_IY2019  Global Proteomics
#
#                       Formal Type               Measurement Type  \
# 149130                  cid:12988          3-METHYL-3-BUTEN-1-OL
# 149131                  cid:12988          3-METHYL-3-BUTEN-1-OL
# 149132                  cid:12988          3-METHYL-3-BUTEN-1-OL
# 149133                  cid:12988          3-METHYL-3-BUTEN-1-OL
# 149134                  cid:12988          3-METHYL-3-BUTEN-1-OL
# ...                           ...                            ...
# 1182265  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase
# 1182266  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase
# 1182267  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase
# 1182268  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase
# 1182269  sp|Q9Z408|CSD_PSEPK Csda  Probable cysteine desulfurase
#
#                 Value  Strain
# 149130   2.989604e+02  IY1586
# 149131   1.673975e+02  IY1587
# 149132   3.405714e+02  IY1588
# 149133   3.485097e+02  IY1589
# 149134   2.151588e+02  IY1590
# ...               ...     ...
# 1182265  1.051687e+06  IY2022
# 1182266  9.921411e+05  IY2022
# 1182267  5.949145e+05  IY2019
# 1182268  3.865737e+05  IY2019
# 1182269  1.419732e+06  IY2019
#
# [1033140 rows x 7 columns]

# %%
(df2['Strain'].unique())
# Out:
# array(['IY1586', 'IY1587', 'IY1588', 'IY1589', 'IY1590', 'IY1591',
#        'IY1592', 'IY1593', 'IY1594', 'IY1595', 'IY1596', 'IY1597',
#        'IY1452', 'IY1655', 'IY1656', 'IY1657', 'IY1658', 'IY1659',
#        'IY1660', 'IY1661', 'IY1662', 'IY1663', 'IY1664', 'IY1665',
#        'IY1666', 'IY1667', 'IY1668', 'IY1669', 'IY1670', 'IY1671',
#        'IY1672', 'IY1673', 'IY1674', 'IY1675', 'IY1676', 'IY1677',
#        'IY1678', 'IY1679', 'IY1680', 'IY1682', 'IY1683', 'IY1684',
#        'IY1685', 'IY1686', 'IY1687', 'IY1688', 'IY1689', 'IY1690',
#        'IY1681', 'IY2020', 'IY2021', 'IY2023', 'IY2024', 'IY2054',
#        'IY2027', 'IY2028', 'IY2031', 'IY2033', 'IY2034', 'IY2055',
#        'IY2035', 'IY2056', 'IY2036', 'IY2037', 'IY2038', 'IY2057',
#        'IY2058', 'IY2039', 'IY2040', 'IY2041', 'IY2042', 'IY2043',
#        'IY2044', 'IY2045', 'IY2046', 'IY2047', 'IY2048', 'IY2186',
#        'IY2187', 'IY2188', 'IY2189', 'IY2190', 'IY2237', 'IY2191',
#        'IY2238', 'IY2192', 'IY2239', 'IY2193', 'IY2195', 'IY2194',
#        'IY2196', 'IY2197', 'IY2198', 'IY2199', 'IY2200', 'IY2201',
#        'IY2202', 'IY2203', 'IY2204', 'IY2205', 'IY2206', 'IY2207',
#        'IY2242', 'IY2208', 'IY2209', 'IY2210', 'IY2211', 'IY2212',
#        'IY2214', 'IY2215', 'IY2216', 'IY2217', 'IY2218', 'IY2219',
#        'IY2220', 'IY2221', 'IY2222', 'IY2223', 'IY2224', 'IY2225',
#        'IY2226', 'IY2025', 'IY2026', 'IY2029', 'IY2032', 'IY2019',
#        'IY2022', 'NT'], dtype=object)

# %% [markdown]
# #### Define control strains

# %% [markdown]
# We find the control strains by looking for the 'ontrol' string in the line name (using instead of 'Control' or 'control' to avoid capitalization issues), and we add the information as a new column:

# %%
find_control   = lambda x: True if 'ontrol' in x else False 
df2['Control'] =  df2['Line Name'].apply(find_control)

# %%
df2.loc[df2['Control']==True,:]
# Out:
#            Line Name Line Description           Protocol  \
# 149532    Control-R1         BL1A1_NT             GC-FID
# 149533    Control-R2         BL1B1_NT             GC-FID
# 149534    Control-R3         BL1C1_NT             GC-FID
# 149535    Control-R4         BL2A1_NT             GC-FID
# 149536    Control-R5         BL2B1_NT             GC-FID
# ...              ...              ...                ...
# 1181817  Control-R18         BL6C1_NT  Global Proteomics
# 1182042  Control-R15         BL5C1_NT  Global Proteomics
# 1182043  Control-R16         BL6A1_NT  Global Proteomics
# 1182044  Control-R17         BL6B1_NT  Global Proteomics
# 1182045  Control-R18         BL6C1_NT  Global Proteomics
#
#                       Formal Type                    Measurement Type  \
# 149532                  cid:12988               3-METHYL-3-BUTEN-1-OL
# 149533                  cid:12988               3-METHYL-3-BUTEN-1-OL
# 149534                  cid:12988               3-METHYL-3-BUTEN-1-OL
# 149535                  cid:12988               3-METHYL-3-BUTEN-1-OL
# 149536                  cid:12988               3-METHYL-3-BUTEN-1-OL
# ...                           ...                                 ...
# 1181817     sp|Q9FD71|HMGCS_ENTFL  Hydroxymethylglutaryl-CoA synthase
# 1182042  sp|Q9Z408|CSD_PSEPK Csda       Probable cysteine desulfurase
# 1182043  sp|Q9Z408|CSD_PSEPK Csda       Probable cysteine desulfurase
# 1182044  sp|Q9Z408|CSD_PSEPK Csda       Probable cysteine desulfurase
# 1182045  sp|Q9Z408|CSD_PSEPK Csda       Probable cysteine desulfurase
#
#                 Value Strain  Control
# 149532   2.660055e+02     NT     True
# 149533   2.728256e+02     NT     True
# 149534   2.541087e+02     NT     True
# 149535   2.425143e+02     NT     True
# 149536   2.046448e+02     NT     True
# ...               ...    ...      ...
# 1181817  8.302083e+07     NT     True
# 1182042  1.117643e+06     NT     True
# 1182043  1.821115e+06     NT     True
# 1182044  1.755651e+06     NT     True
# 1182045  1.319987e+06     NT     True
#
# [43657 rows x 8 columns]

# %% [markdown]
# This is the control strain:

# %%
df2.loc[df2['Control']==True,:]['Strain'].unique()
# Out:
# array(['NT'], dtype=object)

# %%
control_strain = df2.loc[df2['Control']==True,:]['Strain'].unique()[0]

# %%
control_strain
# Out:
# 'NT'

# %% [markdown]
# ### Check negative values

# %% [markdown]
# Check if there are negative values for measurements (a big no no for concentrations and protein counts):

# %%
len(df2[df2['Value'] < 0])
# Out:
# 0

# %% [markdown]
# It seems we are good.

# %% [markdown]
# ### Check replicates

# %% [markdown]
# Let's check how many replicates we have for our data:

# %%
df2['Protocol'].unique()
# Out:
# array(['GC-FID', 'Global Proteomics'], dtype=object)

# %%
df2[df2['Protocol']=='GC-FID']['Line Name'].unique()
# Out:
# array(['PP_4549-R1', 'PP_4550-R1', 'PP_0368-R1', 'PP_2136-R1',
#        'PP_0774-R1', 'PP_0362-R1', 'PP_0437-R1', 'PP_4549-R2',
#        'PP_4550-R2', 'PP_0368-R2', 'PP_2136-R2', 'PP_0774-R2',
#        'PP_0362-R2', 'PP_0437-R2', 'PP_4549-R3', 'PP_4550-R3',
#        'PP_0368-R3', 'PP_2136-R3', 'PP_0774-R3', 'PP_0362-R3',
#        'PP_0437-R3', 'PP_2589-R1', 'PP_3744-R1', 'PP_4194_NT2-R1',
#        'PP_4194_NT3-R1', 'PP_1607_NT1-R1', 'PP_1607_NT4-R1',
#        'PP_1607_NT1_xylS_Pm-R1', 'PP_1607_NT2_xylS_Pm-R1', 'PP_2589-R2',
#        'PP_3744-R2', 'PP_4194_NT2-R2', 'PP_4194_NT3-R2', 'PP_1607_NT1-R2',
#        'PP_1607_NT4-R2', 'PP_1607_NT1_xylS_Pm-R2',
#        'PP_0658-R1', 'PP_1506-R1', 'PP_1620-R1', 'PP_4266-R1',
#        'PP_1457-R1', 'PP_5203-R1', 'PP_4159-R2', 'PP_0658-R2',
#        'PP_1506-R2', 'PP_1620-R2', 'PP_4266-R2', 'PP_1457-R2',
#        'PP_5203-R2', 'PP_4159-R3', 'PP_0658-R3', 'PP_1506-R3',
#        'PP_1620-R3', 'PP_4266-R3', 'PP_1457-R3', 'PP_5203-R3',
#        'PP_0277-R1', 'PP_0226-R1', 'PP_0225-R1', 'PP_4651-R1',
#        'PP_4650-R1', 'PP_4193-R1', 'PP_4192-R1', 'PP_4191-R1',
#        'PP_0277-R2', 'PP_0226-R2', 'PP_0225-R2', 'PP_4651-R2',
#        'PP_4650-R2', 'PP_4193-R2', 'PP_4192-R2', 'PP_4191-R2',
#        'PP_0277-R3', 'PP_0226-R3', 'PP_0225-R3', 'PP_4651-R3',
#        'PP_4650-R3', 'PP_4193-R3', 'PP_4192-R3', 'PP_4191-R3',
#        'PP_0897-R1', 'PP_0944-R1', 'PP_1755-R1', 'PP_0654-R1',
#        'PP_0751-R1', 'PP_2925-R1', 'PP_1251-R1', 'PP_0897-R2',
#        'PP_0944-R2', 'PP_1755-R2', 'PP_0654-R2', 'PP_0751-R2',
#        'PP_2925-R2', 'PP_1251-R2', 'PP_0897-R3', 'PP_0944-R3',
#        'PP_1755-R3', 'PP_0654-R3', 'PP_0751-R3', 'PP_2925-R3',
#        'PP_1251-R3', 'PP_2112-R1', 'PP_2339-R1', 'PP_4011-R1',
#        'PP_4012-R1', 'PP_4185-R1', 'PP_4186-R1', 'PP_4119-R1',
#        'PP_4120-R1', 'PP_2112-R2', 'PP_2339-R2', 'PP_4011-R2',
#        'PP_4012-R2', 'PP_4185-R2', 'PP_4186-R2', 'PP_4119-R2',
#        'PP_4120-R2', 'PP_2112-R3', 'PP_2339-R3', 'PP_4011-R3',
#        'PP_4012-R3', 'PP_4185-R3', 'PP_4186-R3', 'PP_4119-R3',
#        'PP_4120-R3', 'PP_4123-R1', 'PP_4128-R1', 'PP_5420-R1',
#        'PP_5416-R1', 'PP_1607_NT1-R4', 'PP_4679-R4', 'PP_4678-R4',
#        'PP_4123-R2', 'PP_4128-R2', 'PP_5420-R2', 'PP_5416-R2',
#        'PP_1607_NT1-R5', 'PP_4679-R5', 'PP_4678-R5', 'PP_4123-R3',
#        'PP_4128-R3', 'PP_5420-R3', 'PP_5416-R3', 'PP_1607_NT1-R6',
#        'PP_4679-R6', 'PP_4678-R6', 'Control-R1', 'Control-R2',
#        'Control-R3', 'Control-R4', 'Control-R5', 'Control-R6',
#        'Control-R7', 'Control-R8', 'Control-R9', 'Control-R10',
#        'Control-R11', 'Control-R12', 'Control-R13', 'Control-R14',
#        'Control-R15', 'Control-R16', 'Control-R17', 'Control-R18'],
#       dtype=object)

# %% [markdown]
# We seem to have triplicates for isoprenol measurements

# %%
df2[df2['Protocol']=='Global Proteomics']['Line Name'].unique()
# Out:
# array(['Control-R1', 'Control-R2', 'Control-R3', 'Control-R4',
#        'PP_4650-R2', 'PP_4650-R3', 'PP_4651-R1', 'PP_4651-R2',
#        'PP_4651-R3', 'PP_4678-R4', 'PP_4678-R5', 'PP_4678-R6',
#        'PP_4679-R4', 'PP_4679-R5', 'PP_4679-R6', 'PP_4862-R1',
#        'PP_4862-R2', 'PP_4862-R3', 'PP_5064-R1', 'PP_5064-R2',
#        'PP_5064-R3', 'PP_5128-R1', 'PP_5128-R2', 'PP_5128-R3',
#        'PP_5186-R1', 'PP_5186-R2', 'PP_5186-R3', 'PP_5203-R1',
#        'PP_5203-R2', 'PP_5203-R3', 'PP_5416-R1', 'PP_5416-R2',
#        'PP_5416-R3', 'PP_5420-R1', 'PP_5420-R2', 'PP_5420-R3'],
#       dtype=object)

# %% [markdown]
# And we have triplicates for proteomics measurements, as well.

# %% [markdown]
# ### Protein data

# %% [markdown]
# Let's get the protein data into proper format for later use:

# %% [markdown]
# #### Bring out Uniprot names

# %% [markdown]
# Filter everything out from the formal type except uniprot name ('sp|Q9Z408|CSD_PSEPK Csda' --> 'Q9Z408'):

# %%
get_Uniprot = lambda x: re.sub('.*\|(.*)\|.*', r'\1', x)

# %%
get_Uniprot('sp|Q9Z408|CSD_PSEPK Csda')  # filters name only if protein
# Out:
# 'Q9Z408'

# %%
get_Uniprot('cid:12988')                 # Doesn't change anything otherwise
# Out:
# 'cid:12988'

# %%
df2['Formal Type'] =  df2['Formal Type'].apply(get_Uniprot)

# %%
df2
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID   cid:12988
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID   cid:12988
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID   cid:12988
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID   cid:12988
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID   cid:12988
# ...             ...              ...                ...         ...
# 1182265  PP_5416-R2    BL10B5_IY2022  Global Proteomics      Q9Z408
# 1182266  PP_5416-R3    BL10C5_IY2022  Global Proteomics      Q9Z408
# 1182267  PP_5420-R1    BL10A4_IY2019  Global Proteomics      Q9Z408
# 1182268  PP_5420-R2    BL10B4_IY2019  Global Proteomics      Q9Z408
# 1182269  PP_5420-R3    BL10C4_IY2019  Global Proteomics      Q9Z408
#
#                       Measurement Type         Value  Strain  Control
# 149130           3-METHYL-3-BUTEN-1-OL  2.989604e+02  IY1586    False
# 149131           3-METHYL-3-BUTEN-1-OL  1.673975e+02  IY1587    False
# 149132           3-METHYL-3-BUTEN-1-OL  3.405714e+02  IY1588    False
# 149133           3-METHYL-3-BUTEN-1-OL  3.485097e+02  IY1589    False
# 149134           3-METHYL-3-BUTEN-1-OL  2.151588e+02  IY1590    False
# ...                                ...           ...     ...      ...
# 1182265  Probable cysteine desulfurase  1.051687e+06  IY2022    False
# 1182266  Probable cysteine desulfurase  9.921411e+05  IY2022    False
# 1182267  Probable cysteine desulfurase  5.949145e+05  IY2019    False
# 1182268  Probable cysteine desulfurase  3.865737e+05  IY2019    False
# 1182269  Probable cysteine desulfurase  1.419732e+06  IY2019    False
#
# [1033140 rows x 8 columns]

# %% [markdown]
# #### Limit protein data to target genes

# %% [markdown]
# Since we only need the proteomics data for the target genes, we will only keep that. To figure out the target genes, we need to get the file mapping Uniprot IDs to PPxx names for the target genes:

# %%
ProtMapping_df = pd.read_excel(user_params['protein_map'])

# %%
ProtMapping_df
# Out:
#     CRISPRi target gene UNIPROT ID
# 0           PP_1607_NT2     Q88MG4
# 1           PP_1607_NT3     Q88MG4
# 2           PP_1607_NT4     Q88MG4
# 3               PP_4549     Q88EB7
# 4               PP_4550     Q88EB6
# ..                  ...        ...
# 126             PP_4186     Q88FB2
# 127             PP_1023     Q88P30
# 128             PP_5128     Q88CQ2
# 129             PP_2095     Q88L40
# 130             PP_0225     Q88PN6
#
# [131 rows x 2 columns]

# %% [markdown]
# We will limit CRISPRi target gene name to standard names (e.g. we will convert 'PP_1607_NT2' to 'PP_1607', **PLEASE CHECK THIS IS OK!!**):
#
# Alternative approach - save the NT as a separate column to identify it later

# %%
ProtMapping_df["CRISPRi target gene"] = ProtMapping_df["CRISPRi target gene"].apply(lambda x: x[0:7])

# %% [markdown]
# Find all target genes/proteins from this mapping:

# %%
targets = ProtMapping_df['UNIPROT ID'].unique().tolist()

# %%
targets[0:10]
# Out:
# ['Q88MG4',
#  'Q88EB7',
#  'Q88EB6',
#  'Q88QW6',
#  'Q88L02',
#  'Q88PS4',
#  'Q88QX2',
#  'Q88QQ1',
#  'Q88JR0',
#  'Q88GH9']

# %%
df2.loc[df2['Formal Type'].isin(targets),'Formal Type']
number_matched = len(df2.loc[df2['Formal Type'].isin(targets),'Formal Type'])

# %% [markdown]
# Compare the above filter (whether the formal type is in the targets list) with the length of the whole dataframe:

# %%
print(f'full dataframe is length: {len(df2)}, dataframe filtered for targets is length: {number_matched}')
# Out:
# full dataframe is length: 1033140, dataframe filtered for targets is length: 40968

# %% [markdown]
# So we are losing around 60% of our proteins. (Useful information in there?)

# %%
df2[(df2['Formal Type'].isin(targets)) & (df2['Protocol']=='Global Proteomics')]
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 150702   Control-R1         BL1A1_NT  Global Proteomics      P0A126
# 150703   Control-R2         BL1B1_NT  Global Proteomics      P0A126
# 150704   Control-R3         BL1C1_NT  Global Proteomics      P0A126
# 150705   Control-R4         BL2A1_NT  Global Proteomics      P0A126
# 150706   Control-R5         BL2B1_NT  Global Proteomics      P0A126
# ...             ...              ...                ...         ...
# 1173145  PP_5416-R2    BL10B5_IY2022  Global Proteomics      Q88RM6
# 1173146  PP_5416-R3    BL10C5_IY2022  Global Proteomics      Q88RM6
# 1173147  PP_5420-R1    BL10A4_IY2019  Global Proteomics      Q88RM6
# 1173148  PP_5420-R2    BL10B4_IY2019  Global Proteomics      Q88RM6
# 1173149  PP_5420-R3    BL10C4_IY2019  Global Proteomics      Q88RM6
#
#                               Measurement Type       Value  Strain  Control
# 150702   Integration host factor subunit alpha  4201002.90      NT     True
# 150703   Integration host factor subunit alpha  4517773.00      NT     True
# 150704   Integration host factor subunit alpha  3999560.28      NT     True
# 150705   Integration host factor subunit alpha  3858903.76      NT     True
# 150706   Integration host factor subunit alpha  3800910.30      NT     True
# ...                                        ...         ...     ...      ...
# 1173145         Cytochrome c oxidase subunit 2  1677449.00  IY2022    False
# 1173146         Cytochrome c oxidase subunit 2  1181200.00  IY2022    False
# 1173147         Cytochrome c oxidase subunit 2   823529.94  IY2019    False
# 1173148         Cytochrome c oxidase subunit 2   817266.74  IY2019    False
# 1173149         Cytochrome c oxidase subunit 2   754412.05  IY2019    False
#
# [40968 rows x 8 columns]

# %%
df2[(~df2['Formal Type'].isin(targets)) & (df2['Protocol']=='Global Proteomics')].index
# Out:
# Int64Index([ 149550,  149551,  149552,  149553,  149554,  149555,  149556,
#              149557,  149558,  149559,
#             ...
#             1182260, 1182261, 1182262, 1182263, 1182264, 1182265, 1182266,
#             1182267, 1182268, 1182269],
#            dtype='int64', length=991752)

# %% [markdown]
# Drop the rows that are not in targets from the proteomics protocol:

# %%
df2 = df2.drop(index=df2[(~df2['Formal Type'].isin(targets)) & (df2['Protocol']=='Global Proteomics')].index)

# %%
df2
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID   cid:12988
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID   cid:12988
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID   cid:12988
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID   cid:12988
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID   cid:12988
# ...             ...              ...                ...         ...
# 1173145  PP_5416-R2    BL10B5_IY2022  Global Proteomics      Q88RM6
# 1173146  PP_5416-R3    BL10C5_IY2022  Global Proteomics      Q88RM6
# 1173147  PP_5420-R1    BL10A4_IY2019  Global Proteomics      Q88RM6
# 1173148  PP_5420-R2    BL10B4_IY2019  Global Proteomics      Q88RM6
# 1173149  PP_5420-R3    BL10C4_IY2019  Global Proteomics      Q88RM6
#
#                        Measurement Type         Value  Strain  Control
# 149130            3-METHYL-3-BUTEN-1-OL  2.989604e+02  IY1586    False
# 149131            3-METHYL-3-BUTEN-1-OL  1.673975e+02  IY1587    False
# 149132            3-METHYL-3-BUTEN-1-OL  3.405714e+02  IY1588    False
# 149133            3-METHYL-3-BUTEN-1-OL  3.485097e+02  IY1589    False
# 149134            3-METHYL-3-BUTEN-1-OL  2.151588e+02  IY1590    False
# ...                                 ...           ...     ...      ...
# 1173145  Cytochrome c oxidase subunit 2  1.677449e+06  IY2022    False
# 1173146  Cytochrome c oxidase subunit 2  1.181200e+06  IY2022    False
# 1173147  Cytochrome c oxidase subunit 2  8.235299e+05  IY2019    False
# 1173148  Cytochrome c oxidase subunit 2  8.172667e+05  IY2019    False
# 1173149  Cytochrome c oxidase subunit 2  7.544121e+05  IY2019    False
#
# [41388 rows x 8 columns]

# %%
'Q88RM6' in targets
# Out:
# True

# %% [markdown]
# #### Change names from Uniprot to PP_ names

# %% [markdown]
# Use the mapping again to change names from Uniprot to PPxx names:

# %%
ProtMapping_df
# Out:
#     CRISPRi target gene UNIPROT ID
# 0               PP_1607     Q88MG4
# 1               PP_1607     Q88MG4
# 2               PP_1607     Q88MG4
# 3               PP_4549     Q88EB7
# 4               PP_4550     Q88EB6
# ..                  ...        ...
# 126             PP_4186     Q88FB2
# 127             PP_1023     Q88P30
# 128             PP_5128     Q88CQ2
# 129             PP_2095     Q88L40
# 130             PP_0225     Q88PN6
#
# [131 rows x 2 columns]

# %%
number_crispr_target_genes = len(ProtMapping_df["CRISPRi target gene"].unique())
number_uniprot_id = len(ProtMapping_df["UNIPROT ID"].unique())
target_value_counts = ProtMapping_df["CRISPRi target gene"].value_counts()
upid_value_counts = ProtMapping_df['UNIPROT ID'].value_counts()

print(f'In the Protein Mapping spreadsheet, there are {number_crispr_target_genes} unique target genes and {number_uniprot_id} unique uniprot IDs')
print('These targets have show up multiple times in the list:')
print(target_value_counts[target_value_counts>1])
print('These Uniprot IDs show up multiple times')
print(upid_value_counts[upid_value_counts>1])
# Out:
# In the Protein Mapping spreadsheet, there are 123 unique target genes and 120 unique uniprot IDs
# These targets have show up multiple times in the list:
# PP_1607    8
# PP_4194    2
# Name: CRISPRi target gene, dtype: int64
# These Uniprot IDs show up multiple times
# Q88MG4    8
# Q88FB0    2
# Q88FA4    2
# Q877U6    2
# Q88PN6    2
# Name: UNIPROT ID, dtype: int64

# %% [markdown]
# There are two sets of multiple guide RNAs (PP_1607/Q88MG4, PP_4194/Q88FA4), which explains the multiple target entries. The following target gene entries have multiple strains attached to them:
#
# UPID Q88FB0 is targeted by PP_4188 and PP_0814
#
# UPID Q877U6 is targeted by PP_1157 and PP_3365
#
# UPID Q88PN6 is targeted by PP_0813 and PP_0225

# %%
len(ProtMapping_df["UNIPROT ID"].unique())
# Out:
# 120

# %% [markdown]
# Create a protein mapping dictionary that translates from Uniprot to PP names:
# (**NOTICE THERE IS NOT A ONE TO ONE CORRESPONDENCE, SO WE NEED TO DISCUSS THIS**)
#
# PCK: I think this is arbitrarily deciding whether to call double entry UPIDs with one of the target genes. Make a second dictionary to compare, end iteration early. This is super hacky but just to prove a point.

# %%
proteinMap = {}
for index in ProtMapping_df.index:
    proteinMap[ProtMapping_df.loc[index,"UNIPROT ID"]] = ProtMapping_df.loc[index,"CRISPRi target gene"]
dupList = ProtMapping_df[ProtMapping_df['UNIPROT ID'] == 'Q88FB0'].index.tolist()
proteinMapTest = {} 
for ii in range(min(dupList)+1):
    proteinMapTest[ProtMapping_df.loc[ii,"UNIPROT ID"]] = ProtMapping_df.loc[ii,"CRISPRi target gene"]

# %% [markdown]
# By comparing the same key (Uniprot ID) between dictionaries we see that for a few target genes, the Uniprot ID will be arbitraily assigned to whatever is listed second in the spreadsheet.

# %%
print(proteinMap['Q88FB0'])
print(proteinMapTest['Q88FB0'])
# Out:
# PP_0814
# PP_4188

# %%
df2
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID   cid:12988
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID   cid:12988
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID   cid:12988
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID   cid:12988
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID   cid:12988
# ...             ...              ...                ...         ...
# 1173145  PP_5416-R2    BL10B5_IY2022  Global Proteomics      Q88RM6
# 1173146  PP_5416-R3    BL10C5_IY2022  Global Proteomics      Q88RM6
# 1173147  PP_5420-R1    BL10A4_IY2019  Global Proteomics      Q88RM6
# 1173148  PP_5420-R2    BL10B4_IY2019  Global Proteomics      Q88RM6
# 1173149  PP_5420-R3    BL10C4_IY2019  Global Proteomics      Q88RM6
#
#                        Measurement Type         Value  Strain  Control
# 149130            3-METHYL-3-BUTEN-1-OL  2.989604e+02  IY1586    False
# 149131            3-METHYL-3-BUTEN-1-OL  1.673975e+02  IY1587    False
# 149132            3-METHYL-3-BUTEN-1-OL  3.405714e+02  IY1588    False
# 149133            3-METHYL-3-BUTEN-1-OL  3.485097e+02  IY1589    False
# 149134            3-METHYL-3-BUTEN-1-OL  2.151588e+02  IY1590    False
# ...                                 ...           ...     ...      ...
# 1173145  Cytochrome c oxidase subunit 2  1.677449e+06  IY2022    False
# 1173146  Cytochrome c oxidase subunit 2  1.181200e+06  IY2022    False
# 1173147  Cytochrome c oxidase subunit 2  8.235299e+05  IY2019    False
# 1173148  Cytochrome c oxidase subunit 2  8.172667e+05  IY2019    False
# 1173149  Cytochrome c oxidase subunit 2  7.544121e+05  IY2019    False
#
# [41388 rows x 8 columns]

# %% [markdown]
# And do the translation:

# %%
ProteomicsInd = df2['Protocol']=='Global Proteomics'

df2.loc[ProteomicsInd,'Formal Type'] = df2.loc[ProteomicsInd,'Formal Type'].apply(lambda x: proteinMap[x])

# %%
df2
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID   cid:12988
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID   cid:12988
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID   cid:12988
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID   cid:12988
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID   cid:12988
# ...             ...              ...                ...         ...
# 1173145  PP_5416-R2    BL10B5_IY2022  Global Proteomics     PP_0103
# 1173146  PP_5416-R3    BL10C5_IY2022  Global Proteomics     PP_0103
# 1173147  PP_5420-R1    BL10A4_IY2019  Global Proteomics     PP_0103
# 1173148  PP_5420-R2    BL10B4_IY2019  Global Proteomics     PP_0103
# 1173149  PP_5420-R3    BL10C4_IY2019  Global Proteomics     PP_0103
#
#                        Measurement Type         Value  Strain  Control
# 149130            3-METHYL-3-BUTEN-1-OL  2.989604e+02  IY1586    False
# 149131            3-METHYL-3-BUTEN-1-OL  1.673975e+02  IY1587    False
# 149132            3-METHYL-3-BUTEN-1-OL  3.405714e+02  IY1588    False
# 149133            3-METHYL-3-BUTEN-1-OL  3.485097e+02  IY1589    False
# 149134            3-METHYL-3-BUTEN-1-OL  2.151588e+02  IY1590    False
# ...                                 ...           ...     ...      ...
# 1173145  Cytochrome c oxidase subunit 2  1.677449e+06  IY2022    False
# 1173146  Cytochrome c oxidase subunit 2  1.181200e+06  IY2022    False
# 1173147  Cytochrome c oxidase subunit 2  8.235299e+05  IY2019    False
# 1173148  Cytochrome c oxidase subunit 2  8.172667e+05  IY2019    False
# 1173149  Cytochrome c oxidase subunit 2  7.544121e+05  IY2019    False
#
# [41388 rows x 8 columns]

# %% [markdown]
# #### Add target gene

# %% [markdown]
# Add now a column with the target gene for each strain:

# %%
get_target_gene = lambda x: re.split('-', x)[0][0:7] # last part eliminates non standard names from PP name (e.g. PP_1607_NT3)

# %%
get_target_gene('PP_4549-R1')
# Out:
# 'PP_4549'

# %%
df2['Target']=df2['Line Name'].apply(get_target_gene)

# %%
df2.head
# Out:
#           Line Name Line Description           Protocol Formal Type  \
# 149130   PP_4549-R1     BL1A2_IY1586             GC-FID   cid:12988
# 149131   PP_4550-R1     BL1A3_IY1587             GC-FID   cid:12988
# 149132   PP_0368-R1     BL1A4_IY1588             GC-FID   cid:12988
# 149133   PP_2136-R1     BL1A5_IY1589             GC-FID   cid:12988
# 149134   PP_0774-R1     BL1A6_IY1590             GC-FID   cid:12988
# ...             ...              ...                ...         ...
# 1173145  PP_5416-R2    BL10B5_IY2022  Global Proteomics     PP_0103
# 1173146  PP_5416-R3    BL10C5_IY2022  Global Proteomics     PP_0103
# 1173147  PP_5420-R1    BL10A4_IY2019  Global Proteomics     PP_0103
# 1173148  PP_5420-R2    BL10B4_IY2019  Global Proteomics     PP_0103
# 1173149  PP_5420-R3    BL10C4_IY2019  Global Proteomics     PP_0103
#
#                        Measurement Type         Value  Strain  Control  \
# 149130            3-METHYL-3-BUTEN-1-OL  2.989604e+02  IY1586    False
# 149131            3-METHYL-3-BUTEN-1-OL  1.673975e+02  IY1587    False
# 149132            3-METHYL-3-BUTEN-1-OL  3.405714e+02  IY1588    False
# 149133            3-METHYL-3-BUTEN-1-OL  3.485097e+02  IY1589    False
# 149134            3-METHYL-3-BUTEN-1-OL  2.151588e+02  IY1590    False
# ...                                 ...           ...     ...      ...
# 1173145  Cytochrome c oxidase subunit 2  1.677449e+06  IY2022    False
# 1173146  Cytochrome c oxidase subunit 2  1.181200e+06  IY2022    False
# 1173147  Cytochrome c oxidase subunit 2  8.235299e+05  IY2019    False
# 1173148  Cytochrome c oxidase subunit 2  8.172667e+05  IY2019    False
# 1173149  Cytochrome c oxidase subunit 2  7.544121e+05  IY2019    False
#
#           Target
# 149130   PP_4549
# 149131   PP_4550
# 149132   PP_0368
# 149133   PP_2136
# 149134   PP_0774
# ...          ...
# 1173145  PP_5416
# 1173146  PP_5416
# 1173147  PP_5420
# 1173148  PP_5420
# 1173149  PP_5420
#
# [41388 rows x 9 columns]

# %%
df2['Formal Type'].unique()
# Out:
# array(['cid:12988', 'PP_2471', 'PP_1506', 'PP_0001', 'PP_3365', 'PP_5419',
#        'PP_5417', 'PP_5416', 'PP_5335', 'PP_5288', 'PP_5203', 'PP_5186',
#        'PP_5128', 'PP_5064', 'PP_4894', 'PP_4862', 'PP_4702', 'PP_4679',
#        'PP_4678', 'PP_4667', 'PP_4651', 'PP_4650', 'PP_4636', 'PP_4635',
#        'PP_4550', 'PP_4549', 'PP_4487', 'PP_4266', 'PP_4194', 'PP_4193',
#        'PP_4192', 'PP_4191', 'PP_4090', 'PP_4189', 'PP_0814', 'PP_4187',
#        'PP_4186', 'PP_4185', 'PP_4175', 'PP_4174', 'PP_4130', 'PP_4129',
#        'PP_4123', 'PP_4122', 'PP_4121', 'PP_4120', 'PP_4119', 'PP_4116',
#        'PP_4012', 'PP_4011', 'PP_3755', 'PP_3754', 'PP_3578', 'PP_3123',
#        'PP_3122', 'PP_3071', 'PP_2925', 'PP_2339', 'PP_2213', 'PP_2137',
#        'PP_2136', 'PP_2112', 'PP_2095', 'PP_1777', 'PP_1770', 'PP_1769',
#        'PP_1755', 'PP_1664', 'PP_1620', 'PP_1610', 'PP_1607', 'PP_1457',
#        'PP_1444', 'PP_1319', 'PP_1318', 'PP_1317', 'PP_1251', 'PP_1240',
#        'PP_1031', 'PP_1023', 'PP_0999', 'PP_0944', 'PP_0897', 'PP_0225',
#        'PP_0812', 'PP_0774', 'PP_0751', 'PP_0691', 'PP_0658', 'PP_0654',
#        'PP_0597', 'PP_0582', 'PP_0528', 'PP_0437', 'PP_0368', 'PP_0338',
#        'PP_0226', 'PP_0168', 'PP_0548', 'PP_0103'], dtype=object)

# %% [markdown]
# ## Statistical analysis

# %% [markdown]
# ### Pivot dataframe to table

# %% [markdown]
# First, let's pivot the data into an easier format to work with:
# *NOTE* Tried to do pivot table with np.std and np.var, results not as expected (is this useful?) - Note I think using np.std or np.var uses a different denominator than len(x)?

# %%
df_targets = df2.pivot_table(
    index="Strain", columns=["Formal Type"], values="Value", aggfunc=np.mean    #Using mean here instead of sum
)
def std_custom(x):
    x = np.array(x)
    meanX = np.mean(x)
    return np.sqrt(1/len(x)*np.sum((x-meanX)**2))

std_custom(np.array([1, 3, 5]))
df_std = df2.pivot_table(
    index="Strain", columns=["Formal Type"], values="Value", aggfunc=std_custom    #Using std to get a table for the standard deviation
)

# %%
df_targets
# Out:
# Formal Type       PP_0001       PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452       3.586415e+06           NaN  9.210642e+06  1.124118e+07
# IY1586       4.941056e+06           NaN  1.236235e+07  9.721919e+06
# IY1587       3.383160e+06           NaN  6.041816e+06  9.352343e+06
# IY1588       3.782190e+06           NaN  1.541983e+07  9.795028e+06
# IY1589       5.161205e+06           NaN  6.916297e+06  1.067935e+07
# ...                   ...           ...           ...           ...
# IY2237       2.551562e+06  27225.933333  5.617526e+06  6.300809e+06
# IY2238       3.479561e+06  40485.960000  8.943537e+06  5.933978e+06
# IY2239       2.883891e+06  16973.733333  6.771840e+06  5.520682e+06
# IY2242       2.750830e+06  16167.386667  1.534163e+07  5.912609e+06
# NT           4.190752e+06  17237.230000  9.065235e+06  9.133443e+06
# IY1589       234074.079156   33446.748652  5.576633e+05  5.555699e+05
# ...                    ...            ...           ...           ...
# IY2237       260814.783716   74228.063448  4.331022e+05  1.803522e+05
# IY2238       464466.437816   55770.015244  4.626168e+05  2.210751e+05
# IY2239       152898.177221   68835.184801  4.765143e+05  2.109362e+05
# IY2242       110834.047023  122959.174335  1.944543e+05  1.931268e+05
# NT           251857.954009  167261.013890  6.868934e+05  1.024778e+06
#
# Formal Type       PP_5416       PP_5417        PP_5419  cid:12988
# Strain
# IY1452       1.525152e+06  3.773606e+06  471313.947455  55.243577
# IY1586       8.840375e+05  1.886022e+06  375047.999732   3.110975
# IY1587       2.518384e+05  1.736167e+06  166491.699350  10.605987
# IY1588       9.695114e+05  1.818769e+06   23908.824666  11.804464
# IY1589       3.842925e+05  2.282375e+06  266321.187306   2.140100
# ...                   ...           ...            ...        ...
# IY2237       4.439490e+05  5.291940e+05  193290.086922   4.240001
# IY2238       8.001847e+05  1.500259e+06    7516.924246   9.909703
# IY2239       8.847182e+05  3.275295e+06   12002.241942   5.529495
# IY2242       7.021976e+05  8.423560e+05  180542.747467  23.783604
# NT           1.841144e+06  4.577591e+06  267471.475307  28.937728
#
# [128 rows x 100 columns]

# %% [markdown]
# Do sanity checks on mean and var (and check that I know what I'm doing)

# %%
strain_use = 'IY1589'
target_use = 'PP_0001'
df_section = df2[(df2['Strain'] == strain_use) & (df2['Formal Type'] == target_use)]

print(f'mean value at {strain_use} and {target_use} in pivot table should be {np.mean(df_section.Value)}')

print(f'Delta is {np.mean(df_section.Value) - df_targets.loc[strain_use, target_use]}')

print(f'Var value at {strain_use} and {target_use} in pivot table should be {std_custom(df_section.Value)}')

print(f'Delta is {std_custom(df_section.Value) - df_std.loc[strain_use, target_use]}')
# Out:
# mean value at IY1589 and PP_0001 in pivot table should be 5161205.266666667
# Delta is 0.0
# Var value at IY1589 and PP_0001 in pivot table should be 1837189.3057667634
# Delta is 0.0

# %% [markdown]
# Change the compound id (cid) into its common name:

# %%
df_targets.rename(columns={'cid:12988': 'Isoprenol mean'}, inplace=True)

# %%
df_targets
# Out:
# Formal Type       PP_0001       PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452       3.586415e+06           NaN  9.210642e+06  1.124118e+07
# IY1586       4.941056e+06           NaN  1.236235e+07  9.721919e+06
# IY1587       3.383160e+06           NaN  6.041816e+06  9.352343e+06
# IY1588       3.782190e+06           NaN  1.541983e+07  9.795028e+06
# IY1589       5.161205e+06           NaN  6.916297e+06  1.067935e+07
# ...                   ...           ...           ...           ...
# IY2237       2.551562e+06  27225.933333  5.617526e+06  6.300809e+06
# IY2238       3.479561e+06  40485.960000  8.943537e+06  5.933978e+06
# IY2239       2.883891e+06  16973.733333  6.771840e+06  5.520682e+06
# IY2242       2.750830e+06  16167.386667  1.534163e+07  5.912609e+06
# NT           4.190752e+06  17237.230000  9.065235e+06  9.133443e+06
#
# Formal Type        PP_0226       PP_0338       PP_0368        PP_0437  \
# Strain
# IY1452       142166.586667  6.109116e+07  8.039113e+06  298727.406667
# NT           8.390255e+06  2.702211e+07  1.193798e+06  254.648694
#
# [128 rows x 100 columns]

# %% [markdown]
# Add let's now add the target genes to this table:
# Does this create a linked copy of df2 or does it create an entirely separate copy?

# %%
TargetMap = df2[["Strain","Target"]].drop_duplicates().set_index("Strain")

# %%
TargetMap
# Out:
#          Target
# Strain
# IY1586  PP_4549
# IY1587  PP_4550
# IY1588  PP_0368
# IY1589  PP_2136
# IY1590  PP_0774
# ...         ...
# IY2029  PP_4123
# IY2032  PP_4128
# IY2019  PP_5420
# IY2022  PP_5416
# NT      Control
#
# [128 rows x 1 columns]

# %%
df_targets.loc[TargetMap.index,"Target"] = TargetMap["Target"]

# %%
df_targets
# Out:
# Formal Type       PP_0001       PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452       3.586415e+06           NaN  9.210642e+06  1.124118e+07
# IY1586       4.941056e+06           NaN  1.236235e+07  9.721919e+06
# IY1587       3.383160e+06           NaN  6.041816e+06  9.352343e+06
# IY1588       3.782190e+06           NaN  1.541983e+07  9.795028e+06
# IY1589       5.161205e+06           NaN  6.916297e+06  1.067935e+07
# ...                   ...           ...           ...           ...
# IY2237       2.551562e+06  27225.933333  5.617526e+06  6.300809e+06
# IY2238       3.479561e+06  40485.960000  8.943537e+06  5.933978e+06
# IY2239       2.883891e+06  16973.733333  6.771840e+06  5.520682e+06
# IY2242       2.750830e+06  16167.386667  1.534163e+07  5.912609e+06
# NT           4.190752e+06  17237.230000  9.065235e+06  9.133443e+06
#
# Formal Type        PP_0226       PP_0338       PP_0368        PP_0437  \
# Strain
# IY1452       142166.586667  6.109116e+07  8.039113e+06  298727.406667
# IY1586       308027.333333  6.355352e+07  7.188374e+06  554030.300000
# IY1587       149748.286667  5.562492e+07  6.100304e+06  404533.066667
# IY1588       532825.913333  8.523304e+07  2.806301e+05  478575.080000
# IY1589       175308.100000  5.926596e+07  3.409878e+07  442735.666667
# ...                    ...           ...           ...            ...
# IY2237       177208.746667  4.531242e+07  4.233804e+06  334483.353333
# IY2238        90210.166667  4.384645e+07  3.470908e+06  259724.090000
# IY2239       170363.866667  3.842493e+07  3.989654e+06  341517.433333
# IY2242         8083.693333  4.446235e+07  4.116759e+06  314735.050000
# NT           231729.880000  6.404960e+07  7.475888e+06  414110.655556
#
# Formal Type       PP_0528       PP_0548  ...       PP_5128        PP_5186  \
# Strain                                   ...
# IY1452       9.636014e+05           NaN  ...  3.309500e+07  714464.702222
# IY1586       1.033685e+06           NaN  ...  3.538221e+07  802231.100000
# IY1587       8.223293e+05           NaN  ...  4.170485e+07  337268.900000
# IY1588       9.449282e+05           NaN  ...  4.037166e+07  768653.320000
# IY1589       1.115515e+06           NaN  ...  3.808640e+07  641292.433333
# ...                   ...           ...  ...           ...            ...
# IY2237       5.641511e+05   6806.483333  ...  2.260773e+07  813603.970000
# IY2238       4.674478e+05  10121.490000  ...  2.367315e+07  675847.070000
# IY2239       4.326523e+05   4243.433333  ...  2.195752e+07  329903.733333
# IY2242       4.170791e+05   4041.846667  ...  2.480115e+07  323244.410000
# NT           7.558040e+05   4309.307500  ...  3.496566e+07  837986.602778
#
# Formal Type        PP_5203       PP_5288       PP_5335       PP_5416  \
# Strain
# IY1452       264223.151111  2.445540e+06  5.063224e+06  7.287413e+06
# IY1586       161008.533333  3.504255e+06  6.403841e+06  7.892991e+06
# IY1587        42837.280000  7.075045e+06  5.252234e+06  7.197036e+06
# IY1588       170738.773333  4.443869e+06  5.520132e+06  7.560586e+06
# IY1589       275513.400000  2.478471e+06  4.940154e+06  7.361192e+06
# ...                    ...           ...           ...           ...
# IY2237        70950.503333  2.034283e+06  4.045274e+06  6.612702e+06
# IY2238        77744.156667  1.505822e+06  4.150746e+06  5.089367e+06
# IY2239        97011.533333  2.739738e+06  3.983225e+06  5.140160e+06
# IY2242       120226.216667  2.162935e+06  3.808412e+06  5.592523e+06
# NT           178156.592222  3.109214e+06  5.058710e+06  8.390255e+06
#
# Formal Type       PP_5417       PP_5419   cid:12988   Target
# Strain
# IY1452       2.881347e+07  8.183859e+05  289.814111  PP_1607
# IY1586       3.218307e+07  4.716865e+05  302.681833  PP_4549
# IY1587       3.061075e+07  2.213753e+05  154.452567  PP_4550
# IY1588       3.083117e+07  1.164940e+06  355.020800  PP_0368
# IY1589       3.034837e+07  9.698603e+05  351.199900  PP_2136
# ...                   ...           ...         ...      ...
# IY2237       2.121695e+07  2.770417e+05  198.964367  PP_1023
# IY2238       1.827777e+07  2.024298e+04  160.748000  PP_5128
# IY2239       1.876271e+07  8.486867e+03  197.783400  PP_2095
# IY2242       1.748532e+07  6.703499e+05  179.574180  PP_0225
# NT           2.702211e+07  1.193798e+06  254.648694  Control
#
# [128 rows x 101 columns]

# %% [markdown]
# Some target genes are note present in the proteomics data:

# %%
for gene in df_targets["Target"]:
    if gene not in df_targets.columns:
        print(gene)
# Out:
# PP_0362
# PP_2589
# PP_3744
# PP_3394
# PP_3355
# PP_3282
# PP_1157
# PP_1394
# PP_3280
# PP_4737
# PP_5420
# PP_0806
# PP_4128
# PP_4188
# PP_4043
# PP_0104
# PP_0105
# PP_0106
# PP_0813
# PP_0815
# PP_4161
# PP_4160
# PP_4159
# PP_0277
# Control

# %% [markdown]
# ### Proteomics data

# %% [markdown]
# Now we can add the statistical data from the proteomics data (mean, std, first and third quantile):

# %%
df_targets = find_library_stats(df_targets)
# Out:
# Data for these 25 proteins was not present:
# ['PP_0362', 'PP_2589', 'PP_3744', 'PP_3394', 'PP_3355', 'PP_3282', 'PP_1157', 'PP_1394', 'PP_3280', 'PP_4737', 'PP_5420', 'PP_0806', 'PP_4128', 'PP_4188', 'PP_4043', 'PP_0104', 'PP_0105', 'PP_0106', 'PP_0813', 'PP_0815', 'PP_4161', 'PP_4160', 'PP_4159', 'PP_0277', 'Control']

# %%
df_targets
# Out:
# Formal Type        PP_0001        PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452        3.586415e+06            NaN  9.210642e+06  1.124118e+07
# IY1586        4.941056e+06            NaN  1.236235e+07  9.721919e+06
# IY1587        3.383160e+06            NaN  6.041816e+06  9.352343e+06
# Strain
# IY1452        2.881347e+07  8.183859e+05  289.814111  PP_1607
# IY1586        3.218307e+07  4.716865e+05  302.681833  PP_4549
# IY1587        3.061075e+07  2.213753e+05  154.452567  PP_4550
# IY1588        3.083117e+07  1.164940e+06  355.020800  PP_0368
# IY1589        3.034837e+07  9.698603e+05  351.199900  PP_2136
# ...                    ...           ...         ...      ...
# NT            2.702211e+07  1.193798e+06  254.648694  Control
# Library_mean  2.414633e+07  3.813389e+05         NaN     None
# Library_std   5.414382e+06  4.036474e+05         NaN     None
# Library_Q1    1.948206e+07  1.477412e+04         NaN     None
# Library_Q3    2.822295e+07  6.880770e+05         NaN     None
#
# [132 rows x 101 columns]

# %% [markdown]
# ### Production data

# %% [markdown]
# We now find the coefficient of variation for the isoprenol data:

# %%
df_isoprenol             = df2[df2['Measurement Type']=='3-METHYL-3-BUTEN-1-OL']
df_isoprenol             = df_isoprenol.drop(columns=['Line Name', 'Line Description', 'Measurement Type', 'Protocol','Control'])
stats_isoprenol          = df_isoprenol.groupby(['Strain']).mean()
stats_isoprenol.rename(columns={'Value': 'mean'}, inplace=True)
stats_isoprenol['std']   = df_isoprenol.groupby(['Strain']).std()
stats_isoprenol['CV[%]'] = 100* stats_isoprenol['std'] / stats_isoprenol['mean']
stats_isoprenol = stats_isoprenol.sort_values('CV[%]', ascending=False)
stats_isoprenol.head()
# Out:
# /tmp/ipykernel_194501/688815194.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   stats_isoprenol          = df_isoprenol.groupby(['Strain']).mean()
# /tmp/ipykernel_194501/688815194.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   stats_isoprenol['std']   = df_isoprenol.groupby(['Strain']).std()
#               mean         std       CV[%]
# Strain
# IY2192   15.849800   27.452659  173.205081
# IY1671  100.588117  110.470009  109.824115
# IY2025   27.581113   23.906693   86.677767
# IY2195   63.463733   39.644337   62.467704
# IY1597  275.054650   93.993453   34.172646

# %% [markdown]
# Let's now add the statistic to the main dataframe:

# %%
product = 'Isoprenol'
df_isoprenol.rename(columns={'Value': product}, inplace=True)
df_isoprenol = df_isoprenol.sort_values(product, ascending=False)
df_isoprenol['CV[%]'] = None

strains = [strain for strain in stats_isoprenol.index.unique()]
for strain in strains:
    index = df_isoprenol[df_isoprenol['Strain']==strain].index
    cv_value = stats_isoprenol[stats_isoprenol.index==strain]['CV[%]'].values
    df_isoprenol.loc[index, 'CV[%]'] = np.ones(len(index))*cv_value

df_isoprenol.drop(columns='Formal Type', inplace=True)
df_isoprenol.set_index("Strain", inplace=True)

# %%
df_isoprenol.loc["IY1452"]
# Out:
#         Isoprenol   Target      CV[%]
# Strain
# IY1452   374.7397  PP_1607  20.218016
# IY1452   350.1727  PP_1607  20.218016
# IY1452   327.9539  PP_1607  20.218016
# IY1452   325.2797  PP_1607  20.218016
# IY1452   285.8704  PP_1607  20.218016
# IY1452   269.9460  PP_1607  20.218016
# IY1452   247.7752  PP_1607  20.218016
# IY1452   215.6081  PP_1607  20.218016
# IY1452   210.9813  PP_1607  20.218016

# %%
df_isoprenol
# Out:
#         Isoprenol   Target       CV[%]
# Strain
# IY2020   618.3056  PP_5419    5.359461
# IY1688   603.9709  PP_0528    2.279287
# IY1688   590.6272  PP_0528    2.279287
# IY2020   587.8620  PP_5419    5.359461
# IY1688   577.0506  PP_0528    2.279287
# ...           ...      ...         ...
# IY2192     0.0000  PP_5064  173.205081
# IY1671     0.0000  PP_4679  109.824115
# IY1673     0.0000  PP_1777         NaN
# IY1661     0.0000  PP_3394         NaN
# IY1673     0.0000  PP_1777         NaN
#
# [420 rows x 3 columns]

# %% [markdown]
# Stats for control strain:

# %%
df_control_stat = df_isoprenol.loc[control_strain]

# %% [markdown]
# ### Merging all information into a single dataframe

# %% [markdown]
# Add the CV information (isoprenol mean is already there)

# %%
df_targets.loc[df_isoprenol.index,["CV[%]","Target"]] = df_isoprenol.loc[:,["CV[%]","Target"]]

# %%
df_targets
# Out:
# Formal Type        PP_0001        PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452        3.586415e+06            NaN  9.210642e+06  1.124118e+07
# IY1586        4.941056e+06            NaN  1.236235e+07  9.721919e+06
# IY1587        3.383160e+06            NaN  6.041816e+06  9.352343e+06
# IY1588        3.782190e+06            NaN  1.541983e+07  9.795028e+06
# IY1589        5.161205e+06            NaN  6.916297e+06  1.067935e+07
# ...                    ...            ...           ...           ...
# NT            4.190752e+06   17237.230000  9.065235e+06  9.133443e+06
# Library_mean  3.414433e+06   83293.375614  9.349293e+06  7.547084e+06
# Library_std   1.002450e+06  205309.771335  4.764965e+06  2.921855e+06
# Library_Q1    2.559820e+06   15805.573333  6.016084e+06  5.913119e+06
# Library_Q3    4.167827e+06   39626.850000  1.189087e+07  9.482606e+06
#
# Formal Type         PP_0226       PP_0338       PP_0368        PP_0437  \
# Strain
# IY1452        142166.586667  6.109116e+07  8.039113e+06  298727.406667
# IY1586        308027.333333  6.355352e+07  7.188374e+06  554030.300000
# IY1587        149748.286667  5.562492e+07  6.100304e+06  404533.066667
# IY1588        532825.913333  8.523304e+07  2.806301e+05  478575.080000
# IY1589        175308.100000  5.926596e+07  3.409878e+07  442735.666667
# ...                     ...           ...           ...            ...
# NT            231729.880000  6.404960e+07  7.475888e+06  414110.655556
# Library_mean  185201.354357  5.084225e+07  5.920965e+06  295036.870542
# Library_std   143476.518113  1.375086e+07  3.444215e+06  132166.182716
# Library_Q1     70373.793333  4.089993e+07  3.984947e+06  205423.990000
# Library_Q3    278716.522500  6.099721e+07  6.799267e+06  374586.676667
#
# Formal Type        PP_0528       PP_0548  ...        PP_5186        PP_5203  \
# Strain                                    ...
# IY1452        9.636014e+05           NaN  ...  714464.702222  264223.151111
# IY1586        1.033685e+06           NaN  ...  802231.100000  161008.533333
# IY1587        8.223293e+05           NaN  ...  337268.900000   42837.280000
# IY1588        9.449282e+05           NaN  ...  768653.320000  170738.773333
# IY1589        1.115515e+06           NaN  ...  641292.433333  275513.400000
# ...                    ...           ...  ...            ...            ...
# NT            7.558040e+05   4309.307500  ...  837986.602778  178156.592222
# Library_mean  6.907668e+05  19054.325119  ...  600862.612507  171669.659934
# Library_std   2.791358e+05  31765.947948  ...  249896.728229  110649.467870
# Library_Q1    5.073299e+05   3550.646667  ...  409545.275000   84343.266667
# Library_Q3    8.286603e+05  10121.490000  ...  736351.890000  244835.266667
#
# Formal Type        PP_5288       PP_5335       PP_5416       PP_5417  \
# Strain
# IY1452        2.445540e+06  5.063224e+06  7.287413e+06  2.881347e+07
# IY1586        3.504255e+06  6.403841e+06  7.892991e+06  3.218307e+07
# IY1587        7.075045e+06  5.252234e+06  7.197036e+06  3.061075e+07
# IY1588        4.443869e+06  5.520132e+06  7.560586e+06  3.083117e+07
# IY1589        2.478471e+06  4.940154e+06  7.361192e+06  3.034837e+07
# ...                    ...           ...           ...           ...
# NT            3.109214e+06  5.058710e+06  8.390255e+06  2.702211e+07
# Library_mean  2.442659e+06  4.516804e+06  6.909082e+06  2.414633e+07
# Library_std   1.068624e+06  9.093907e+05  1.327981e+06  5.414382e+06
# Library_Q1    1.709141e+06  3.822143e+06  5.858884e+06  1.948206e+07
# Library_Q3    3.085702e+06  5.343338e+06  7.895797e+06  2.822295e+07
#
# Formal Type        PP_5419   cid:12988   Target      CV[%]
# Strain
# IY1452        8.183859e+05  289.814111  PP_1607  20.218016
# IY1586        4.716865e+05  302.681833  PP_4549   1.258797
# IY1587        2.213753e+05  154.452567  PP_4550   8.410108
# IY1588        1.164940e+06  355.020800  PP_0368   4.072284
# IY1589        9.698603e+05  351.199900  PP_2136    0.74632
# ...                    ...         ...      ...        ...
# NT            1.193798e+06  254.648694  Control  11.693238
# Library_mean  3.813389e+05         NaN     None        NaN
# Library_std   4.036474e+05         NaN     None        NaN
# Library_Q1    1.477412e+04         NaN     None        NaN
# Library_Q3    6.880770e+05         NaN     None        NaN
#
# [132 rows x 102 columns]

# %% [markdown]
# ## Data visualization

# %% [markdown]
# Visualize isoprenols production and coefficient of variation (**TO BE DONE!**):

# %%
plot_titers(df_isoprenol, df_control_stat)
# Out:
# /tmp/ipykernel_194501/3388281739.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(df_prod.index.unique(), fontsize=10, rotation = 90)

# %%
df_isoprenol
df_isoprenol.index == 'NT'
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False,  True, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False,  True,  True, False, False, False, False,
#        False, False, False, False,  True, False,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
df_control_stat
# Out:
#         Isoprenol   Target      CV[%]
# Strain
# NT       304.0572  Control  11.693238
# NT       296.6867  Control  11.693238
# NT       288.9557  Control  11.693238
# NT       276.4664  Control  11.693238
# NT       272.8256  Control  11.693238
# NT       266.0055  Control  11.693238
# NT       265.7784  Control  11.693238
# NT       264.2026  Control  11.693238
# NT       254.1087  Control  11.693238
# NT       252.0408  Control  11.693238
# NT       248.3300  Control  11.693238
# NT       248.2884  Control  11.693238
# NT       243.4777  Control  11.693238
# NT       243.1879  Control  11.693238
# NT       242.5143  Control  11.693238
# NT       226.3360  Control  11.693238
# NT       204.6448  Control  11.693238
# NT       185.7698  Control  11.693238

# %% [markdown]
# **THERE ARE SOME ERRORS IN THIS GRAPH THAT NEED TO BE FIXED!!!**

# %% [markdown]
# ## Selecting target genes

# %% [markdown]
# **Criteria for downselection:**
#
# - Transcription value for the **CRISPRi** targeted gene:
#     - Within the bottom 25th percentile of the library
#     - More than 25% lower than the mean of the library

# %% [markdown]
# ### Calculate ratios

# %% [markdown]
# We calculate the ratios of the target protein concentration to the control, library mean, Q1 and Q3 (eliminating the strain with the target gene):

# %%
df_targets = find_fold_changes(df_targets)
# Out:
# Data for these 25 proteins was not present:
# ['PP_0362', 'PP_2589', 'PP_3744', 'PP_3394', 'PP_3355', 'PP_3282', 'PP_1157', 'PP_1394', 'PP_3280', 'PP_4737', 'PP_5420', 'PP_0806', 'PP_4128', 'PP_4188', 'PP_4043', 'PP_0104', 'PP_0105', 'PP_0106', 'PP_0813', 'PP_0815', 'PP_4161', 'PP_4160', 'PP_4159', 'PP_0277', 'Control']

# %%
df_targets
# Out:
# Formal Type        PP_0001        PP_0103       PP_0168       PP_0225  \
# Strain
# IY1452        3.586415e+06            NaN  9.210642e+06  1.124118e+07
# IY1586        4.941056e+06            NaN  1.236235e+07  9.721919e+06
# IY1587        3.383160e+06            NaN  6.041816e+06  9.352343e+06
# IY1588        3.782190e+06            NaN  1.541983e+07  9.795028e+06
# IY1589        5.161205e+06            NaN  6.916297e+06  1.067935e+07
# ...                    ...            ...           ...           ...
# NT            4.190752e+06   17237.230000  9.065235e+06  9.133443e+06
# Library_mean  3.414433e+06   83293.375614  9.349293e+06  7.547084e+06
# Library_std   1.002450e+06  205309.771335  4.764965e+06  2.921855e+06
# Library_Q1    2.559820e+06   15805.573333  6.016084e+06  5.913119e+06
# Library_Q3    4.167827e+06   39626.850000  1.189087e+07  9.482606e+06
#
# Formal Type         PP_0226       PP_0338       PP_0368        PP_0437  \
# Strain
# IY1452        142166.586667  6.109116e+07  8.039113e+06  298727.406667
# IY1586        308027.333333  6.355352e+07  7.188374e+06  554030.300000
# IY1587        149748.286667  5.562492e+07  6.100304e+06  404533.066667
# IY1588        532825.913333  8.523304e+07  2.806301e+05  478575.080000
# IY1589        175308.100000  5.926596e+07  3.409878e+07  442735.666667
# ...                     ...           ...           ...            ...
# NT            231729.880000  6.404960e+07  7.475888e+06  414110.655556
# Library_mean  185201.354357  5.084225e+07  5.920965e+06  295036.870542
# Library_std   143476.518113  1.375086e+07  3.444215e+06  132166.182716
# Library_Q1     70373.793333  4.089993e+07  3.984947e+06  205423.990000
# Library_Q3    278716.522500  6.099721e+07  6.799267e+06  374586.676667
#
# Formal Type        PP_0528       PP_0548  ...       PP_5417       PP_5419  \
# Strain                                    ...
# IY1452        9.636014e+05           NaN  ...  2.881347e+07  8.183859e+05
# IY1586        1.033685e+06           NaN  ...  3.218307e+07  4.716865e+05
# IY1587        8.223293e+05           NaN  ...  3.061075e+07  2.213753e+05
# IY1588        9.449282e+05           NaN  ...  3.083117e+07  1.164940e+06
# IY1589        1.115515e+06           NaN  ...  3.034837e+07  9.698603e+05
# ...                    ...           ...  ...           ...           ...
# NT            7.558040e+05   4309.307500  ...  2.702211e+07  1.193798e+06
# Library_mean  6.907668e+05  19054.325119  ...  2.414633e+07  3.813389e+05
# Library_std   2.791358e+05  31765.947948  ...  5.414382e+06  4.036474e+05
# Library_Q1    5.073299e+05   3550.646667  ...  1.948206e+07  1.477412e+04
# Library_Q3    8.286603e+05  10121.490000  ...  2.822295e+07  6.880770e+05
#
# Formal Type   Isoprenol mean   Target      CV[%]  Target:Control  \
# Strain
# IY1452            289.814111  PP_1607  20.218016        0.962351
# IY1586            302.681833  PP_4549   1.258797        0.055989
# IY1587            154.452567  PP_4550   8.410108        0.883285
# IY1588            355.020800  PP_0368   4.072284        0.037538
# IY1589            351.199900  PP_2136    0.74632        0.040121
# ...                      ...      ...        ...             ...
# NT                254.648694  Control  11.693238            None
# Library_mean             NaN      NaN        NaN            None
# Library_std              NaN      NaN        NaN            None
# Library_Q1               NaN      NaN        NaN            None
# Library_Q3               NaN      NaN        NaN            None
#
# Formal Type   Target:Library_mean  Target:Library_Q1  Target:Library_Q3  \
# Strain
# IY1452                   1.260467           1.626546           1.025424
# IY1586                   0.085443           0.114832           0.068155
# IY1587                   0.341594           1.251369           0.354566
# IY1588                   0.047396           0.070423           0.041274
# IY1589                   0.043054           0.052783           0.037776
# ...                           ...                ...                ...
# NT                           None               None               None
# Library_mean                 None               None               None
# Library_std                  None               None               None
# Library_Q1                   None               None               None
# Library_Q3                   None               None               None
#
# Formal Type    Z-score
# Strain
# IY1452        0.892173
# IY1586       -2.700526
# IY1587       -0.309067
# IY1588       -1.637626
# IY1589       -2.583302
# ...                ...
# NT                None
# Library_mean      None
# Library_std       None
# Library_Q1        None
# Library_Q3        None
#
# [132 rows x 107 columns]

# %% [markdown]
# ### Downselect targets

# %% [markdown]
# Create new dataframe to ease filtering:

# %%
cols = [
    'Target',
    'Isoprenol mean','CV[%]',
    'Target:Control','Target:Library_mean',
    'Target:Library_Q1','Target:Library_Q3'
]
df_filtering = df_targets.loc[strains][cols]

# %%
df_filtering
# Out:
# Formal Type   Target  Isoprenol mean       CV[%] Target:Control  \
# Strain
# IY2192       PP_5064       15.849800  173.205081       0.725064
# IY1671       PP_4679      100.588117  109.824115       0.395498
# IY2025       PP_4119       27.581113   86.677767       0.092758
# IY2195       PP_1610       63.463733   62.467704       0.418672
# IY1597       PP_1607      275.054650   34.172646           None
# ...              ...             ...         ...            ...
# IY1586       PP_4549      302.681833    1.258797       0.055989
# IY2047       PP_1317      228.187567    0.790181       0.009341
# IY1589       PP_2136      351.199900     0.74632       0.040121
# IY1661       PP_3394        0.000000         NaN           None
# IY1673       PP_1777        0.000000         NaN       0.012035
#
# Formal Type Target:Library_mean Target:Library_Q1 Target:Library_Q3
# Strain
# IY2192                 0.662723          1.162307           0.55705
# IY1671                 0.685004           1.16743          0.493447
# IY2025                 0.119652          0.187328           0.08702
# IY2195                 0.592968           0.87684          0.449948
# IY1597                     None              None              None
# ...                         ...               ...               ...
# IY1586                 0.085443          0.114832          0.068155
# IY2047                 0.009184          0.014582          0.007451
# IY1589                 0.043054          0.052783          0.037776
# IY1661                     None              None              None
# IY1673                 0.015424           0.02022          0.012625
#
# [128 rows x 7 columns]

# %% [markdown]
# Select gene targets with a protein expression that is lower than 75% of the mean protein expresion and within the bottom 25th percentile of the library, while having a minimum production of 100:

# %%
df_selection = df_filtering.loc[(
        (df_filtering['Target:Library_mean']<0.75) &
        (df_filtering['Target:Library_Q1']<1)
)
     & (df_filtering['Isoprenol mean']>100)
,:]

# %%
df_selection
# Out:
# Formal Type   Target  Isoprenol mean      CV[%] Target:Control  \
# Strain
# IY2057       PP_4187      215.706100  23.598608       0.384561
# IY2211       PP_4192      349.035467  20.285296       0.483296
# IY2216       PP_1755      172.138800  17.773086       0.047226
# IY1682       PP_2471      281.494767  17.505552       0.311721
# IY2225       PP_4185      172.424043   16.05754        0.26922
# ...              ...             ...        ...            ...
# IY2207       PP_0226      209.453243   1.802531       0.029683
# IY2026       PP_4120      242.994757   1.723609       0.008938
# IY1586       PP_4549      302.681833   1.258797       0.055989
# IY2047       PP_1317      228.187567   0.790181       0.009341
# IY1589       PP_2136      351.199900    0.74632       0.040121
#
# Formal Type Target:Library_mean Target:Library_Q1 Target:Library_Q3
# Strain
# IY2057                 0.556083          0.786809          0.412976
# IY2211                   0.5452          0.742546          0.424522
# IY2216                 0.062057          0.093938          0.049562
# IY1682                 0.412428          0.529113          0.336649
# IY2225                 0.484682          0.663339          0.360442
# ...                         ...               ...               ...
# IY2207                 0.037141          0.097742          0.024679
# IY2026                 0.010626          0.014253            0.0081
# IY1586                 0.085443          0.114832          0.068155
# IY2047                 0.009184          0.014582          0.007451
# IY1589                 0.043054          0.052783          0.037776
#
# [61 rows x 7 columns]

# %% [markdown]
# And here they are:

# %%
gene_targets= df_selection["Target"].tolist()
print(str(len(gene_targets))+ " gene targets:")
print(gene_targets)
# Out:
# 61 gene targets:
# ['PP_4187', 'PP_4192', 'PP_1755', 'PP_2471', 'PP_4185', 'PP_4651', 'PP_1769', 'PP_4186', 'PP_2137', 'PP_1444', 'PP_4121', 'PP_1319', 'PP_0658', 'PP_0437', 'PP_0814', 'PP_0168', 'PP_4189', 'PP_4116', 'PP_0597', 'PP_4862', 'PP_4667', 'PP_1506', 'PP_4011', 'PP_2213', 'PP_0103', 'PP_3071', 'PP_2339', 'PP_1620', 'PP_0812', 'PP_0774', 'PP_4266', 'PP_0897', 'PP_0368', 'PP_5186', 'PP_4636', 'PP_3578', 'PP_1240', 'PP_4123', 'PP_3123', 'PP_2095', 'PP_3755', 'PP_5203', 'PP_1457', 'PP_4487', 'PP_0654', 'PP_1318', 'PP_4191', 'PP_5288', 'PP_0528', 'PP_4122', 'PP_2925', 'PP_0999', 'PP_0751', 'PP_3365', 'PP_3754', 'PP_2112', 'PP_0226', 'PP_4120', 'PP_4549', 'PP_1317', 'PP_2136']

# %% [markdown]
# While keeping the maximum production:

# %%
max(df_selection["Isoprenol mean"])
# Out:
# 590.5495666666667

# %%
max(df_targets["Isoprenol mean"])
# Out:
# 590.5495666666667

# %% [markdown]
# ## Select double and triple combinations

# %% [markdown]
# Here we specify how many instances (designs or recommendations) we want to create and how many replicates (change as desired):

# %%
user_params['n_instances_double'] = 25
user_params['n_instances_triple'] = 25
user_params['n_replicates'] = 3

# %%
df_selection.head()
# Out:
# Formal Type   Target  Isoprenol mean      CV[%] Target:Control  \
# Strain
# IY2057       PP_4187      215.706100  23.598608       0.384561
# IY2211       PP_4192      349.035467  20.285296       0.483296
# IY2216       PP_1755      172.138800  17.773086       0.047226
# IY1682       PP_2471      281.494767  17.505552       0.311721
# IY2225       PP_4185      172.424043   16.05754        0.26922
#
# Formal Type Target:Library_mean Target:Library_Q1 Target:Library_Q3
# Strain
# IY2057                 0.556083          0.786809          0.412976
# IY2211                   0.5452          0.742546          0.424522
# IY2216                 0.062057          0.093938          0.049562
# IY1682                 0.412428          0.529113          0.336649
# IY2225                 0.484682          0.663339          0.360442

# %% [markdown]
# And we make a new dataframe with just the data we need for this task:

# %%
df_targets2 = df_selection[["Target","Isoprenol mean"]]
df_targets2.columns.name=''

# %%
df_targets2
# Out:
#          Target  Isoprenol mean
# Strain
# IY2057  PP_4187      215.706100
# IY2211  PP_4192      349.035467
# IY2216  PP_1755      172.138800
# IY1682  PP_2471      281.494767
# IY2225  PP_4185      172.424043
# ...         ...             ...
# IY2207  PP_0226      209.453243
# IY2026  PP_4120      242.994757
# IY1586  PP_4549      302.681833
# IY2047  PP_1317      228.187567
# IY1589  PP_2136      351.199900
#
# [61 rows x 2 columns]

# %% [markdown]
# To which we add the ratio of mean Isoprenol prodution to the production of the control strain:

# %%
control_production = df_targets.loc["NT",'Isoprenol mean']
df_targets2.loc[:,'Ratio'] = df_targets2.loc[:,'Isoprenol mean']/control_production
# Out:
# /tmp/ipykernel_1296431/4093088892.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets2.loc[:,'Ratio'] = df_targets2.loc[:,'Isoprenol mean']/control_production

# %%
df_targets2
# Out:
#          Target  Isoprenol mean     Ratio
# Strain
# IY2057  PP_4187      215.706100  0.847073
# IY2211  PP_4192      349.035467  1.370655
# IY2216  PP_1755      172.138800  0.675985
# IY1682  PP_2471      281.494767  1.105424
# IY2225  PP_4185      172.424043  0.677106
# ...         ...             ...       ...
# IY2207  PP_0226      209.453243  0.822518
# IY2026  PP_4120      242.994757  0.954235
# IY1586  PP_4549      302.681833  1.188625
# IY2047  PP_1317      228.187567  0.896088
# IY1589  PP_2136      351.199900  1.379155
#
# [61 rows x 3 columns]

# %% [markdown]
# As ratios go from very close to zero to around 1, we will add a factor (e.g. 5) to all of the targets so to have a non-zero probability to sample each of the targets.

# %%
df_targets2['Weight']= 5 + (10*df_targets2['Ratio']).apply(round)
df_targets2 = df_targets2.astype({'Weight': 'int'})
# Out:
# /tmp/ipykernel_1296431/3383393911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets2['Weight']= 5 + (10*df_targets2['Ratio']).apply(round)

# %%
df_targets2
# Out:
#          Target  Isoprenol mean     Ratio  Weight
# Strain
# IY2057  PP_4187      215.706100  0.847073      13
# IY2211  PP_4192      349.035467  1.370655      19
# IY2216  PP_1755      172.138800  0.675985      12
# IY1682  PP_2471      281.494767  1.105424      16
# IY2225  PP_4185      172.424043  0.677106      12
# ...         ...             ...       ...     ...
# IY2207  PP_0226      209.453243  0.822518      13
# IY2026  PP_4120      242.994757  0.954235      15
# IY1586  PP_4549      302.681833  1.188625      17
# IY2047  PP_1317      228.187567  0.896088      14
# IY1589  PP_2136      351.199900  1.379155      19
#
# [61 rows x 4 columns]

# %% [markdown]
# And we get rid of the ratio, since we use the weight column to choose doubles and triples:

# %%
df_targets2 = df_targets2[['Target', 'Isoprenol mean','Weight']]

# %%
df_targets2
# Out:
#          Target  Isoprenol mean  Weight
# Strain
# IY2057  PP_4187      215.706100      13
# IY2211  PP_4192      349.035467      19
# IY2216  PP_1755      172.138800      12
# IY1682  PP_2471      281.494767      16
# IY2225  PP_4185      172.424043      12
# ...         ...             ...     ...
# IY2207  PP_0226      209.453243      13
# IY2026  PP_4120      242.994757      15
# IY1586  PP_4549      302.681833      17
# IY2047  PP_1317      228.187567      14
# IY1589  PP_2136      351.199900      19
#
# [61 rows x 3 columns]

# %%
n_targets = len(df_targets2['Target'])

# %% [markdown]
# ### Choose double targets

# %% [markdown]
# We now choose double targets randomly but increasing the chances of choosing strains with higher production (as given by the weight):

# %%
df_targets2.sort_values(by='Target', inplace=True)
df_targets2.reset_index(drop=True, inplace=True)
# Out:
# /tmp/ipykernel_1296431/891652387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_targets2.sort_values(by='Target', inplace=True)

# %%
targets_double = choose_targets(
    df_targets2, 
    size=2, 
    n_instances=user_params['n_instances_double'],
    verbose=0
)

# %% [markdown]
# And here they are:

# %%
for target in targets_double:
    print(target)
# Out:
# ('PP_3365', 'PP_4191')
# ('PP_0814', 'PP_3365')
# ('PP_1318', 'PP_5186')
# ('PP_0528', 'PP_5288')
# ('PP_4487', 'PP_4862')
# ('PP_0814', 'PP_1755')
# ('PP_1318', 'PP_1319')
# ('PP_0528', 'PP_4011')
# ('PP_1317', 'PP_4636')
# ('PP_1319', 'PP_4116')
# ('PP_2925', 'PP_4549')
# ('PP_1240', 'PP_4636')
# ('PP_0437', 'PP_4191')
# ('PP_4191', 'PP_4862')
# ('PP_0168', 'PP_4123')
# ('PP_2213', 'PP_4189')
# ('PP_1319', 'PP_4636')
# ('PP_0103', 'PP_2471')
# ('PP_1755', 'PP_4011')
# ('PP_0168', 'PP_4011')
# ('PP_0654', 'PP_4120')
# ('PP_2471', 'PP_4121')
# ('PP_1317', 'PP_2213')
# ('PP_0658', 'PP_4667')
# ('PP_2136', 'PP_3755')

# %% [markdown]
# which we save in a file for later use:

# %%
with open(user_params['double_targets_file'], mode="wt") as f:
    for target in targets_double:
        f.write(str(target))

# %% [markdown]
# This is what they look like:

# %%
plot_double_targets(targets_double, df_targets2)

# %% [markdown]
# ### Choose triple targets

# %% [markdown]
# As for the case of double targets, we choose triple targets randomly but increasing the chances of choosing strains with higher production (as given by the weight):

# %%
targets_triple = choose_targets(
    df_targets2, 
    size=3, 
    n_instances=user_params['n_instances_triple'], 
)

# %%
plot_triple_targets(targets_triple, df_targets2)

# %%
targets_triple
# Out:
# [('PP_0774', 'PP_2136', 'PP_4487'),
#  ('PP_0437', 'PP_1769', 'PP_3578'),
#  ('PP_0814', 'PP_2137', 'PP_4186'),
#  ('PP_0528', 'PP_1240', 'PP_4122'),
#  ('PP_0654', 'PP_4121', 'PP_4487'),
#  ('PP_0774', 'PP_2137', 'PP_3754'),
#  ('PP_2925', 'PP_4116', 'PP_5288'),
#  ('PP_1769', 'PP_3071', 'PP_4122'),
#  ('PP_1444', 'PP_2471', 'PP_3754'),
#  ('PP_1506', 'PP_4120', 'PP_4187'),
#  ('PP_3123', 'PP_4120', 'PP_4862'),
#  ('PP_0751', 'PP_0814', 'PP_2137'),
#  ('PP_2136', 'PP_4116', 'PP_4185'),
#  ('PP_1457', 'PP_2136', 'PP_4186'),
#  ('PP_1317', 'PP_1318', 'PP_5288'),
#  ('PP_3755', 'PP_4191', 'PP_4636'),
#  ('PP_1240', 'PP_1769', 'PP_4187'),
#  ('PP_1506', 'PP_2136', 'PP_4549'),
#  ('PP_0658', 'PP_3123', 'PP_4487'),
#  ('PP_0168', 'PP_0774', 'PP_4191'),
#  ('PP_3071', 'PP_4189', 'PP_5203'),
#  ('PP_0774', 'PP_2471', 'PP_4487'),
#  ('PP_2339', 'PP_4191', 'PP_4487'),
#  ('PP_0812', 'PP_2112', 'PP_5203'),
#  ('PP_0368', 'PP_0437', 'PP_0814')]

# %% [markdown]
# And we save them in a file:

# %%
with open(user_params['triple_targets_file'], mode="wt") as f:
    for target in targets_triple:
        f.write(str(target))

# %%
def plot_crispr_library(df_long, df_targets,targetsP):
    
    # Figure dimensions, color and label
    fig_height = 15
    color = 'tomato'
    ylabel = 'Proteomics'
    
    # Keep only strains in index (assumed to have a non NaN value for production)    
    df_crispr = df_targets.loc[df_targets['Isoprenol mean'].dropna().index,:]
    df_crispr.sort_values('Isoprenol mean', ascending=False, inplace=True)
    
    # Find targets
#    n_crispr = len(df_crispr)
#    targetsP = df_crispr['Target'].tolist()
    
    # Create figure
    fig = plt.figure(figsize=(15, fig_height))
    fig.subplots_adjust(hspace=0.3, wspace=0.2)
    fig.suptitle(f'CRISPRi')

    for target in targetsP:
        i = targetsP.index(target)
        # Creating axes of the right size
        ax = fig.add_subplot(int(np.ceil(len(targetsP)/5)), 5, (i+1))
        if i==0:
            ax.set_ylabel(ylabel, fontsize=10)
        else:
            ax.set_ylabel(None)
        ax.set_xlabel(None)
            
        
        if target in df_crispr.columns.tolist():
            # Add violinplot
            data = df_long[df_long['Formal Type']==target]
            if len(data)>0:
                sns.violinplot(
                    data=data, 
                    x='Formal Type',
                    y='Value',
                    orient='v',
                    width=0.05,
                    linewidth=1, color='lightgray', alpha=0.3
                )

            # Add control
            plt.plot(df_targets.loc[control_strain, target], '.', color='k', markersize=10)

            # Add target
            data = df_targets[df_targets['Target']==target][target]
            if len(data)==1:
                plt.plot(data, marker='_', color=color, markersize=50, markeredgewidth=3)

            # Set y limits
            ylim = np.max(df_targets[target]) + 50
            ax.set_ylim([0, ylim])

        sns.despine(left=False, bottom=True)

        #fig.savefig(
         #   f"{user_params['output_dir']}/crispri_{ylabel}.png",
          #  transparent=True,
           # bbox_inches="tight",
            #dpi=300,
    #)
