# %% [markdown]
# # Train ART on Isoprenol and Proteomics data

# %% [markdown]
# Tested using **ART_3.9** kernel on skynet.ese.lbl.gov.

# %% [markdown]
# ## Inputs and output

# %% [markdown]
# **Requirements to run the notebook:**
#
# - EDD study slug
# - user parameters

# %% [markdown]
# **Files generated by running this notebook:**
#
# - a pickle file containing a trained ART object
# - files containing predictive accuracy metrics
# - plot of (cross-validated) predictions vs observations for the train data set
# - `draws.txt`, containing all draws from the optimization procedure
# - `recommendations.csv`, containing the ART recommendations for the next cycle
# - plots of predictive distributions for the recommendations
# - plots of success probabilities for the recommendations

# %% [markdown]
# ## Setup

# %% [markdown]
# The first step is to make sure the `ART` library is available in your kernel.
#
# Clone the corresponding git repository:
#
#
# `git clone https://github.com/JBEI/AutomatedRecommendationTool.git`
#
# or pull the latest version.
#
# Information about licensing ART is available at https://github.com/JBEI/ART.

# %% [markdown]
# We can then add library to the path and do the necessary import:

# %%
import sys
# sys.path.insert(0, "../AutomatedRecommendationTool")
import os

import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
import pickle
import shap

from art.core import * 
from art import filter_3rd_party_warnings

# %%
filter_3rd_party_warnings()
warnings.filterwarnings("ignore")

# %% [markdown]
# ## User parameters

# %%
user_params = {
    'output_dir': '../results/',
}

# %% [markdown]
# Load EDD study into a dataframe:

# %%
edd_study_slug = 'targeted-proteomics-of-isoprenol-producing-strains'
edd_server = 'edd.jbei.org'
username = 'tradivojevic'

# %%
df = utils.load_study(edd_study_slug=edd_study_slug, edd_server=edd_server, username=username)
# Out:
# Password for tradivojevic:  ··············
#  90%|█████████████████████████████████▍   | 1101/1218 [00:00<00:00, 2230.63it/s]/opt/conda/envs/ART_3.9/lib/python3.9/site-packages/edd_utils/__init__.py:169: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame, ignore_index=True)
# 100%|█████████████████████████████████████| 1218/1218 [00:00<00:00, 1762.58it/s]

# %%
df.head()
# Out:
#    Study ID                                         Study Name  Line ID  \
# 0    149074  Targeted proteomics of isoprenol producing str...   149854
# 1    149074  Targeted proteomics of isoprenol producing str...   149854
# 2    149074  Targeted proteomics of isoprenol producing str...   149854
# 3    149074  Targeted proteomics of isoprenol producing str...   149854
# 4    149074  Targeted proteomics of isoprenol producing str...   149854
#
#                           Replicate Key Line Name          Line Description  \
# 0  91734777-746a-4158-ad97-9bd27a910e7f   IY10-R1  p229-48h-a-18_PCRTUBE_43
# 1  91734777-746a-4158-ad97-9bd27a910e7f   IY10-R1  p229-48h-a-18_PCRTUBE_43
# 2  91734777-746a-4158-ad97-9bd27a910e7f   IY10-R1  p229-48h-a-18_PCRTUBE_43
# 3  91734777-746a-4158-ad97-9bd27a910e7f   IY10-R1  p229-48h-a-18_PCRTUBE_43
# 4  91734777-746a-4158-ad97-9bd27a910e7f   IY10-R1  p229-48h-a-18_PCRTUBE_43
#
#      Protocol  Assay ID Assay Name            Formal Type  \
# 0  Proteomics    150279    IY10-R1  sp|D7URV0|NPHT7_STRC1
# 1  Proteomics    150279    IY10-R1                 P00634
# 2  Proteomics    150279    IY10-R1                 P0AE22
# 3  Proteomics    150279    IY10-R1                 P0AFC0
# 4  Proteomics    150279    IY10-R1   sp|P15496|IDI1_YEAST
#
#                               Measurement Type  Compartment Units   Value  \
# 0               Acetoacetyl CoA synthase NphT7            0   NaN  3041.0
# 1                         Alkaline phosphatase            0   NaN     0.0
# 2                     Class B acid phosphatase            0   NaN     0.0
# 3  Dihydroneopterin triphosphate diphosphatase            0   NaN  6711.0
# 4      Isopentenyl-diphosphate delta-isomerase            0   NaN  2604.0
#
#    Hours
# 0   48.0
# 1   48.0
# 2   48.0
# 3   48.0
# 4   48.0

# %% [markdown]
# ## Dataframe profiling

# %%
profile_1 = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# %%
# profile_1.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 profile_1.to_notebook_iframe()
#
# File /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/pandas_profiling/profile_report.py:391, in ProfileReport.to_notebook_iframe(self)
#     380 """Used to output the HTML representation to a Jupyter notebook.
#     381 When config.notebook.iframe.attribute is "src", this function creates a temporary HTML file
#     382 in `./tmp/profile_[hash].html` and returns an Iframe pointing to that contents.
#    (...)
#     387     This constructions solves problems with conflicting stylesheets and navigation links.
#     388 """
#     389 from IPython.core.display import display
# --> 391 from pandas_profiling.report.presentation.flavours.widget.notebook import (
#     392     get_notebook_iframe,
#     393 )
#     395 # Ignore warning: https://github.com/ipython/ipython/pull/11350/files
#     396 with warnings.catch_warnings():
#
# File /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/__init__.py:1, in <module>
# ----> 1 from pandas_profiling.report.presentation.flavours.widget.alerts import WidgetAlerts
#       2 from pandas_profiling.report.presentation.flavours.widget.collapse import WidgetCollapse
#       3 from pandas_profiling.report.presentation.flavours.widget.container import (
#       4     WidgetContainer,
#       5 )
#
# File /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/alerts.py:3, in <module>
#       1 from typing import List
# ----> 3 from ipywidgets import HTML, Button, widgets
#       5 from pandas_profiling.report.presentation.core import Alerts
#       6 from pandas_profiling.report.presentation.flavours.html import templates
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %%
profile_1.to_file(f"{user_params['output_dir']}Pandas_report_1.html")

# %%
measurements = df["Measurement Type"].unique()

# %%
measurements
# Out:
# array(['Acetoacetyl CoA synthase NphT7', 'Alkaline phosphatase',
#        'Class B acid phosphatase',
#        'Dihydroneopterin triphosphate diphosphatase',
#        'Isopentenyl-diphosphate delta-isomerase',
#        'Farnesyl diphosphate synthase', 'Phosphomevalonate kinase',
#        'Diphosphomevalonate decarboxylase',
#        'Acetyl-CoA acetyltransferase',
#        'Hydroxymethylglutaryl-CoA synthase',
#        'Small heat shock protein IbpA', 'Geranyl diphosphate synthase',
#        'Mevalonate kinase',
#        'Acetyl-CoA acetyltransferase/HMG-CoA reductase',
#        'Limonene synthase', '3-METHYL-3-BUTEN-1-OL'], dtype=object)

# %% [markdown]
# ## ART run

# %% [markdown]
# Next we define a dictionary that contains all of the settings that ART will use to find the recommendations.

# %%
art_params = {
    'input_vars': [
        'Acetoacetyl CoA synthase NphT7', 
        'Alkaline phosphatase',
        'Class B acid phosphatase',
        'Dihydroneopterin triphosphate diphosphatase',
        'Isopentenyl-diphosphate delta-isomerase',
        'Farnesyl diphosphate synthase', 
        'Phosphomevalonate kinase',
        'Diphosphomevalonate decarboxylase',
        'Acetyl-CoA acetyltransferase',
        'Hydroxymethylglutaryl-CoA synthase',
        'Small heat shock protein IbpA', 
        'Geranyl diphosphate synthase',
        'Mevalonate kinase',
        'Acetyl-CoA acetyltransferase/HMG-CoA reductase',
        'Limonene synthase'
    ],
    'response_vars': ['3-METHYL-3-BUTEN-1-OL'],
    'cross_val': True,
    'num_recommendations': 20,
    'max_mcmc_cores': 10,
    'seed': 10,
    'output_directory': user_params['output_dir'],
    'verbose': 1
}

# %% [markdown]
# ### Train data analysis

# %% [markdown]
# Before we proceed with training ART, let's analyze the dataframe of input and response variables. For that we just turn off the `build_model` option and let ART transform the dataframe exported from EDD:

# %%
art_params['build_model'] = False

# %%
art = RecommendationEngine(df, **art_params)
# Out:
# Using a maximum of 10 cores for MCMC sampling (of 72 available).

# %%
art.df.head()
# Out:
#                          Input Variables                       \
#           Acetoacetyl CoA synthase NphT7 Alkaline phosphatase
# Line Name
# IY10-R1                           3041.0                  0.0
# IY10-R2                           1384.0                219.0
# IY10-R3                           3292.0                  0.0
# IY1049-R1                         1302.0                  0.0
# IY1049-R2                         1416.0                  0.0
#
#                                     \
#           Class B acid phosphatase
# Line Name
# IY10-R1                        0.0
# IY10-R2                        0.0
# IY10-R3                        0.0
# IY1049-R1                 218394.0
# IY1049-R2                 223548.0
#
#                                                        \
#           Dihydroneopterin triphosphate diphosphatase
# Line Name
# IY10-R1                                        6711.0
# IY10-R2                                        7521.0
# IY10-R3                                        7195.0
# IY1049-R1                                   1046648.0
# IY1049-R2                                   1098810.0
#
#                                                    \
#           Isopentenyl-diphosphate delta-isomerase
# Line Name
# IY10-R1                                    2604.0
# IY10-R2                                       0.0
# IY10-R3                                       0.0
# IY1049-R1                                     0.0
# IY1049-R2                                     0.0
#
#                                                                   \
#           Farnesyl diphosphate synthase Phosphomevalonate kinase
# Line Name
# IY10-R1                          2815.0                    662.0
# IY10-R2                          3485.0                      0.0
# IY10-R3                          1421.0                      0.0
# IY1049-R1                        2836.0                      0.0
# IY1049-R2                        2129.0                      0.0
#
#                                                                           \
#           Diphosphomevalonate decarboxylase Acetyl-CoA acetyltransferase
# Line Name
# IY10-R1                               859.0                          0.0
# IY10-R2                              1298.0                          0.0
# IY10-R3                               652.0                          0.0
# IY1049-R1                          889158.0                     270776.0
# IY1049-R2                          911561.0                     271357.0
#
#                                                                             \
#           Hydroxymethylglutaryl-CoA synthase Small heat shock protein IbpA
# Line Name
# IY10-R1                              47215.0                        2682.0
# IY10-R2                              11241.0                        2711.0
# IY10-R3                               6041.0                        2796.0
# IY1049-R1                           400994.0                       97909.0
# IY1049-R2                           412270.0                      107645.0
#
#                                                           \
#           Geranyl diphosphate synthase Mevalonate kinase
# Line Name
# IY10-R1                          652.0               0.0
# IY10-R2                            0.0               0.0
# IY10-R3                            0.0               0.0
# IY1049-R1                       1458.0          644835.0
# IY1049-R2                          0.0          659958.0
#
#                                                                             \
#           Acetyl-CoA acetyltransferase/HMG-CoA reductase Limonene synthase
# Line Name
# IY10-R1                                            305.0            1232.0
# IY10-R2                                            741.0            1028.0
# IY10-R3                                              0.0             955.0
# IY1049-R1                                       272148.0             918.0
# IY1049-R2                                       278026.0            1352.0
#
#              Response Variables
#           3-METHYL-3-BUTEN-1-OL
# Line Name
# IY10-R1                     NaN
# IY10-R2                     NaN
# IY10-R3                     NaN
# IY1049-R1             699.82880
# IY1049-R2             710.20416

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10,5), gridspec_kw={'width_ratios': [5, 1]})
sns.heatmap(art.df['Input Variables'], linewidth=0.5, ax=axs[0])
axs[0].set_title('Input Variables')
sns.heatmap(art.df['Response Variables'], linewidth=0.5, ax=axs[1])
axs[1].set_title('Response Variable')
# Out:
# Text(0.5, 1.0, 'Response Variable')

# %% [markdown]
# Looks like we don't have isoprenol measurements for all lines.

# %%
line_names_nan = art.df[art.df['Response Variables'].isna()['3-METHYL-3-BUTEN-1-OL']].index

# %%
line_names_nan
# Out:
# Index(['IY10-R1', 'IY10-R2', 'IY10-R3', 'IY1135-R1', 'IY1135-R2', 'IY1135-R3',
#        'IY1136-R1', 'IY1136-R2', 'IY1136-R3', 'IY1137-R1', 'IY1137-R2',
#        'IY1137-R3', 'IY1138-R1', 'IY1138-R2', 'IY1138-R3', 'IY1139-R1',
#        'IY1139-R2', 'IY1139-R3', 'IY535-R1', 'IY535-R2', 'IY535-R3',
#        'IY603-R1', 'IY603-R2', 'IY603-R3', 'IY606-R1', 'IY606-R2', 'IY606-R3',
#        'IY780-R1', 'IY780-R2', 'IY780-R3'],
#       dtype='object', name='Line Name')

# %%
len(line_names_nan)
# Out:
# 30

# %% [markdown]
# Drop lines without isoprenol measurements:

# %%
art.df = art.df.drop(index=line_names_nan)

# %%
num_instances = len(art.df)

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10,5), gridspec_kw={'width_ratios': [5, 1]})
sns.heatmap(art.df['Input Variables'], linewidth=0.5, ax=axs[0])
axs[0].set_title('Input Variables')
sns.heatmap(art.df['Response Variables'], linewidth=0.5, ax=axs[1])
axs[1].set_title('Response Variable')
# Out:
# Text(0.5, 1.0, 'Response Variable')

# %% [markdown]
# Let's look into isoprenol data as a function of individual protein expressions:

# %%
from matplotlib import cm
fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(10,10), sharey=True, constrained_layout=True)

cmap_name = 'tab20b'
colors = cm.get_cmap(cmap_name)

for protein, ax in zip(measurements[:-1], axs.ravel()):
    for i in range(num_instances):
        ax.plot(
            art.df['Input Variables'][protein].iloc[i], 
            art.df['Response Variables'].iloc[i], 
            color=colors(1), 
            marker='o', 
            label=art.df.index[i])
    ax.set_xlabel(protein)
    ax.set_ylabel(art.response_vars[0])
    
# fig.legend(lines, labels, loc = 'right')

# %% [markdown]
# Filter lines from the full dataframe that do not have isoprenol measurements:

# %%
df['Protocol'].unique()
# Out:
# array(['Proteomics', 'GC-FID'], dtype=object)

# %%
lines_proteomics = set(df[df['Protocol']=='Proteomics']['Line Name'].unique())
lines_isoprenol = set(df[df['Protocol']=='GC-FID']['Line Name'].unique())

# %%
lines_all = lines_proteomics.intersection(lines_isoprenol)

# %%
len(lines_all)
# Out:
# 48

# %%
df = df[df['Line Name'].isin(lines_all)]

# %%
len(df['Line Name'].unique())
# Out:
# 48

# %% [markdown]
# ### Train ART model

# %%
art_params['build_model'] = True
art_params['recommend'] = False

# %%
run_art = False

# %%
# %%time
if run_art:
    art = RecommendationEngine(df, **art_params)
else:
    with open(os.path.join(art_params['output_directory'], 'art.pkl'), 'rb') as output:
        art = pickle.load(output)
# Out:
# CPU times: user 364 ms, sys: 79.1 ms, total: 443 ms
# Wall time: 1.87 s

# %%
art.evaluate_models_cv()
# Out:
#                                     MAE     MRAE(%)        StdAE  \
# Name
# Neural Regressor             797.026978  310.112798  1538.150100
# Random Forest Regressor       86.336187   75.363802    71.143011
# Support Vector Regressor     341.717945  461.013208   184.882525
# Kernel Ridge Regressor       264.118493   54.288693   249.242019
# K-NN Regressor               233.932904  127.907102   226.759975
# Gaussian Process Regressor   103.920731   48.764534    97.990328
# Gradient Boosting Regressor   85.031523   70.583232    83.788623
# TPOT Regressor               143.111196   65.335398   183.914413
# Ensemble Model               126.300000   37.287317   128.118133
#
#                                       MSE      $R^2$
# Name
# Neural Regressor             3.001158e+06 -21.628111
# Random Forest Regressor      1.251527e+04   0.905637
# Support Vector Regressor     1.509527e+05  -0.138152
# Kernel Ridge Regressor       1.318802e+05   0.005651
# K-NN Regressor               1.061447e+05   0.199691
# Gaussian Process Regressor   2.040162e+04   0.846176
# Gradient Boosting Regressor  1.425089e+04   0.892551
# TPOT Regressor               5.430533e+04   0.590549
# Ensemble Model               3.236595e+04   0.755967

# %%
art.evaluate_models()

# %%
art.model_df[0][["MAE", "MRAE(%)", "StdAE", "MSE", "$R^2$"]]
# Out:
#                                     MAE     MRAE(%)       StdAE  \
# Name
# Neural Regressor               2.811129    1.064756    6.316177
# Random Forest Regressor       15.323789    7.508701   19.794421
# Support Vector Regressor     309.789053  435.931363  190.957223
# Kernel Ridge Regressor        50.361159   11.417539   47.255723
# K-NN Regressor                58.738198   20.483834   50.339967
# Gaussian Process Regressor    13.827038   12.816823   12.547523
# Gradient Boosting Regressor    0.532693    0.357730    0.401073
# TPOT Regressor                16.976517   12.844323   13.825677
# Ensemble Model                14.689567   10.890322   11.937240
#
#                                        MSE     $R^2$
# Name
# Neural Regressor                 47.796535  0.999640
# Random Forest Regressor         626.637631  0.995275
# Support Vector Regressor     132433.918701  0.001476
# Kernel Ridge Regressor         4769.349715  0.964040
# K-NN Regressor                 5984.288135  0.954880
# Gaussian Process Regressor      348.627339  0.997371
# Gradient Boosting Regressor       0.444621  0.999997
# TPOT Regressor                  479.351446  0.996386
# Ensemble Model                  358.281079  0.997299

# %% [markdown]
# Plot observations vs. posterior predictive distributions for the cross-validated data.

# %%
plot.predictions_vs_observations(art, cv_flag=True, errorbars_flag=True,
                                 xlim=[[-50, 1300]], ylim=[[-100, 1500]])

# %% [markdown]
# Train data:

# %%
plot.predictions_vs_observations(art, cv_flag=False, errorbars_flag=True,
                                 xlim=[[-50, 1300]], ylim=[[-100, 1500]])

# %% [markdown]
# Plot the mean (lower triangle) and standard deviation (upper triangle) of the final model as functions of each pair of input varibles:

# %%
plot.model_pairwise(art)

# %% [markdown]
# ### Find recommendations

# %% [markdown]
# Alternatively, you can change those parameters to generate recommendations from a longer/shorter sampling run or a different exploration-exploitation strategy:

# %%
art_scaleinput.niter = 100000
art_scaleinput.rel_rec_distance = 2
art_scaleinput.optimize()
# Out:
# Starting parallel tempering using 10 chains…
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# /opt/conda/envs/ART_3.9/lib/python3.9/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
# warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 1 of 10
# Chain 1 of 10: loaded ART params in 0.01 s
# Finished 1.00 percent in 7.103512 s Acceptance rate = 0.133
# Finished 2.00 percent in 14.055635 s Acceptance rate = 0.1225Adding DE jump with weight 20
# Finished 3.00 percent in 20.738389 s Acceptance rate = 0.116
# Finished 4.00 percent in 27.354531 s Acceptance rate = 0.10825
# Finished 5.00 percent in 34.077451 s Acceptance rate = 0.1068
# Finished 6.00 percent in 40.719854 s Acceptance rate = 0.105167
# Finished 7.00 percent in 48.161806 s Acceptance rate = 0.108
# Finished 8.00 percent in 55.326468 s Acceptance rate = 0.113125
# Finished 9.00 percent in 62.623085 s Acceptance rate = 0.111556
# Finished 10.00 percent in 69.691915 s Acceptance rate = 0.11
# Finished 11.00 percent in 76.831955 s Acceptance rate = 0.111455
# Finished 12.00 percent in 83.949887 s Acceptance rate = 0.116
# Finished 13.00 percent in 91.182606 s Acceptance rate = 0.116077
# Finished 14.00 percent in 98.661163 s Acceptance rate = 0.112214
# Finished 15.00 percent in 105.525522 s Acceptance rate = 0.113333
# Finished 16.00 percent in 112.846187 s Acceptance rate = 0.112937
# Finished 17.00 percent in 120.160259 s Acceptance rate = 0.113
# Finished 18.00 percent in 127.263423 s Acceptance rate = 0.113556
# Finished 19.00 percent in 134.571019 s Acceptance rate = 0.114737
# Finished 20.00 percent in 142.434799 s Acceptance rate = 0.11475
# Finished 21.00 percent in 149.935162 s Acceptance rate = 0.114429
# Finished 22.00 percent in 157.268649 s Acceptance rate = 0.115455
# Finished 23.00 percent in 164.202774 s Acceptance rate = 0.116043
# Finished 24.00 percent in 171.295518 s Acceptance rate = 0.117333
# Finished 25.00 percent in 178.754878 s Acceptance rate = 0.1168
# Finished 26.00 percent in 185.819931 s Acceptance rate = 0.116346
# Finished 27.00 percent in 193.238332 s Acceptance rate = 0.116519
# Finished 28.00 percent in 201.043998 s Acceptance rate = 0.117286
# Finished 29.00 percent in 208.872353 s Acceptance rate = 0.117552
# Finished 30.00 percent in 216.698605 s Acceptance rate = 0.1183
# Finished 77.00 percent in 602.740514 s Acceptance rate = 0.126896
# Finished 78.00 percent in 611.172702 s Acceptance rate = 0.126487
# Finished 79.00 percent in 619.588180 s Acceptance rate = 0.126506
# Finished 80.00 percent in 628.117796 s Acceptance rate = 0.1268
# Finished 81.00 percent in 636.352541 s Acceptance rate = 0.126914
# Finished 82.00 percent in 645.007399 s Acceptance rate = 0.127049
# Finished 83.00 percent in 654.211426 s Acceptance rate = 0.127325
# Finished 84.00 percent in 662.688694 s Acceptance rate = 0.127298
# Finished 85.00 percent in 670.995930 s Acceptance rate = 0.127612
# Finished 86.00 percent in 679.748015 s Acceptance rate = 0.127209
# Finished 87.00 percent in 688.844805 s Acceptance rate = 0.127471
# Finished 88.00 percent in 697.398492 s Acceptance rate = 0.12767
# Finished 89.00 percent in 706.120646 s Acceptance rate = 0.128067
# Finished 90.00 percent in 715.048050 s Acceptance rate = 0.128233
# Finished 91.00 percent in 723.621597 s Acceptance rate = 0.127923
# Finished 92.00 percent in 732.197029 s Acceptance rate = 0.127793
# Finished 93.00 percent in 740.720794 s Acceptance rate = 0.127989
# Finished 94.00 percent in 749.376179 s Acceptance rate = 0.128117
# Finished 95.00 percent in 758.041615 s Acceptance rate = 0.128011
# Finished 96.00 percent in 766.952396 s Acceptance rate = 0.128083
# Finished 97.00 percent in 775.762781 s Acceptance rate = 0.128186
# Finished 98.00 percent in 784.482607 s Acceptance rate = 0.128459
# Finished 99.00 percent in 793.656836 s Acceptance rate = 0.128444
# Run Complete in 804.27 s
# Chain 1 of 10: done in 804.36 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 2 of 10
# Chain 2 of 10: loaded ART params in 0.01 s
# Chain 2 of 10: done in 804.37 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 3 of 10
# Chain 3 of 10: loaded ART params in 0.01 s
# Chain 3 of 10: done in 804.36 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 4 of 10
# Chain 4 of 10: loaded ART params in 0.01 s
# Chain 4 of 10: done in 804.38 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 5 of 10
# Chain 5 of 10: loaded ART params in 0.01 s
# Chain 5 of 10: done in 804.67 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 6 of 10
# Chain 6 of 10: loaded ART params in 0.02 s
# Chain 6 of 10: done in 804.67 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 7 of 10
# Chain 7 of 10: loaded ART params in 0.01 s
# Chain 7 of 10: done in 804.66 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 8 of 10
# Chain 8 of 10: loaded ART params in 0.01 s
# Chain 8 of 10: done in 804.78 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 9 of 10
# Chain 9 of 10: loaded ART params in 0.01 s
# Chain 9 of 10: done in 804.62 s
# Optional acor package is not installed. Acor is optionally used to calculate the effective chain length for output in the chain file.
# Running chain 10 of 10
# Chain 10 of 10: loaded ART params in 0.01 s
# Chain 10 of 10: done in 804.59 s
# Done with parallel tempering in 809.98 s
# 24 recommendations neglected with 40.00% engineering accuracy
# Recommendations:
#     Acetoacetyl CoA synthase NphT7  Alkaline phosphatase  \
# 0                      2884.881761          11785.388419
# 1                      2890.088131          11440.551907
# 2                      2880.481549          11895.852483
# 3                      2934.398255          11255.423867
# 4                      2970.146240          11904.603233
# 5                      2894.356385          11472.575807
# 6                      2888.729549          11764.078030
# Sampling-based optimization and generation of recommendations was ran above with the default options (`niter=100000` for number of samples collected, `alpha=None` for a purely exploitative strategy) and `rel_rec_distance=40%` for relative recommendations distance.

# %% [markdown]
# Calculate and visualize the success probabilities if the recommended strains are being engineered.

# %%
cumulative_success_prob = art_scaleinput.calculate_success_prob(current_best=art_scaleinput.find_current_best())
plot.success_prob(art_scaleinput, cumulative_success_prob)
# Out:
# Calculating success probabilities…
# Sampling posterior predictive distributions…
# Done sampling in 14.94 s
# Done calculating success probabilities in 14.95 s

# %%
art_scaleinput.recommendations
# Out:
#     Acetoacetyl CoA synthase NphT7  Alkaline phosphatase  \
# 0                      2884.881761          11785.388419
# 1                      2890.088131          11440.551907
# 2                      2880.481549          11895.852483
# 3                      2934.398255          11255.423867
# 4                      2970.146240          11904.603233
# 5                      2894.356385          11472.575807
# 6                      2888.729549          11764.078030
# 7                      2924.220871          11516.616488
# 8                      2900.536086          11703.507728
# 9                      2927.261683          12150.198394
# 10                     2985.852215          11774.576944
# 11                     2875.967221          11954.548993
# 12                     2875.030624          11869.289019
# 13                     2890.793326          12017.838356
# 14                     2930.672332          11554.846643
# 15                     2927.057960          11633.467343
# 16                     2985.123054          12005.442760
# 17                     2930.735851          12211.863864
# 18                     2951.947458          11274.791858
# 19                     2874.925263          12225.322178
#
#     Class B acid phosphatase  Dihydroneopterin triphosphate diphosphatase  \
# 0              303733.366386                                438920.440020
# 1              302338.105538                                434828.095694
# 2              303682.630205                                440489.457403
# 3              303582.535430                                388566.861706
# 4              303673.670174                                416868.254154
# 5              303487.320917                                431032.733451
# 6              303213.052098                                430390.942789
# 7              303817.804681                                413997.188756
# 8              302302.831550                                437365.792000
# 9              302894.724069                                441173.459612
# 10             303445.576806                                411459.224653
# 11             303039.423636                                442272.346600
# 12             303050.078947                                442403.980227
# 13             303157.533871                                448876.402780
# 14             303715.447525                                411187.602700
# 15             303675.875844                                416547.668223
# 16             303444.299080                                411551.109858
# 17             303223.418658                                440401.818265
# 18             303482.007619                                409339.341068
# 19             303120.070396                                440137.517332
#
#     Isopentenyl-diphosphate delta-isomerase  Farnesyl diphosphate synthase  \
# 0                               9026.572757                    1304.019261
# 1                               8969.896611                    1156.104930
# 2                               9015.614218                    1310.220243
# 3                               8409.669022                    1713.093239
# 4                               8589.499445                    1215.228426
# 5                               9014.472995                    1340.824243
# 6                               8954.639811                    1047.317089
# 7                               8786.899166                    1616.042888
# 8                               8894.336624                    1123.422021
# 9                               8970.185494                    1165.181587
# 10                              8699.321587                    1543.946174
# 11                              8980.173300                    1442.373880
# 12                              8984.771917                    1446.008606
# 13                              8968.293814                    1448.706462
# 14                              8848.704211                    1685.497563
# 15                              8790.631954                    1577.602768
# 16                              8675.996108                    1510.720316
# 17                              8960.922284                    1262.027385
# 18                              8733.817113                    1592.067685
# 19                              8960.873960                    1262.096624
#
#     Phosphomevalonate kinase  Diphosphomevalonate decarboxylase  \
# 0               28582.318998                      157822.920856
# 1               25546.078087                      153175.728012
# 2               28558.375504                      158362.164681
# 3               25528.559381                      143993.792019
# 1         1536.974584            1431.378470
# 2         1560.342162            1431.344543
# 3         1548.634289            1431.163585
# 4         1477.177716            1431.160822
# 5         1563.197851            1431.153470
# 6         1515.296685            1431.115816
# 7         1562.219918            1431.083410
# 8         1540.324798            1430.933317
# 9         1547.838518            1430.807509
# 10        1557.807666            1430.800445
# 11        1564.112082            1430.784521
# 12        1563.450945            1430.783692
# 13        1555.796159            1430.778668
# 14        1554.117060            1430.754587
# 15        1557.780453            1430.743826
# 16        1560.755447            1430.742570
# 17        1542.691242            1430.736368
# 18        1557.462973            1430.733638
# 19        1542.661608            1430.733376

# %% [markdown]
# Plot first two principal components of recommendations (in green) with observed data (in red).

# %%
plt.style.use('default')
plot.recommendations_pc(art_scaleinput, plot_scale_factor=1)

# %% [markdown]
# Heatmap of the mean of the final model as function of the two principal components of input varibles:

# %%
# Need a fix in the plot.py module
# test_y = []

# model = art
# plot.plot_model(model, art, scaling_factor=1.5,
#                 midpoint=0.6,
#                 title='Ensemble Model', plot_points=True)

# %%
# Need a fix in the plot.py module

# titles = ['Neural Regressor',
#           'Random Forest Regressor',
#           'Support Vector Regressor',
#           'Kernel Ridge Regressor',
#           'K-NN Regressor',
#           'Gaussian Process Regressor',
#           'Gradient Boosting Regressor',
#           'TPOT Regressor']

# for model, title in zip(art.model_df[0]['Model'][:-1],titles):
#     plot.plot_model(model, art, scaling_factor=1.5,
#                midpoint=0.6, title=title, plot_points=True)

# %% [markdown]
# Visualize input data pairwise. The size of each point represents the level of output variable (limonene production).

# %%
plot.data_pairwise(art_scaleinput, recommendations=art_scaleinput.recommendations, scale=0.3)

# %%
art_scaleinput.save_pkl_object()

# %% [markdown]
# ## SHAP analysis

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
plt.style.use('default')

# %% [markdown]
# Define the function for our predictions:

# %%
def f(X):
    return art_scaleinput.predict(X)

# %%
X_df = pd.DataFrame(data=art_scaleinput.X, columns=art_params['input_vars'])

# %%
explainer_e = shap.Explainer(f, X_df)
shap_values_e = explainer_e(X_df)
# Out:
# Permutation explainer: 49it [00:32,  1.18it/s]

# %% [markdown]
# To inspect the global importance of each feature in the model for all instances we run:

# %%
shap.summary_plot(shap_values_e)

# %% [markdown]
# This bar plot shows that Class B acid phosphatase, Hydroxymethylglutaryl-CoA synthase and Acetyl-CoA acetyltransferase/HMG-CoA reductase are the top three factors driving the model's prediction of Isoprenol

# %%
shap.plots.heatmap(shap_values_e, instance_order=shap_values_e.sum(1), max_display=15)

# %%
clustering = shap.utils.hclust(X_df, art_scaleinput.y) # by default this trains (X.shape[1] choose 2) 2-feature XGBoost models
shap.plots.bar(shap_values_e, clustering=clustering)

# %%
# use Kernel SHAP to explain the ART's predictions
explainer = shap.KernelExplainer(model=f, data=X_df)
shap_values = explainer.shap_values(X=X_df, nsamples=10) # runs ART 10 times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # use Kernel SHAP to explain the ART's predictions
# ----> 2 explainer = shap.KernelExplainer(model=f, data=X_df)
#       3 shap_values = explainer.shap_values(X=X_df, nsamples=10)
#
# NameError: name 'shap' is not defined
