# %% [markdown]
# ### Volcano plots from Top3 proteomics data
#
# - The notebook requires Top3 data from proteomics with individual replicates
# - Originally designed for iterative upload of DBTL data (7 rounds)
#     - Substitute with your own data of interest

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
import re
from adjustText import adjust_text
import os

# %%
cd
# Out:
# C:\Users\Carruthers

# %% [markdown]
# #### Import Top3 data of interest

# %% [markdown]
# Load Top3 data from each of the DBTL cycles for analysis

# %%
input_dir = r'Figure_Data'
output_dir = r'Figure_Export'

# %%
filenames = [f'DBTL{0}.csv']

input_paths = [os.path.join(input_dir, filename) for filename in filenames]

# Load CSVs and concatenate multiple files if necessary
dataframes = [pd.read_csv(input_path) for input_path in input_paths]
combined_df = pd.concat(dataframes, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       3 input_paths = [os.path.join(input_dir, filename) for filename in filenames]
#       5 # Load CSVs and concatenate multiple files if necessary
# ----> 6 dataframes = [pd.read_csv(input_path) for input_path in input_paths]
#       7 combined_df = pd.concat(dataframes, ignore_index=True)
#
# Cell In[10], line 6, in <listcomp>(.0)
#       3 input_paths = [os.path.join(input_dir, filename) for filename in filenames]
#       5 # Load CSVs and concatenate multiple files if necessary
# ----> 6 dataframes = [pd.read_csv(input_path) for input_path in input_paths]
#       7 combined_df = pd.concat(dataframes, ignore_index=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Figure_Data\\DBTL0.csv'

# %%
combined_df.head()
# Out:
#   Protein.Group Protein.Names Protein                   Protein.Description  \
# 0        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 1        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 2        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 3        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
# 4        P00552    KKA2_KLEPN     Neo  Aminoglycoside 3'-phosphotransferase
#
#     Sample Replicate  Top_3pep_counts_mean  \
# 0  Control        R1           119112382.0
# 1  Control        R2           149172095.3
# 2  Control        R3           138700868.7
# 3  Control        R4           100306326.3
# 4  Control        R5           114276780.7
#
#    %_of protein_abundance_Top3-method  log10_%_abundance  Cycle
# 0                            3.112624           0.493127      0
# 1                            3.712705           0.569690      0
# 2                            3.700489           0.568259      0
# 3                            2.650788           0.423375      0
# 4                            2.835433           0.452619      0

# %% [markdown]
# Translate Top3 proteins into locus identities and then transform all of the uploaded concatenated .csvs

# %%
# Load the name_df DataFrame for translation
name_df = pd.read_csv('proteomics_id_translator_240305.csv') 

# Create a dictionary from the name_df for fast lookup
translator_dict = pd.Series(name_df['locus'].values, index=name_df['extracted']).to_dict()

# Use the dictionary to map the Protein.Group names to locus names
combined_df['Protein.Group'] = combined_df['Protein.Group'].map(lambda x: translator_dict.get(x, x))

# Count the number of non-translated protein groups
nontranslated = combined_df['Protein.Group'].apply(lambda x: x not in translator_dict.values()).sum()
print(f"In total, N = {nontranslated}/{len(combined_df['Protein.Group'])} proteins were not translated to locus names")
# Out:
# In total, N = 0/784056 proteins were not translated to locus names

# %% [markdown]
# ### Initialize a DataFrame to store log2 and log10 values for all samples

# %% [markdown]
# Include samples across all cycles to be analyzed
#
# ##### These will be compared against your "controls"

# %%
# samples_df = pd.read_csv('Top_25.csv')
# samples_of_interest = samples_df['Top_25'].tolist()

samples_of_interest = [
    "PP_0368",
    "PP_0437",
    "PP_0528",
    "PP_0751",
    "PP_0812",
    "PP_0813",
    "PP_0814",
    "PP_0815",
    "PP_1317",
    "PP_1506",
    "PP_2136",
    "PP_4120",
    "PP_4189",
    "PP_4191",
    "PP_4192"]

# %%
samples_of_interest
# Out:
# ['PP_0368',
#  'PP_0437',
#  'PP_0528',
#  'PP_0751',
#  'PP_0812',
#  'PP_0813',
#  'PP_0814',
#  'PP_0815',
#  'PP_1317',
#  'PP_1506',
#  'PP_2136',
#  'PP_4120',
#  'PP_4189',
#  'PP_4191',
#  'PP_4192']

# %% [markdown]
# #### Define your controls
# - Pairwise comparison of samples_of_interest to the defined controls pooled across all cycles

# %%
# Initialize an empty DataFrame to store log2 and log10 results
log2_log10_results = pd.DataFrame()
sample_control_pairs = {sample: "Control" for sample in samples_of_interest}

# %% [markdown]
# #### Set thresholds for the volcano plots
# - p-value threshold and log2 fold_change threshold
# - filtering Top3 data

# %%
# Define thresholds for filtering
# Use 1 if simply looking for any differences between a strain and a control
fold_change_threshold = 2
log2_fold_change_threshold= np.log2(fold_change_threshold)

p_value_threshold = 0.05
top3_filter = 0.001

# %% [markdown]
# ### Generate volcano plots
# - Sample pairs vs. control

# %%
# Initialize the results DataFrame before the loop
log2_log10_results = pd.DataFrame()
replicates_to_include = ['R4', 'R5', 'R6']

for sample, control in sample_control_pairs.items():
    # Filter data for the current sample and its control
    if sample in ['PP_0812', 'PP_0813']:
        sample_data = combined_df[(combined_df['Sample'] == sample) & (combined_df['Replicate'].isin(replicates_to_include))]
    else:
        sample_data = combined_df[combined_df['Sample'] == sample]
    
    control_data = combined_df[combined_df['Sample'] == control]

    # Debug: Check if data is loaded correctly
    if sample_data.empty or control_data.empty:
        print(f"No data for {sample} or {control}")
        continue

# for sample, control in sample_control_pairs.items():
#     sample_data = combined_df[combined_df['Sample'] == sample]
#     control_data = combined_df[combined_df['Sample'] == control]
#     # Debug: Check if data is loaded correctly
#     if sample_data.empty or control_data.empty:
#         print(f"No data for {sample} or {control}")
#         continue

    # Compute mean %_of protein_abundance_Top3-method for each protein
    sample_mean = sample_data.groupby('Protein.Group')['%_of protein_abundance_Top3-method'].mean().reset_index()
    control_mean = control_data.groupby('Protein.Group')['%_of protein_abundance_Top3-method'].mean().reset_index()

    # Rename columns for clarity
    sample_mean.rename(columns={'%_of protein_abundance_Top3-method': 'sample_abundance'}, inplace=True)
    control_mean.rename(columns={'%_of protein_abundance_Top3-method': 'control_abundance'}, inplace=True)

    # Filter reference_mean to include only abundances > top3_filter
    sample_mean = sample_mean[sample_mean['sample_abundance'] > top3_filter]

    # Merge the data on Protein.Group
    merged_data = pd.merge(sample_mean, control_mean, on='Protein.Group', how='outer')

    # Calculate log2 fold change (fill missing values with NaN)
    merged_data['log2_change'] = np.log2(merged_data['sample_abundance'] / merged_data['control_abundance'])

    # Debug: Check if log2_change contains NaN values
    if merged_data['log2_change'].isna().all():
        print(f"All log2 fold changes are NaN for {sample} vs {control}")
        continue

    # Compute p-values (assume replicates data exists for actual p-value calculation)
    sample_reps = sample_data[['Protein.Group', '%_of protein_abundance_Top3-method']]
    control_reps = control_data[['Protein.Group', '%_of protein_abundance_Top3-method']]

    p_values = []
    for protein in merged_data['Protein.Group']:
        group1 = sample_reps[sample_reps['Protein.Group'] == protein]['%_of protein_abundance_Top3-method']
        group2 = control_reps[control_reps['Protein.Group'] == protein]['%_of protein_abundance_Top3-method']
        if not group1.empty and not group2.empty:
            _, p_val = ttest_ind(group1, group2, equal_var=False)
        else:
            p_val = np.nan
        p_values.append(p_val)

    # Add p-values and log10 transformation
    merged_data['p_value'] = p_values
    merged_data['log10_p_value'] = -np.log10(merged_data['p_value'])

    # Debug: Check if log10_p_value contains NaN values
    if merged_data['log10_p_value'].isna().all():
        print(f"All log10 p-values are NaN for {sample} vs {control}")
        continue

    # Filter based on plotting criteria
    filtered_data = merged_data[
        (merged_data['log2_change'].abs() > log2_fold_change_threshold) &
        (merged_data['log10_p_value'] > -np.log10(p_value_threshold))
    ]

    # Store filtered results in log2_log10_results
    if not filtered_data.empty:
        temp_results = filtered_data[['Protein.Group', 'log2_change', 'log10_p_value']].copy()
        temp_results.rename(
            columns={'log2_change': f'{sample}_log2_FC', 'log10_p_value': f'{sample}_log10_pval'},
            inplace=True
        )

        # Merge with the main results DataFrame
        if log2_log10_results.empty:
            log2_log10_results = temp_results
        else:
            log2_log10_results = pd.merge(
                log2_log10_results,
                temp_results,
                on='Protein.Group',
                how='outer'
            )

    # Create volcano plot for the current sample
    fold_change = merged_data['log2_change']
    p_values = merged_data['log10_p_value']

    plt.figure(figsize=(8, 6))
    plt.scatter(fold_change, p_values, s=15, alpha=0.25)
    plt.title(f"{sample} vs {control}")
    plt.xlabel("Log2(Fold Change)")
    plt.ylabel("Log10(P-Value)")
    plt.grid(False)
    plt.ylim(0,)
    plt.xlim(-10, 10)

    # Threshold lines
    plt.axvline(x=log2_fold_change_threshold, color='r', linestyle='--', linewidth=1)
    plt.axvline(x=-log2_fold_change_threshold, color='r', linestyle='--', linewidth=1)
    plt.axhline(y=-np.log10(p_value_threshold), color='g', linestyle='--', linewidth=1)

#     #Annotate significant points; this adds arrows to each of the plots and is computationally intensive, will probably crash if threshold zero
#     texts = []
#     labels = merged_data['Protein.Group']
#     for i, label in enumerate(labels):
#         if (fold_change[i] > log2_fold_change_threshold or fold_change[i] <-log2_fold_change_threshold) and p_values[i] > -np.log10(p_value_threshold):
#             text = plt.text(fold_change[i], p_values[i], label, fontsize=10)
#             texts.append(text)

#     if texts:
#          adjust_text(texts, arrowprops=dict(arrowstyle='-', color='red', lw=1))

#     #Show the plot
    plt.show()

# Save the filtered log2 and log10 values to a CSV file
if not log2_log10_results.empty:
    log2_log10_results.to_csv('Volcano_Results.csv', index=False)
    print("Log2 and Log10 values saved to 'Volcano_Results.csv'")
else:
    print("No significant results to save.")
# Out:
# Log2 and Log10 values saved to 'Volcano_Results.csv'

# %% [markdown]
# ### Investigating genes that are upregulated amongst a subset of samples

# %%
len('Volcano_Results.csv')
# Out:
# 19

# %% [markdown]
# #### TCA Cycle

# %%
# Define the list of proteins
pathway_name = "Proteins_TCA_Superpathway"
proteins_txt = pd.read_csv('pathway-genes-TCA.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the TCA cycle were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
#print("Those genes were:")
#print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 22 out of 23 genes in the TCA cycle were significantly changed across strains
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### Branched Chain AA Superpathway

# %%
# Define the list of proteins
pathway_name = "Proteins_AA_Superpathway"
proteins_txt = pd.read_csv('pathway-genes-BRANCHED-CHAIN-AA-SYN-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# %% [markdown]
# #### Glycolysis Genes

# %%
# Define the list of proteins
pathway_name = "Glycolysis"
proteins_txt = pd.read_csv('pathway-genes-PWY1G01-2.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} cycle were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 28 out of 34 genes in the Glycolysis cycle were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                                                  Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0751_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0751_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_1024       eda                                                   KHG/KDPG aldolase        -0.311405        -0.505757         0.492084              NaN         0.490707         0.490914         0.567566              NaN         0.379132              NaN        -0.706530              NaN              NaN         0.391689              NaN            1.616924            2.725510            3.504495                 NaN            3.223036            1.729247            4.386733                 NaN            1.931708                 NaN            2.297498                 NaN                 NaN            4.332899                 NaN
#        PP_1444       gcd                                  quinoprotein glucose dehydrogenase        -0.690919        -0.230660         0.502380              NaN        -0.823606              NaN        -1.606803         0.926337              NaN              NaN        -1.214911              NaN              NaN              NaN              NaN            2.875827            1.476083            3.977055                 NaN            1.517911                 NaN            3.134626           10.164618                 NaN                 NaN            2.368586                 NaN                 NaN                 NaN                 NaN
#        PP_3376      kguD                                    phosphogluconate 2-dehydrogenase        -0.234613        -1.096369        -0.836835         0.479221        -0.454512        -0.311090        -1.263662        -0.695968        -0.532727        -2.114745        -1.206675              NaN              NaN        -1.482891        -0.257084            1.679668            7.983913            7.202242            4.353198            5.204655            1.917028           11.141412            2.666143            3.699775            5.202476            5.750919                 NaN                 NaN           12.140725            2.676514
#        PP_3378      kguK                                                 2-ketogluconokinase        -0.747193        -1.580989        -0.390027         0.502911        -0.899145        -0.697548        -1.500915        -1.035895        -0.431445        -2.817369              NaN         0.285247        -0.600662        -2.507846        -0.210273            3.286865            2.612434            1.476610            3.070770            4.266890            7.413425            7.036908            2.873344            5.527205            4.360464                 NaN            1.636598            3.276665           13.419371            2.353738
#        PP_4701     pgi-2                                       glucose 6-phosphate isomerase        -2.034184        -1.918009         1.216870              NaN              NaN              NaN              NaN              NaN              NaN              NaN        -2.224520              NaN              NaN              NaN              NaN            2.462049            2.230414            4.574268                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            2.560720                 NaN                 NaN                 NaN                 NaN
#        PP_4960       fba                                      fructose-bisphosphate aldolase        -0.153960              NaN        -0.155441         0.264880         0.328534         0.387084         0.376531              NaN         0.245305         0.259017              NaN         0.281818         0.716477         0.721560         0.728776            1.852432                 NaN            1.587841            4.705850            2.120680            2.635145            3.103475                 NaN            2.047385            2.331902                 NaN            3.447303            1.500558            3.898821            2.541157
#        PP_5056      gpmI         2,3-bisphosphoglycerate-independent phosphoglycerate mutase        -0.220186        -0.149076              NaN         0.181223              NaN         0.226124              NaN              NaN         0.172126              NaN              NaN              NaN         0.614049         0.442760         0.313209            1.485873            1.965021                 NaN            4.723477                 NaN            2.226027                 NaN                 NaN            1.324367                 NaN                 NaN                 NaN            2.109906            3.503450            2.096457
#        PP_1009      gapA                            glyceraldehyde-3-phosphate dehydrogenase              NaN        -0.752818        -0.252604              NaN              NaN              NaN         0.182089        -0.549738        -0.450066        -1.078030              NaN              NaN              NaN        -0.648514        -0.432726                 NaN            5.397051            2.361465                 NaN                 NaN                 NaN            1.468072            1.901089            4.348456            8.559868                 NaN                 NaN                 NaN            5.545975            4.163084
#        PP_1010       edd                                        phosphogluconate dehydratase              NaN        -0.272269              NaN              NaN        -0.152296        -0.140362              NaN              NaN        -0.373021              NaN              NaN        -0.172372              NaN              NaN              NaN                 NaN            3.691268                 NaN                 NaN            2.208118            2.942575                 NaN                 NaN            1.344678                 NaN                 NaN            1.783375                 NaN                 NaN                 NaN
#        PP_1612       eno                                                             enolase              NaN        -0.291003              NaN              NaN         0.266172              NaN         0.138740              NaN              NaN              NaN              NaN         0.449667         0.234586              NaN              NaN                 NaN            3.011332                 NaN                 NaN            2.570969                 NaN            3.438858                 NaN                 NaN                 NaN                 NaN            2.442598            1.816296                 NaN                 NaN
#        PP_2052       NaN bifunctional sugar-phosphatase/mannitol-1-phosphate 5-dehydrogenase              NaN        -0.903047              NaN        -1.666547              NaN              NaN              NaN        -0.414864        -1.393607        -1.091448              NaN        -1.747523        -1.908767        -0.679927        -0.709112                 NaN            1.869290                 NaN            1.630740                 NaN                 NaN                 NaN            1.582740            3.658249            3.248935                 NaN            2.124860            4.804064            2.174199            1.806805
#        PP_2149      gapB                            glyceraldehyde-3-phosphate dehydrogenase              NaN         0.223250              NaN         0.333830         0.569588         0.591486         0.694460         0.622177              NaN              NaN         0.220548         0.386939         0.316456         0.852051         0.468231                 NaN            2.917955                 NaN            6.546384            1.604165            1.367854           12.554646            2.092140                 NaN                 NaN            2.984405            2.234141            1.920441            3.072423            4.268659
#        PP_3416      gnuK                                                  D-gluconate kinase              NaN        -0.722960         0.191190              NaN        -0.266237        -0.373089              NaN        -0.931987              NaN        -0.476436         0.585574              NaN         0.462993        -0.801692        -0.552362                 NaN            2.842115            1.658540                 NaN            2.079137            3.515195                 NaN            7.575472                 NaN            2.060254            4.228786                 NaN            3.432667            5.525305            4.533038
#        PP_4963       pgk                                             phosphoglycerate kinase              NaN         0.276128        -0.161099              NaN              NaN              NaN              NaN         0.425571              NaN              NaN              NaN         0.154593              NaN         0.580976         0.659088                 NaN            3.299285            1.851864                 NaN                 NaN                 NaN                 NaN            1.880510                 NaN                 NaN                 NaN            1.401472                 NaN            1.349372            1.686221
#        PP_5040       fbp                                 class 1 fructose-1,6-bisphosphatase              NaN        -0.214368        -0.254529        -0.218969        -0.313687        -0.277784        -0.512668              NaN        -0.461131        -0.302909        -0.236767              NaN              NaN              NaN         0.138414                 NaN            2.018150            1.717498            6.680894            3.494261            7.622598            5.545634                 NaN            5.861019            2.518127            2.102399                 NaN                 NaN                 NaN            1.616911
#        PP_5150      rpiA                                      ribose-5-phosphate isomerase A              NaN         0.174729        -0.305413              NaN        -0.520287              NaN              NaN              NaN              NaN        -0.424217              NaN              NaN              NaN              NaN              NaN                 NaN            1.766740            5.993965                 NaN            5.240436                 NaN                 NaN                 NaN                 NaN            1.424500                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_5351     zwf-3                                 glucose 6-phosphate 1-dehydrogenase              NaN         1.150998         1.387071              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            4.258971            1.433859                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0415       rpe                                    ribulose-5-phosphate 3-epimerase              NaN              NaN        -0.366499        -0.333671         0.213497              NaN              NaN              NaN              NaN        -0.192234              NaN              NaN              NaN         0.306503              NaN                 NaN                 NaN            4.981107            1.593088            2.767403                 NaN                 NaN                 NaN                 NaN            1.829820                 NaN                 NaN                 NaN            2.665742                 NaN
#        PP_1022     zwf-1                                 glucose 6-phosphate-1-dehydrogenase              NaN              NaN         0.168286              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.126129                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1023       pgl                                           6-phosphogluconolactonase              NaN              NaN         0.235827              NaN              NaN         0.325316         0.386984         0.449069              NaN         0.593146        -0.409972              NaN              NaN         0.692070              NaN                 NaN                 NaN            3.209865                 NaN                 NaN            1.915981            2.782003            3.706146                 NaN            1.932359            4.489745                 NaN                 NaN            4.920359                 NaN
#        PP_1362      pykA                                                  pyruvate kinase II              NaN              NaN        -0.205865        -0.220139        -0.326194        -0.372895              NaN              NaN              NaN              NaN              NaN        -0.245182              NaN              NaN              NaN                 NaN                 NaN            1.396207            2.986053            1.915062            1.966730                 NaN                 NaN                 NaN                 NaN                 NaN            1.645368                 NaN                 NaN                 NaN
#        PP_3384       NaN                                           gluconate 2-dehydrogenase              NaN              NaN        -0.323158              NaN              NaN              NaN        -1.486016              NaN              NaN        -1.100755              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.265021                 NaN                 NaN                 NaN            2.720759                 NaN                 NaN            1.567386                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_3443       NaN                            glyceraldehyde-3-phosphate dehydrogenase              NaN              NaN         0.512356              NaN              NaN        -0.296400              NaN         0.291929         0.277662              NaN              NaN              NaN              NaN         0.534344              NaN                 NaN                 NaN            5.612969                 NaN                 NaN            1.925158                 NaN            2.278515            1.431730                 NaN                 NaN                 NaN                 NaN            2.385897                 NaN
#        PP_4715      tpiA                                          triose phosphate isomerase              NaN              NaN        -0.230864              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            3.105637                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1011       glk                                                         glucokinase              NaN              NaN              NaN        -0.214851              NaN              NaN        -0.217464              NaN        -0.359412              NaN              NaN              NaN              NaN              NaN        -0.198374                 NaN                 NaN                 NaN            1.724930                 NaN                 NaN            2.403796                 NaN            3.455361                 NaN                 NaN                 NaN                 NaN                 NaN            1.411970
#        PP_3383       NaN                                           gluconate 2-dehydrogenase              NaN              NaN              NaN         0.244240              NaN              NaN        -1.483149         0.770529              NaN              NaN              NaN              NaN              NaN         0.343319              NaN                 NaN                 NaN                 NaN            3.292216                 NaN                 NaN            1.783953            1.371463                 NaN                 NaN                 NaN                 NaN                 NaN            1.539079                 NaN
#        PP_4965      tktA                                                     transketolase A              NaN              NaN              NaN              NaN              NaN         0.265555              NaN              NaN              NaN              NaN              NaN         0.179065              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN            3.084013                 NaN                 NaN                 NaN                 NaN                 NaN            1.428672                 NaN                 NaN                 NaN
#        PP_3382       NaN                                           gluconate 2-dehydrogenase              NaN              NaN              NaN              NaN              NaN              NaN        -0.944707         0.521150              NaN              NaN              NaN         0.215327              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            2.473275            1.825254                 NaN                 NaN                 NaN            2.748796                 NaN                 NaN                 NaN
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### Non-oxidative PP Pathway

# %%
# Define the second list of proteins
pathway_name = "Proteins_Non_Oxidative_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-NONOXIPENT-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
# Out:
# 4 out of 4 genes in the Proteins_Non_Oxidative_PP_Pathway were significantly changed across strains
# Those genes were:
# Gene Accession Gene name               Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0751_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0751_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_2168       tal                    transaldolase              NaN         0.710663         0.210730              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN         0.770813              NaN                 NaN            1.696065            1.308219                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            4.843813                 NaN
#        PP_5150      rpiA   ribose-5-phosphate isomerase A              NaN         0.174729        -0.305413              NaN        -0.520287              NaN              NaN              NaN              NaN        -0.424217              NaN              NaN              NaN              NaN              NaN                 NaN            1.766740            5.993965                 NaN            5.240436                 NaN                 NaN                 NaN                 NaN             1.42450                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0415       rpe ribulose-5-phosphate 3-epimerase              NaN              NaN        -0.366499        -0.333671         0.213497              NaN              NaN              NaN              NaN        -0.192234              NaN              NaN              NaN         0.306503              NaN                 NaN                 NaN            4.981107            1.593088            2.767403                 NaN                 NaN                 NaN                 NaN             1.82982                 NaN                 NaN                 NaN            2.665742                 NaN
#        PP_4965      tktA                  transketolase A              NaN              NaN              NaN              NaN              NaN         0.265555              NaN              NaN              NaN              NaN              NaN         0.179065              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN            3.084013                 NaN                 NaN                 NaN                 NaN                 NaN            1.428672                 NaN                 NaN                 NaN

# %% [markdown]
# #### Oxidative PP Pathway

# %%
# Define the list of proteins
pathway_name = "Proteins_Oxidative_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-OXIDATIVEPENT-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes in the {pathway_name} were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')

# Extract relevant columns
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 3 out of 5 genes in the Proteins_Oxidative_PP_Pathway were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                  Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0751_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0751_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_5351     zwf-3 glucose 6-phosphate 1-dehydrogenase              NaN         1.150998         1.387071              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            4.258971            1.433859                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1022     zwf-1 glucose 6-phosphate-1-dehydrogenase              NaN              NaN         0.168286              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN            2.126129                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1023       pgl           6-phosphogluconolactonase              NaN              NaN         0.235827              NaN              NaN         0.325316         0.386984         0.449069              NaN         0.593146        -0.409972              NaN              NaN          0.69207              NaN                 NaN                 NaN            3.209865                 NaN                 NaN            1.915981            2.782003            3.706146                 NaN            1.932359            4.489745                 NaN                 NaN            4.920359                 NaN
# The genes were saved to 'locus_genes.csv'

# %% [markdown]
# #### PP Pathway

# %%
# Define the list of proteins
pathway_name = "Proteins_PP_Pathway"
proteins_txt = pd.read_csv('pathway-genes-PENTOSE-P-PWY.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt['Gene Accession'].tolist()

filtered_data = log2_log10_results.dropna(subset=[f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest])
matching_proteins = filtered_data[filtered_data['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)
# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
# Out:
# 0 out of 9 genes were significantly changed across strains
# Those genes were:
# Empty DataFrame
# Columns: [Gene Accession, Gene name, Enzymatic activity, PP_0368_log2_FC, PP_0437_log2_FC, PP_0528_log2_FC, PP_0751_log2_FC, PP_0812_log2_FC, PP_0813_log2_FC, PP_0814_log2_FC, PP_0815_log2_FC, PP_1317_log2_FC, PP_1506_log2_FC, PP_2136_log2_FC, PP_4120_log2_FC, PP_4189_log2_FC, PP_4191_log2_FC, PP_4192_log2_FC, PP_0368_log10_pval, PP_0437_log10_pval, PP_0528_log10_pval, PP_0751_log10_pval, PP_0812_log10_pval, PP_0813_log10_pval, PP_0814_log10_pval, PP_0815_log10_pval, PP_1317_log10_pval, PP_1506_log10_pval, PP_2136_log10_pval, PP_4120_log10_pval, PP_4189_log10_pval, PP_4191_log10_pval, PP_4192_log10_pval]
# Index: []

# %% [markdown]
# #### Full ETC

# %%
# Define the second list of proteins
pathway_name = "pathway-genes-PWY-Respiration_Full"
proteins_txt = pd.read_csv('pathway-genes-PWY-Respiration_Full.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
locus_genes.to_csv('locus_genes.csv', index=False)
print("The genes were saved to 'locus_genes.csv'")
# Out:
# 32 out of 53 genes were significantly changed across strains
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "8-amino-7-oxononanoate biosynthesis"
proteins_txt = pd.read_csv('8-amino-7-oxononanoate biosynthesis.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 11 out of 20 genes were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                                               Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0751_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0751_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_4175      fabB                                           3-oxoacyl-ACP synthase        -0.240274              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN            3.675007                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0363      bioF                                  8-amino-7-oxononanoate synthase              NaN         4.948147              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            1.412259                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0364      bioH                               pimeloyl-ACP methyl ester esterase              NaN         2.153040              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            1.574523                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_0366      bioD                                          dethiobiotin synthetase              NaN         1.203607         0.393883        -0.205277        -0.788860              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN                 NaN            1.458399            1.346258            1.980448            1.631296                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4635       NaN                       enoylpimeloyl-[acp] methyl ester reductase              NaN         0.251917              NaN        -0.440840              NaN              NaN              NaN              NaN              NaN              NaN         0.201659        -0.216806              NaN              NaN              NaN                 NaN            2.096430                 NaN            4.855578                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.335915            6.219617                 NaN                 NaN                 NaN
#        PP_1914      fabG                                  3-oxoacyl-ACP reductase subunit              NaN              NaN              NaN         0.291110         0.231485         0.209777              NaN              NaN              NaN         0.688565              NaN              NaN              NaN              NaN         0.426793                 NaN                 NaN                 NaN            4.421255            6.059868            2.181948                 NaN                 NaN                 NaN             2.54571                 NaN                 NaN                 NaN                 NaN            2.070291
#        PP_0581       NaN                                          3-oxoacyl-ACP reductase              NaN              NaN              NaN              NaN        -0.752239        -0.838776              NaN              NaN              NaN              NaN              NaN        -0.898032         -0.74193         1.120335        -1.053206                 NaN                 NaN                 NaN                 NaN            2.946987            1.724384                 NaN                 NaN                 NaN                 NaN                 NaN            1.439148            2.215479            2.017207            4.126439
#        PP_4174      fabA                             3R-3-hydroxydecanoyl-ACP dehydratase              NaN              NaN              NaN              NaN         0.325376              NaN         0.219981              NaN         0.349760              NaN              NaN         0.340749              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN            3.304957                 NaN            3.139426                 NaN            7.879410                 NaN                 NaN            1.402475                 NaN                 NaN                 NaN
#        PP_4984      bioA adenosylmethionine--8-amino-7-oxononanoate aminotransferase BioA              NaN              NaN              NaN              NaN              NaN              NaN              NaN          1.08494         0.838547              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.780691            1.852458                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1916      fabF                                    beta-ketoacyl-ACP synthase II              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN        -0.426622              NaN              NaN              NaN              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            5.885083                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_1602      fabZ                               3-hydroxyacyl-ACP dehydratase FabZ              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN        -0.308978              NaN              NaN              NaN              NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN            1.548167                 NaN                 NaN                 NaN                 NaN
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "pyruvate_to_aceCoA"
proteins_txt = pd.read_csv('pyruvate_to_aceCoA.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
print("Those genes were:")
print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 4 out of 4 genes were significantly changed across strains
# Those genes were:
# Gene Accession Gene name                  Enzymatic activity  PP_0368_log2_FC  PP_0437_log2_FC  PP_0528_log2_FC  PP_0751_log2_FC  PP_0812_log2_FC  PP_0813_log2_FC  PP_0814_log2_FC  PP_0815_log2_FC  PP_1317_log2_FC  PP_1506_log2_FC  PP_2136_log2_FC  PP_4120_log2_FC  PP_4189_log2_FC  PP_4191_log2_FC  PP_4192_log2_FC  PP_0368_log10_pval  PP_0437_log10_pval  PP_0528_log10_pval  PP_0751_log10_pval  PP_0812_log10_pval  PP_0813_log10_pval  PP_0814_log10_pval  PP_0815_log10_pval  PP_1317_log10_pval  PP_1506_log10_pval  PP_2136_log10_pval  PP_4120_log10_pval  PP_4189_log10_pval  PP_4191_log10_pval  PP_4192_log10_pval
#        PP_0339      aceE pyruvate dehydrogenase E1 component         0.186257         0.358541              NaN              NaN        -0.301413        -0.281034        -0.404250              NaN              NaN              NaN              NaN              NaN              NaN              NaN              NaN            1.751200            4.834314                 NaN                 NaN            1.540401            4.313383           11.690939                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN                 NaN
#        PP_4187      lpdG         dihydrolipoyl dehydrogenase        -0.213477              NaN              NaN         0.152331        -0.720353        -0.526100        -0.788279        -0.637925        -0.479302        -0.787339        -0.253101        -0.567896        -2.516605        -0.387113        -0.734688            1.907906                 NaN                 NaN            1.918109            7.442227            6.081902            8.682425            1.518103            5.978406            5.321065            1.659953            5.528544            11.71969            2.560842            5.783035
#        PP_0338      aceF         AceF-S-acetyldihydrolipoate              NaN         0.417881              NaN              NaN              NaN              NaN        -0.212638              NaN         0.325774              NaN              NaN              NaN              NaN              NaN         0.335403                 NaN            2.261722                 NaN                 NaN                 NaN                 NaN            1.333662                 NaN            2.110381                 NaN                 NaN                 NaN                 NaN                 NaN            2.201861
#        PP_5366       lpd         dihydrolipoyl dehydrogenase              NaN              NaN              NaN        -1.901800              NaN        -0.993573              NaN         0.375131              NaN        -1.089180              NaN        -1.306754              NaN         1.202863              NaN                 NaN                 NaN                 NaN            6.424664                 NaN            1.961625                 NaN            1.400714                 NaN            2.700237                 NaN            1.789703                 NaN            4.010713                 NaN
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "Biotin_Pathway_Genes"
proteins_txt = pd.read_csv('Biotin_Pathway_Genes.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
#print("Those genes were:")
#print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 16 out of 26 genes were significantly changed across strains
# The genes were saved to 'locus_genes.csv'

# %%
# Define the second list of proteins
pathway_name = "FAD_FAB"
proteins_txt = pd.read_csv('FAD_FAB.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
#print("Those genes were:")
#print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 25 out of 44 genes were significantly changed across strains
# The genes were saved to 'locus_genes.csv'

# %%
#polyisoprenoid

pathway_name = "polyisoprenoid"
proteins_txt = pd.read_csv('polyisoprenoid.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
#print("Those genes were:")
#print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 6 out of 10 genes were significantly changed across strains
# The genes were saved to 'locus_genes.csv'

# %%
#heme
pathway_name = "heme"
proteins_txt = pd.read_csv('heme.txt', delimiter='\t')  # Adjust the separator if needed
proteins_txt2 = proteins_txt.drop_duplicates(subset='Gene Accession')
second_list = proteins_txt2['Gene Accession'].tolist()

# Compare the significant data against the second list of proteins
matching_proteins = log2_log10_results[log2_log10_results['Protein.Group'].isin(second_list)]
matching_proteins.to_csv(f"{pathway_name}_matching_proteins.csv", index=False)

# Calculate the ratio of significantly changed genes
included = matching_proteins.shape[0]
total = len(second_list)
ratio = included / total

print(f"{included} out of {total} genes were significantly changed across strains")
merged_data = pd.merge(matching_proteins, proteins_txt, left_on='Protein.Group', right_on='Gene Accession')
columns_to_include = ['Gene Accession', 'Gene name', 'Enzymatic activity'] + [f"{sample}_log2_FC" for sample in samples_of_interest] + [f"{sample}_log10_pval" for sample in samples_of_interest]
locus_genes = merged_data[columns_to_include].drop_duplicates(subset='Gene Accession')

# Print the genes by locus with additional information
#print("Those genes were:")
#print(locus_genes.to_string(index=False))
locus_genes.to_csv('locus_genes.csv', index=False)

print("The genes were saved to 'locus_genes.csv'")
# Out:
# 3 out of 5 genes were significantly changed across strains
# The genes were saved to 'locus_genes.csv'
